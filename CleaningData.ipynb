# %%
import json
import re
def ouvrir_json(chemin):
    f = open(chemin, encoding="utf-8")
    toto = json.load(f)
    f.close()
    return toto

def ecrire_fichier(chemin, contenu):
    w = open(chemin, "w", encoding="utf-8")
    w.write(contenu)
    w.close()

def lire_fichier(chemin):
    f = open(chemin, "r", encoding="utf-8")
    chaine = f.read()
    f.close()
    return chaine

def ecrire_json(chemin, contenu):
    w = open(chemin, "w", encoding="utf-8")
    w.write(json.dumps(contenu, indent=2, ensure_ascii=False))
    w.close()

# %%
echantillon1 = ouvrir_json("Data/echantillon1.json").values()

# %%
parole_echantillon1=[]
for child in all_data:
    for parole in child:
        paroles = parole.get("lyrics")
        parole_echantillon1.append(paroles)

# %% [markdown]
# Se débarrasser des fin de lignes et symboles déechappement
# ---------------------------------------------------------------------

# %%
withoutSlash_n =[]
for s in parole_echantillon1:
    try:
        x = re.sub("\n", " ", s)
    except:
        pass
    withoutSlash_n.append(x)

# %%
withoutSlash =[]
for s in withoutSlash_n:
    try:
        x = re.sub("\\'", "'", s)
    except:
        pass
    withoutSlash.append(x)

# %%
#withoutStopwords_spacy = []
#sw = nlp.Defaults.stop_words
#for w in withoutSlash_n:
  #  if w not in sw:
        
 #       withoutStopwords_spacy.append(w)
#print(withoutStopwords_spacy)

# %%
ecrire_json("clean_echantillon1.json", withoutSlash)

# %%
import spacy
nlp_sm = spacy.load("fr_core_news_sm")
nlp_md = spacy.load("fr_core_news_md")
nlp_lg = spacy.load("fr_core_news_lg")

# %%
f1 = ouvrir_json("all_data/clean_all_data.json")
f2 = ouvrir_json("Data/voc_glaff.json")

# %% [markdown]
# Lieux trouvés par le modèle spacy small
# ---------------------------------------------------------------------

# %%
loc=[]
for texte in f1:
    doc = nlp_sm(texte)
    for entity in doc.ents:
        if entity.label_ =="LOC":
            loc.append(entity.text)
print(len(set(loc)))
print(set(loc))
# Out:
# 19881
# {'Dévoré', 'Mont Saint Michel', 'Gentil coquelicot mesdames Gentil', 'Lloran', 'Ensevelies', 'Lincoln continental Je te dirai', 'Évitez', 'Infiltrez', 'Lavilliers', 'mer Pétroliers', 'Aspasie', 'Cailleras Nés', "bois d'Boulogne", 'Se grido Anche', 'Auto-clash', 'guerra Emprunte', 'Light', 'Tokyo tu vis Dans la mort', 'Cette mélodie', 'Laisse tomber ton vieux', 'Lamour', 'Io', 'Dipset', "J't'ai\u2005", 'Italiennes', 'Rodrigue', 'Troublé', 'Kinshasa Sie', 'Soledad', 'El Blanco', 'rue des Batignolles', 'I mutate', 'mer Nous aurons', 'Now I’', 'Ici c’', "J'veux\u205f", 'Borgnes', 'Kingston', 'Winnin', 'Inconsciente', 'Bangkok', 'Laying', 'Hu', 'Chambord', 'Novice', 'bite Sache', 'rue Saint-Vincent', 'Parfumés', 'Quand je vois', 'Valentine', 'Tuez', 'Connaître', 'Chimie', 'Créole', 'T.I.G', 'cap Ferret', 'Gelé', "J'ai des amis", 'RER', 'Aucun grief Personne', 'Instrumental Bridge', 'Douce France', 'Pentagon', 'Puis j’', 'Rover', 'mer Nous', 't’aimerai', 'Limit', 'dentelles de Calais Que', 'Patagonie', 'I promise I', 'Hors-Série', '\x93', 'Démolir', 'mer Mais Anna', "J'ai rêvé", 'Kiabi', 'Kamu', 'Emilio', 'Schick', 'We will', 'Rébecca', 'Mouille', 'jardin Pas', 'Habitué', 'Complexes', 'Daroussin', 'Fleuve', 'Time Square', 'G.A.V.', 'tour Alice', 'rue Nion', 'Fontaineau', 'Assez', 'Paris Danse', 'rue J’', 'Concédons', 'Tout', 'Rom1', 'Puzzle', 'Héritier', 'Col tempo', 'Consciencieux', 'Maine', 'Fort Lauderdale', 'Dafunkamanau', "Bois Sauvages d'Évry Pyramides", 'Pensaré', 'Jamel', 'Ich Ich', "J'kiffe ma life", 'rue du Havre Marie sirène', 'M.A:2', 'Crucifié', 'Surveille', 'Enta', 'Kille', 'Señorita', 'Oursoul', "J'tentais d'écrire les seconds", 'Marbœuf je me gonflais', 'Blackis', '\u200b\u200bles', 'Bong', 'Importantes', 'Junge', 'LA', 'Les bougies les cadeaux et les textos', 'Mbali', 'Riches', 'Iblis', 'Smaïn', 'Donnant', 'Babygrand', 'Ici Sevran', 'Twinky', "J'ai pas de secret", 'Daytime', 'Sapajou', 'Neonlicht', 'Donc attends', 'Boomin', 'Woohoohoo', 'océan Adieu Paris', 'Petite mama', 'R.A.P Pourrait', 'RER A', 'Nécessaire', 'This time I', 'Comores jusqu’', 'love Tomber', "J'déconne", "J'ai essayé la science et la conscience", 'conçois Est', 'Behold', 'Skofreu', 'Ai', 'Connu', 'Abou Debeing', "L'équilibre", 'Iggy', 'Espère', 'Sort', 'Flop', 'Django', 'Folon Ceux', 'Balade', 'Rs3', 'Waves', 'Devra', "J'ai juré", 'Deliveroo', 'Égaré', 'La prima volta', 'oublier De Luxor', 'Nutella Papa', 'Bazin', 'Coupe-moi', 'French Cash', 'Venir', 'Sous la pluie  ', 'Frigorigènes', 'Menacent', 'Apportent', 'Picter', 'On', 'Tuer', 'qu’tu vois', "J'ai mes yeux dans tes yeux", 'Ceylan', 'Les srab', 'Generally', 'Gildaaaaaas', 'Neochrome Hall Stars', 'Tertre', 'Deauville', 'Because', 'Ghayli', 'Où Voulez-vous Que', "J'ai le", 'Seine', "J'avais vu Pampelune", 'Enlacée', 'Tarter', "J'ai tué Raspoutine", 'Columbo', 'Choisis', "Val d'Oise", 'Chief Keef', 'Babys', 'Berlin Berlin', 'Bois !', 'Cool', 'Cha', 'Ressort', 'Espagnole', 'Chicks', "J'fumais ma zetla", 'Darsh', 'Magyd', "J'ai trahi", 'Lyon Vaulx-en-velin', 'Steuplait', 'Porte l’', 'Ludo', 'Gué fa-la-la la-la-lir Nous', 'Vrai Sûr', 'Lalalalalala', 'Kerouac', 'Block', 'Ca rigole', 'Nord Yuri', 'Philly', 'Monte chez', 'Fuck l’', 'Éloigne', 'Lambos', 'Mamounia', 'BO Langage', 'Cac 40', 'Chevy', 'Issu', 'Ducs Normands', 'Harlem Pose ton', 'Mephisto', 'Ferrara', 'Antigua', 'Cigognes', 'Gnocchi', 'Saint-Pierre', 'avenue Montaigne', 'Goose', 'Holly', 'Serrée', 'Confiance', 'Shorty', 'Boulevard', 'Paris  Salut', "J'ai des Féfés", 'Pointes', 'Ob', 'Uniques', "pers' Mama", 'Que Lulu', 'Debout', "J'ai tué et j'ai vu mourir Je mourrai", 'Hier', 'Façonnés', 'Sifflera', 'montagne Marchait', 'Sehnsucht', 'Shahrane', 'Cagoulé', 'Ka', "mer Qu'", 'Milk', 'Parisiennes', 'fort Est', "d'Évry", "J'ai Amaury", 'Orchestres', 'Bic', 'World Trade Center Réveillé', 'Traînés', 'Krylon', 'Capitaine Jack', 'M.A.S.S.', 'Lalalalalalala', 'forêts', 'Jardin du Luxembourg Où tu vis', 'Armada', "J'ai pas voulu", "A Bell'", 'Ohhohh', ...

# %% [markdown]
# Difference avec Glaff
# ---------------------------------------------------------------------

# %%
test = [mot for mot in loc if mot.lower() not in f2]
print(len(test))
# Out:
# 50591

# %%
i = set(loc).difference(test)
print(i)
# Out:
# {'Menton', 'Inquiétant', 'Suceuses', 'Croiser', 'Fredonne', 'Ter', 'Formaté', 'Infiltre', 'Barcelonais', 'Macadam', 'Orange', 'Lancinantes', 'Infiltrez', 'Tropique', 'Largos', 'Ndombolo', 'Congolais', 'Chypre', 'Étend', 'Dégoûtés', 'Enferme', 'Connemara', 'Directeur', 'Passeport', 'Infortuné', 'Dessinent', 'Faisanderie', 'Planquée', 'Dégustons', 'Chelou', 'Passée', 'Pe', 'Congrès', 'Change', 'Jardin', 'Zumba', 'Évacue', 'Coca', 'Descendez', 'Discernes', 'Bourgogne', 'Bonasses', 'Défense', 'Arriver', 'Atlantique', 'Angleterre', 'Este', 'Chartres', 'Buffalo', 'Payol', 'Limonade', 'Italiennes', 'Pruneaux', 'Nanti', 'Penchée', 'Lové', 'Poussières', 'Briquer', 'Cacao', 'Mai', 'Bondir', 'Tours', 'Fixé', 'Essuyez', 'Cogite', 'Plouf', 'Nordiques', 'Parlons', 'Chés', 'Resserres', 'Derricks', 'Renait', 'Borgnes', 'Craignent', 'Posée', 'Croise', 'Annoncent', 'Délinquant', 'Celle', 'Allergique', 'Singeant', 'Gagneront', 'Parme', 'Pénètre', 'Flaques', 'Qui', 'Ile', 'Mignon', 'Étang', 'Défierai', 'Résisté', 'Rein', 'Dessus', 'Chorus', 'Gelé', 'Séchez', 'Invalides', 'Distance', 'Main', 'Liège', 'Farine', 'Criquet', 'Côte', 'Grossir', 'Fâché', 'Margoton', 'Tourbillon', 'Cargaison', 'Funky', 'Vivant', 'Allumant', 'Marquises', 'Arbalète', 'Arrivera', 'Menait', 'Chien', 'Grimpe', 'Gigote', 'Noire', 'Boulonnais', 'Besognées', 'Allongées', 'Gauloise', 'Parle', 'Brandiront', 'Abracadabrant', 'Arrêtons', 'Creusez', 'Maharajas', 'Épinettes', 'Diamants', 'Bandol', 'Guignol', 'Florentines', 'Père', 'Sels', 'Lima', 'Arrêtées', 'Dicte', 'Tequila', 'Confond', 'Savourez', 'Mouille', 'Put', 'Déguisant', 'Messidor', 'Terrorisés', 'Motte', 'Refera', 'Complexes', 'Neuf', 'Songhaï', 'Enfiler', 'Périphérique', 'Squatte', 'Fleuve', 'Fleuves', 'Dissolvent', 'Hissez', 'Courir', 'Coquillage', 'Nausée', 'Tajine', 'Phocéenne', 'Nains', 'Nationalisé', 'Fourre', 'Étendus', 'Babouche', 'Stalag', 'Laconique', 'Travailler', 'Promener', 'Jury', 'Cordes', 'Catch', 'Campanile', 'Perse', 'Satellisé', 'Quittez', 'Détachez', 'Soustraits', 'Dont', 'Dol', 'Port', 'Tunisiens', 'Longer', 'Enflammées', 'Wallonne', 'Grisée', 'Brodé', 'Monnaie', 'Mignonne', 'Enchaîne', 'Saine', 'Trinquons', 'Abandonnées', 'Indécence', 'Baskets', 'Colles', 'Mème', 'Tectonique', 'Cocotiers', 'Luttais', 'Building', 'Noyau', 'Menotté', 'Raser', 'Crucifié', 'Réfugie', 'Misère', 'Enta', 'Mammouth', 'Ave', 'Mentons', 'Lé', 'Mandingues', 'Tension', 'Verront', 'Infime', 'Écorchons', 'LA', 'Gironde', 'MI', 'Mu', 'Polémique', 'Perdu', 'Pensais', 'Métissé', 'Grise', 'Épiceries', 'Adossé', 'Downtown', 'Traîne', 'Donnant', 'Passons', 'Civière', 'Mangés', 'Dealé', 'Palais', 'British', 'Veste', 'Sapajou', 'Irradié', 'Rejoins', 'Galice', 'Crisser', 'Colombienne', 'Bagarrer', 'Brésil', 'Cara', 'Ivoiriens', 'Coupole', 'Coquins', 'Nécessaire', 'Laissait', 'Zamal', 'Pourrissent', 'Pute', 'Faut', 'Smic', 'Boliviano', 'Métissage', 'Appelle', 'Chienne', 'Futile', 'French', 'Permets', 'Pipez', 'Colombes', 'Laboratoire', 'Vais', 'Testé', 'Mercure', 'Lady', 'Mêler', 'Faner', 'Musulman', 'Pékin', 'Mâcon', 'Balade', 'Tiendront', 'Tâchant', 'Lapon', 'Floride', 'Baisse', 'Décrochée', 'Rechercher', 'Étouffées', 'Sereins', 'Claquer', 'Populaire', 'Emplissant', 'Tasses', 'Sucre', 'Bracelet', 'Grenelle', 'Kuduro', 'Arrives', 'Plaqués', 'Mâchonnent', 'Passage', 'Ternaire', 'Claquons', 'Venir', 'Lâcherez', 'Gens', 'Savane', 'Trempant', 'Pillé', 'Dévalent', 'Pois', 'Regardait', 'Galette', 'Assiette', 'Buis', 'Marocains', 'Zappez', 'Espace', 'Golf', 'Papé', 'Aout', 'Trappe', 'Avancez', 'Pull', 'Frileux', 'Clinquant', 'VS', 'Sniffe', 'Seine', 'Britannique', 'Perdues', 'Solitaire', 'Impitoyables', 'Sévit', 'Arrière', 'Ivoirien', 'Dinant', 'Niais', 'Enfouis', 'Tarter', 'Pêcher', 'Dodo', 'Saoulé', 'Déchirant', 'Exalter', 'Crin', 'Salut', 'Servile', 'Ressort', 'Béthune', 'Sucré', 'Fakes', 'Espagnole', 'Blafarde', 'Frileuse', 'Massages', 'Hard', 'Sut', 'Disharmonie', 'Ranges', 'Vendredi', 'Dois', 'Dictateurs', 'Ça', 'Deux', 'Gaffé', 'Présidence', ...

# %% [markdown]
# Majuscules/minuscules
# ---------------------------------------------------------------------

# %%
x =[]
for mot in test:
    if mot.lower() not in test:
        x.append(mot)  
print(len(set(x)))
ecrire_json("lieux_all_data_aprésNettoyage_sm.json",x)
# Out:
# 9724

# %%
f = set(test).difference(x)
print(f)
# Out:
# {'ber1ue', '’'}

# %%
import xml.etree.ElementTree as ET
voc_Glawi = []
tree = ET.parse("/Users/mustapha/Downloads/GLAWI_FR_work_D2015-12-26_R2016-05-18.xml")
root = tree.getroot()
for element in root:
    for child in element:
        if child.tag == "title":
            voc_Glawi.append(child.text)

# %%
ecrire_json("voc_Glawi.json", voc_Glawi)
