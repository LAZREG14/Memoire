# %%
import json

def ouvrir_json(chemin):
    f = open(chemin, encoding="utf-8")
    toto = json.load(f)
    f.close()
    return toto

def ecrire_json(chemin, contenu):
    w = open(chemin, "w", encoding="utf-8")
    w.write(json.dumps(contenu, indent=2, ensure_ascii=False))
    w.close()

# %%
import spacy
nlp_sm = spacy.load("fr_core_news_sm")
nlp_md = spacy.load("fr_core_news_md")
nlp_lg = spacy.load("fr_core_news_lg")

# %%
f1 = ouvrir_json("clean_data_echantillons/clean_echantillon2.json")
f2 = ouvrir_json("Data/voc_glaff.json")

# %%
loc_sm=[]
for texte in f1:
    try:
        doc = nlp_sm(texte)
        for entity in doc.ents:
            if entity.label_ =="LOC":
                loc_sm.append(entity.text)
    except:
        pass
print("lieux trouvés par le modèle small : ",len(set(loc_sm)))
print(set(loc_sm))
print()
print()

tri_1 = [mot for mot in loc_sm if mot not in f2]
test1 = [mot for mot in loc_sm if mot in f2]
print("nombre lieux qui ne se trouvent pas dans le Glaff : ", len(set(tri_1)))
print(set(tri_1))
print()
print(set(test1))
print()

tri_2 = [mot for mot in tri_1 if mot.lower() not in f2]
test2 = [mot for mot in tri_1 if mot.lower() in f2]
print("nombre lieux en miniscules qui ne se trouvent pas dans le Glaff : ",len(set(tri_2)))
print(set(tri_2))
print()
print(set(test2))
print()



tri_3 =[mot for mot in tri_2 if mot.lower() not in tri_2] 
test3 =set(tri_2).difference(tri_3)
print("nombre de lieux obtenu dans la liste finale : ", len(set(tri_3)))
print(set(tri_3))
print()
print(set(test3))
# Out:
# lieux trouvés par le modèle small :  2274
# {'Effronté', 'Obscure', 'Plaise', 'Laissons', 'Indes', 'Balisent', 'Grossiste', 'Buvons', 'Garges-Les-Gonesses', 'Perdre', 'Accepta', 'Striée', 'Systématique', 'Et Margot', 'Sales manières', 'Your', 'Excuse', 'Bilan', 'Belleville', 'v’', 'Pyrex', 'Délavées', 'Qu´est', 'Montrant', 'Anges', 'Pleurez', 'Traîtres', "see'", 'Pont', 'Cliché', 'Résonnent', 'Saint-Cloud', 'Pardonne', 'Tourcoing', 'Madone', 'royaume des Hommes Soudain je vois', 'These', 'Pérou', "Qu'un air d'", 'Intoxiqués', 'Géorgie', 'Au', 'Akkad', 'QI sage Où', 'Boivent', 'pont des Arts', 'Thèbes', "J'ai beau", 'Illuminée', 'Hindou', 'Monténégro', 'Golfe de Naples', 'Occupe', 'Mont’ m’', 'London', 'Garde', 'mer Libre', 'Toulon', 'Montrez', 'Marny', "Levi'", 'Aspire', 'rue Davso', 'Camargue', 'Melopheelo', 'Certain', 'Marie-janne', 'Afin', 'Y', "J'ai troqué", 'Eh', 'Porto', 'Quand viendras', 'Cousin', 'Monté', 'marée', 'Pays Basque', 'Basique', 'Porter', 'Taj Mahal', 'Propagande', 'Anticlérical', 'Burkina', 'Raccourcissent', 'Tolbiac', 'Clamart', 'Rat Luciano', 'Caché', 'Rouge', 'Bénie', 'Poussées', 'Prada', 'Atada', 'Ivre', 'Seine', 'jean’', 'Apollinaire A', 'Séville', 'Les', 'Kan', 'Bastia', "Ch'", 'Deuch', 'Allongés', 'Séché', 'Badé', 'Jupiter', 'Abruzzes', 'chacals Pâle', 'Excellent', 'Brasse', 'lointaines Abattus', 'BN', 'C.D', 'Preuve', 'Hiroshima', 'Robbie', 'Kanaky', "caverne d'Ali", 'Lutem', 'Honduras', 'Casino Secrètement', "La lune c'est le soleil des loups", 'Méfie', 'Nuée', 'Bang', 'Mougeotte', "J'ai\u2005", 'Pigalle Y', 'Premier Quand t’auras l’', 'Faisais', 'Novotel Y', 'Tarbes', 'Bangkok', 'Dag', 'Lovers', 'Tour', 'Dahu', 'Mettez', 'République', 'Déifiant', 'Rejoins', "J'ai pas d'haine", 'Champ de navets Sans grandes pom-', 'Hortense', 'Deviens', 'A Saint-Sulpice', 'j´le', 'Éteignez', 'Vends', 'Aix', 'El Paso', 'Stocks', 'En', 'Sévèrement', 'Grandir', 'Saint-Germain-des-Prés', 'branches A', 'Sodi', 'Comme', 'Pousse', 'Pin', 'cap Du dédain', 'Mollah', 'Rue du Vieux Colombier', 'A l’hôpital Saint-Louis', 'Cordillère des Andes', 'Comptent', 'Combine', 'Besoin', 'New York City', 'Essuyez', 'Va', 'Préparez', 'Mogador', 'Tracer', 'Chope', 'Naples', '"City', 'rue Ensoleill', 'Pèze', 'Maine', 'Sud-Est', 'Medhi', 'Racontez', 'Ça', 'Pareil', 'Marbœuf je me gonflais', 'Mourir', 'Mal', 'Mesquins', 'Les Affranchis', 'A saut', 'Olympia', 'Bolivie', 'Stupides', 'quartier C’', "J'crois", 'Gavroche', 'Eh ouais', 'Woody', 'Ninette', 'Lavomatic', 'Danse', 'Non Jack FrodjoMahjong', 'Perriers', 'Trahi', 'La\u2005', 'Chantez', 'Pochtron', 'Angers', 'Fréjus', 'Quartiers', 'Finiront', "J'ai connu", 'I', 'Sacrée', 'Formé', 'Coulent', 'Autour', 'Ricains', 'Puis', 'Manouche', 'Rio', 'QI', 'Rizla', 'Margot', 'Profondes racines', 'Afrique Autour', 'Embrasse', 'Liffekès', 'Bonheur', 'Panthéon Rue Descartes', 'Anvers', 'Fresh', 'Le Picon', 'Dijon', 'Marinette', 'Gentilshommes', 'vallée S’', 'A Longwy', 'Dupont', 'Patagonie', 'Villefranche', 'Pow Wow', 'Parisien Libéré Pense', "Alhambra d'Bordeaux", 'Disneyland', 'Fraternité', 'Comprends', 'matin Montparnasse', 'Canique', 'Peintures', 'Marylou', 'Maghreb', 'Finira', 'Tri-Nitro-Toluène', 'Chemise', 'Heureusement', 'Rosalie', 'Légère', 'Mali', 'Blonds', 'Authentique', 'Attends', 'Finlande', 'Lille', 'Chinois', 'Moscou', 'de Lille', 'Animateur', 'Petit Scarabée', 'Gaulois', 'India', 'moral Sache', 'Creusant', 'Saturne', 'Naples A', 'Slamalekoum', 'Fresnes', 'Renaissance', 'Iconoclastes', 'Ficelles Tire', 'Poupée Barbie', 'Voltige', 'c\x9cur', 'Hasta', 'Bénites', 'Moi', 'Berne', 'piste Du', 'Libérée', 'Thiais', 'Bois', 'he’', 'Lyriciste', 'Mexique', 'XXX Conçu', 'Torse', 'Afrique Traité', 'moineau A', 'Montélimar', 'Couleur', 'Chouette', 'B.H.L', 'Sympa', 'Sereine', 'Montent', 'Aïcha', 'Défends', 'Malone', 'le Zénith', 'La Seine', 'Gare', 'Brooklyn New York', 'Prisons', 'Basta', 'Virginie', 'Nanana', 'Parcours', 'Rebelle', 'Petite fille de novembre Si blanche dans la nuit de cendre Trouble', 'Courrut', 'Loulou', 'Cible', 'May', 'Quel' ...
# nombre lieux qui ne se trouvent pas dans le Glaff :  2217
# {'Effronté', 'Obscure', 'Plaise', 'Laissons', 'Indes', 'Balisent', 'Grossiste', 'Buvons', 'Garges-Les-Gonesses', 'Perdre', 'Accepta', 'Striée', 'Systématique', 'Et Margot', 'Sales manières', 'Your', 'Excuse', 'Bilan', 'Belleville', 'v’', 'Pyrex', 'Délavées', 'Qu´est', 'Montrant', 'Anges', 'Pleurez', 'Traîtres', "see'", 'Pont', 'Cliché', 'Résonnent', 'Saint-Cloud', 'Pardonne', 'Tourcoing', 'Madone', 'royaume des Hommes Soudain je vois', 'These', 'Pérou', "Qu'un air d'", 'Intoxiqués', 'Géorgie', 'Au', 'Akkad', 'QI sage Où', 'Boivent', 'pont des Arts', 'Thèbes', "J'ai beau", 'Illuminée', 'Hindou', 'Monténégro', 'Golfe de Naples', 'Occupe', 'Mont’ m’', 'London', 'Garde', 'mer Libre', 'Toulon', 'Montrez', 'Marny', "Levi'", 'Aspire', 'rue Davso', 'Camargue', 'Melopheelo', 'Certain', 'Marie-janne', 'Afin', 'Y', "J'ai troqué", 'Eh', 'Quand viendras', 'Cousin', 'Monté', 'marée', 'Pays Basque', 'Basique', 'Porter', 'Taj Mahal', 'Propagande', 'Anticlérical', 'Burkina', 'Raccourcissent', 'Tolbiac', 'Clamart', 'Rat Luciano', 'Caché', 'Rouge', 'Bénie', 'Poussées', 'Prada', 'Atada', 'Ivre', 'Seine', 'jean’', 'Apollinaire A', 'Séville', 'Les', 'Kan', 'Bastia', "Ch'", 'Deuch', 'Allongés', 'Séché', 'Badé', 'Jupiter', 'chacals Pâle', 'Excellent', 'Brasse', 'lointaines Abattus', 'BN', 'C.D', 'Preuve', 'Hiroshima', 'Robbie', 'Kanaky', "caverne d'Ali", 'Lutem', 'Honduras', 'Casino Secrètement', "La lune c'est le soleil des loups", 'Méfie', 'Nuée', 'Bang', 'Mougeotte', "J'ai\u2005", 'Pigalle Y', 'Premier Quand t’auras l’', 'Faisais', 'Novotel Y', 'Tarbes', 'Bangkok', 'Dag', 'Lovers', 'Dahu', 'Mettez', 'République', 'Déifiant', 'Rejoins', "J'ai pas d'haine", 'Champ de navets Sans grandes pom-', 'Hortense', 'Deviens', 'A Saint-Sulpice', 'j´le', 'Éteignez', 'Vends', 'Aix', 'El Paso', 'Stocks', 'En', 'Sévèrement', 'Grandir', 'Saint-Germain-des-Prés', 'branches A', 'Sodi', 'Comme', 'Pousse', 'Pin', 'cap Du dédain', 'Mollah', 'Rue du Vieux Colombier', 'A l’hôpital Saint-Louis', 'Cordillère des Andes', 'Comptent', 'Combine', 'Besoin', 'New York City', 'Essuyez', 'Va', 'Préparez', 'Mogador', 'Tracer', 'Chope', 'Naples', '"City', 'rue Ensoleill', 'Pèze', 'Maine', 'Sud-Est', 'Medhi', 'Racontez', 'Ça', 'Pareil', 'Marbœuf je me gonflais', 'Mourir', 'Mal', 'Mesquins', 'Les Affranchis', 'A saut', 'Olympia', 'Bolivie', 'Stupides', 'quartier C’', "J'crois", 'Gavroche', 'Eh ouais', 'Woody', 'Ninette', 'Lavomatic', 'Danse', 'Non Jack FrodjoMahjong', 'Perriers', 'Trahi', 'La\u2005', 'Chantez', 'Pochtron', 'Angers', 'Fréjus', 'Quartiers', 'Finiront', "J'ai connu", 'I', 'Sacrée', 'Formé', 'Coulent', 'Autour', 'Puis', 'Manouche', 'Rio', 'Rizla', 'Margot', 'Profondes racines', 'Afrique Autour', 'Embrasse', 'Liffekès', 'Bonheur', 'Panthéon Rue Descartes', 'Anvers', 'Fresh', 'Le Picon', 'Dijon', 'Marinette', 'Gentilshommes', 'vallée S’', 'A Longwy', 'Dupont', 'Patagonie', 'Villefranche', 'Pow Wow', 'Parisien Libéré Pense', "Alhambra d'Bordeaux", 'Disneyland', 'Fraternité', 'Comprends', 'matin Montparnasse', 'Canique', 'Peintures', 'Marylou', 'Maghreb', 'Finira', 'Tri-Nitro-Toluène', 'Chemise', 'Heureusement', 'Rosalie', 'Légère', 'Mali', 'Blonds', 'Authentique', 'Attends', 'Finlande', 'Lille', 'Chinois', 'Moscou', 'de Lille', 'Animateur', 'Petit Scarabée', 'Gaulois', 'India', 'moral Sache', 'Creusant', 'Saturne', 'Naples A', 'Slamalekoum', 'Fresnes', 'Iconoclastes', 'Ficelles Tire', 'Poupée Barbie', 'Voltige', 'c\x9cur', 'Hasta', 'Bénites', 'Moi', 'Berne', 'piste Du', 'Libérée', 'Thiais', 'Bois', 'he’', 'Lyriciste', 'Mexique', 'XXX Conçu', 'Torse', 'Afrique Traité', 'moineau A', 'Montélimar', 'Couleur', 'B.H.L', 'Sympa', 'Sereine', 'Montent', 'Aïcha', 'Défends', 'Malone', 'le Zénith', 'La Seine', 'Gare', 'Brooklyn New York', 'Prisons', 'Basta', 'Virginie', 'Nanana', 'Parcours', 'Rebelle', 'Petite fille de novembre Si blanche dans la nuit de cendre Trouble', 'Courrut', 'Loulou', 'Cible', 'May', 'Quel', 'Quand viendras-tu', 'Donner', 'Angleterre', 'Dalila', 'Cher', 'Où t’', ...
#
# {'BO', 'Allemand', 'Suisse', 'Corse', 'Belge', 'Bon', 'Cologne', 'Lucien', 'Tour', 'Est', 'Parisienne', 'Indien', 'Noire', 'Turc', 'N', 'Cancer', 'Ricains', 'MC', 'Abruzzes', 'Porto', 'Égyptiens', 'Aryenne', 'État', 'Basques', 'Père', 'Mélusine', 'QI', 'Africain', 'C', 'G', 'Chouette', 'Montana', 'L', 'Aïd', 'Meccano', 'Germaine', 'Gauloises', 'Blacks', 'Babylone', 'KO', 'Eucharistie', 'Panthéon', 'Balance', 'Thaïs', 'Crie', 'Juste', 'VO', 'Bengale', 'B', 'Lorraine', 'Indiens', 'Argentine', 'Pontoise', 'Renaissance', 'Alsaciens', 'Philistins', 'Phocéens'}
# nombre lieux en miniscules qui ne se trouvent pas dans le Glaff :  1206
# {'port Blanche', 'heure A', 'Grèce', 'Nord-Est Solaar', 'Bretagne', 'Browning A', 'ligne Maintenant la Commission', 'Eternel', 'With Mrs', 'Treets', 'Garges-Les-Gonesses', 'Moi je suis le', 'Moi j’', 'Rue de la Soif', 'Avalon', '? L', 'Tout’', 'Pondichéry', 'Sales manières', 'Et Margot', 'Le Renard', 'Your', 'Villeneuve-Saint-Georges', 'Epicure', 'Égypte', 'Lorque', 'forêts', 'Knicks', 'Que fientes de pigeons', 'Lewis Carrol', 'écho massif Déguisé', 'Laintenanmic', 'tour A', 'Belleville', 'rue des Saules Rue Saint-Vincent', 'v’', 'Pyrex', "J'dirais", 'Cavan', 'Qu´est', 'Fort Greene', "l'Afrique", 'Neuilly Dans', 'Nicaragua', 'Saintes-Maries', 'golfe du Lion Trempe', 'La Jeanne', 'Mesdames', 'Ayato', 'coudes Leur', 'Sévéso', 'Palestine', 'ligne Maginot', 'Mais t’', 'Krivine', "see'", 'l’', 'Jeanne Son', 'Bettancourt', 'Dolto', 'Saint-Cloud', 'Tourcoing', 'Pleure pas Souris', 'Sentenza', 'Abyssinie', "Sainte-Mad'lein’", 'Posse Idéal', 'parking A', 'royaume des Hommes Soudain je vois', 'These', 'Dins', 'Tbilissi', 'Lelay', 'Hôtel de Russie', 'Pérou', 'La Li', 'Nante', "Qu'un air d'", 'Kanterbrau Germaine', 'Géorgie', 'improviste Vole', "J'ai dit", 'Akkad', 'Du côté Est', 'Allemagne', 'Ghana Poètes', 'QI sage Où', 'Tape Malone', 'Eux', 'Débilos', 'Istres', "J'ai jamais", 'fumée', 'Holiday Inn', 'Fabien', 'Saint-Michel', 'pont des Arts', 'Pfff', 'cieux A', 'Thèbes', "J'ai beau", 'Parc Montsouris Après', 'Monténégro', 'Men', 'Reïf', "J'ai ma petite", 'Vercors', 'Tchad Natif de Dakar', 'stade On', 'Golfe de Naples', 'Ceylan', 'Clichy Son', 'pont des Arts  ', 'Danemark', 'Une escapade improvisée Nous sommes', 'Que\u2005', 'Saint-Tropez', 'année', 'Mont’ m’', 'B.Boy', 'Bric-à-brac', 'Malek', 'Irlande', 'London', 'vis Emporte', 'New Balance', 'pas de Camaret', 'Longnon', 'Tolède', 'Saint-Esprit', 'P38', 'Lachaise', 'Indochine', 'mer Libre', 'Greta Pourquoi', 'Toulon', "'Vec", 'Celle de ma chanson Elle', 'nez Est', 'Dublin City', 'A la Bastille', 'Tcherno', 'Suzon', 'Marny', "Duras J'", 'Emaciés', "Levi'", 'an Eméchés', 'Avoriaz', 'forêt de', 'rue Davso', 'bar A', 'vieux Franco', "J'ai croisé des hommes", 'Melopheelo', 'l´au', 'Marie-janne', 'Afin', "J'ai dessiné", 'Bercy', 'Dublin', 'Le bitume', "J'ai troqué", 'Eh', 'D?s', 'Ness', 'Prodigal Sunn:] Yo', 'plumard Renard', 'Fichu Souleiado', 'Dare', 'Je l’', "J'ai pas aimé", 'Elsa', 'Chtbaou', "J'ai laissé des bouts", 'Capoue', 'Pactole Y', 'Quand viendras', 'marée', 'Hanoï', 'Chambéry Mais Jé', 'Pays Basque', 'fi France', 'Fleury', 'Apprinds', 'Armani', 'Hélloïs', 'Californie', 'La Triumph', 'Seul dans ma chambre', 'Tyson', 'I wanted', 'Pigalle', 'Loch Ness', 'Selecto', 'Taj Mahal', 'Byzance', 'Saint-Denis', "Corne d'Aurochs", 'Movie', 'Cap Canaveral', 'Stimorol', 'Vilnius', 'Burkina', 'St Vincent', 'Vallée des Rois', 'J´', 'Serre-moi', 'Gendes', 'Tolbiac', 'Cimetière Aguichant', 'Häagen', 'Molly', 'Clamart', 'Rat Luciano', 'El Diablo', 'sourires Paranoïaques', 'Rolex', 'Atada', 'Prada', 'Reno', 'Medellin', 'Maradona', 'blas?s', 'Arabie', 'jean’', 'Apollinaire A', 'Nil', 'Amsterdam', "J'te montrerai mon", 'Cythère', 'Séville', 'Derrièr', 'Fort Green', 'passerelle’', 'Bastia', "Ch'", 'Amoco', 'Submarina', 'Rue du Vieux Colombier Ton fantôme', 'Deuch', "J'ai vu des bateaux", 'B.D.', 'Washington', 'Avignon', 'Jupiter', 'chacals Pâle', 'M.I.C.', "Kro'", 'Issara', 'Olé', 'Créteil', 'lointaines Abattus', 'Atlanta', 'BN', 'C.D', "Jardin d'Eden", 'Macumba', 'Hiroshima', 'Robbie', 'Baptistain', 'Ouarzazate', 'Palerme', 'Kanaky', 'Falù', 'Votre honneur', 'Yo', 'Ravachol', 'Christ(e', "caverne d'Ali", 'Lutem', 'Manhattan', "J'ai gravé profond", 'Honduras', 'Babel Laquelle', 'Nirvana Ensorcelé', 'Lavilliers', 'Revolucion', 'Casino Secrètement', 'That', 'Sugar Hill', "La lune c'est le soleil des loups", 'I veyot', 'Vänd', 'Taïwan', 'Telecom', 'Sri Lanka Sikh', 'Mougeotte', "J'ai\u2005", 'Europe', 'Tacchini', 'Bullshit', 'Pakistan', 'Those', "Rue d'Charonne", 'Lens', 'P 38', 'Que t’', 'Mongolie',  ...
#
# {'Approchez', 'Géantes', 'Effronté', 'Obscure', 'Couchés', 'Une', 'Plaise', 'Enfoiré', 'Symbole', 'Ajoutez', 'Laissons', 'Immonde', 'Balisent', 'Grossiste', 'Buvons', 'Spirituel', 'Indes', 'Sais', 'Perdre', 'Murmure', 'Damas', 'Mieux', 'Bonnie', 'Rait', 'Mademoiselle', 'Gens', 'Reggae', 'Rital', 'Accepta', 'Striée', 'Tours', 'Systématique', 'Mentons', 'Pareille', 'Regarder', 'Gorille', 'Chanta', 'Celles', 'Fastoche', 'Valence', 'Excuse', 'Graines', 'Désolé', 'Bilan', 'Blondin', 'Con', 'Délavées', 'Soufflé', 'Montrant', 'Rabane', 'Choisir', 'Anges', 'Mars', 'Lier', 'Vois', 'Pleurez', 'Compte', 'Lulu', 'Traîtres', 'Sire', 'Pont', 'Cliché', 'Reviendront', 'Résonnent', 'Féria', 'Pardonne', 'Bac', 'Révélateur', 'Pique', 'Reste', 'Ramassée', 'Distance', 'Don', 'Madone', 'Machin', 'Hommes', 'Croix', 'Marches', 'Intoxiqués', 'Notaires', 'Obligés', 'Dés', 'Au', 'Arbi', 'Souviens', 'Enamourée', 'Boivent', 'Sud', 'Courront', 'Trouble', 'Décolorées', 'Moins', 'Refrain', 'Ne', 'Ivrogne', 'Cube', 'Illuminée', 'Hindou', 'Flagada', 'Plantez', 'Fier', 'Rend', 'Précieuses', 'Simplement', 'Taciturne', 'Pourrais', 'Narbonne', 'Voie', 'Once', 'Contrôlées', 'Margoton', 'Tourne', 'Occupe', 'Connemara', 'Mythiques', 'Capturent', 'Mais', 'Souvenir', 'Oublie', 'Village', 'Plein', 'Perles', 'Panama', 'Cortège', 'Garde', 'Traversé', 'Montrez', 'Quimper', 'Murmura', 'Sparte', 'Coule', 'Baby', 'Animales', 'Aspire', 'Son', 'Auprès', 'Libertaire', 'Camargue', 'Certain', 'Y', "N'", 'Lisette', 'Valider', 'Aimes', 'Jugeant', 'Connais', 'Déchanter', 'Opéra', 'Gaîté', 'Prusse', 'Cousin', 'Monté', 'Attendez', 'Alignés', 'Réquisition', 'Apaches', 'Iront', 'Vaux', 'Bingo', 'Cool', 'Lampistes', 'Errer', 'Basique', 'Déesse', 'Porter', 'Stick', 'Livré', 'Murmurent', 'Concédons', 'Princesse', 'Enfants', 'Propagande', 'Complexe', 'Bambou', 'Berlin', 'Auvergne', 'Anticlérical', 'Méditerranéenne', 'Désiré', 'Délaisse', 'Finie', 'Raccourcissent', 'Opaque', 'Seul', 'Bastilles', 'Dois', 'Bicêtre', 'Bravo', 'Taf', 'Caché', 'Moineau', 'Bénie', 'Poussées', 'Écœuré', 'Misogynie', 'Vatican', 'Ivre', 'Rouge', 'Jalouse', 'Redescends', 'Seine', 'Dallas', 'Libre', 'Frénétique', 'Coudes', 'Les', 'Avez', 'Kan', 'Allongés', 'Saisi', 'Présumais', 'Brandy', 'Vivre', 'Séché', 'Badé', 'Cadavre', 'Toi', 'Sache', 'Excellent', 'Bière', 'Assis', 'Pantin', 'Fatma', 'Grande', 'Brasse', 'Zigzag', 'Viens', 'Tableau', 'Volant', 'Preuve', 'Graff', 'Commencer', 'Quels', 'Es', 'Cliquez', 'Larmes', 'Inutile', 'Paparazzis', 'Reverra', 'Parole', 'Berçant', 'Resto', 'Voilà', 'Terminé', 'Volez', 'Quelque', 'Soumise', 'Onques', 'Nuée', 'Croire', 'Méfie', 'Bang', 'Tectonique', 'Miami', 'Manille', 'Sarcelles', 'Prés', 'Bonjour', 'Titi', 'Belges', 'Pas', 'Partagés', 'Faisais', 'Monoï', 'Chanter', 'Chouf', 'Pernod', 'Monaco', 'Brûlent', 'Puisse', 'Fallait', 'Privées', 'Tendres', 'Dahu', 'Mettez', 'République', 'Val', 'Perçois', 'Déifiant', 'Bagarres', 'Avais', 'Rejoins', 'Suffocante', 'Gangster', 'Travail', 'Deviens', 'Compté', 'Brésil', 'Rendu', 'Telle', 'Direct', 'Trouverais', 'Éteignez', 'Vends', 'Stocks', 'En', 'Tarentelles', 'Sévèrement', 'Maman', 'Très', 'Grandir', 'Pénétrer', 'Supercherie', 'Tombés', 'Funk', 'Comme', 'Pousse', 'Crois', 'Pin', 'Astique', 'Mai', 'Papier', 'Blanche', 'Boit', 'Lin', 'Condamné', 'Mollah', 'Laissa', 'Rendez', 'Croque', 'Comptent', 'Suivit', 'Vienne', 'Souvenez', 'Combine', 'Besoin', 'Sceaux', 'Veuve', 'Si', 'Sorbonne', 'Faites', 'Essuyez', 'Deux', 'Va', 'Neuf', 'Dis', 'Préparez', 'Laver', 'Exploitées', 'Raconte', 'Tracer', 'Chope', 'Tendu', 'Cause', 'Sobre', 'Électrolyse', 'Pèze', 'Landerneau', 'Incontinent', 'Sous', 'Racontez', 'Presque', 'Lorsque', 'Pastis', 'Foutez', 'Soixante', 'Gratter', 'Sentimentale', 'Pareil', 'Ternaire', 'Mourir', 'Renverse', 'Para', 'Certes', 'Mal', 'Fit', 'Mesquins', 'Danger', 'Sentinelle', 'Pensais', 'Affirmatif', 'Darjeeling', 'Longe', 'Bougre', 'Stupides', 'Abjurant', 'Croisant', 'Méditerranée', 'Danse', 'Bande', 'Sues', 'Regardez', 'Funky', 'Nice' ...
#
# nombre de lieux obtenu dans la liste finale :  1158
# {'port Blanche', 'heure A', 'Grèce', 'Nord-Est Solaar', 'Browning A', 'ligne Maintenant la Commission', 'Eternel', 'With Mrs', 'Treets', 'Garges-Les-Gonesses', 'Moi je suis le', 'Moi j’', 'Rue de la Soif', 'Avalon', '? L', 'Tout’', 'Pondichéry', 'Sales manières', 'Et Margot', 'Le Renard', 'Your', 'Villeneuve-Saint-Georges', 'Epicure', 'Égypte', 'Lorque', 'Knicks', 'Que fientes de pigeons', 'Lewis Carrol', 'écho massif Déguisé', 'Laintenanmic', 'tour A', 'Belleville', 'rue des Saules Rue Saint-Vincent', 'Pyrex', "J'dirais", 'Cavan', 'Qu´est', 'Fort Greene', "l'Afrique", 'Neuilly Dans', 'Nicaragua', 'Saintes-Maries', 'golfe du Lion Trempe', 'La Jeanne', 'Mesdames', 'Ayato', 'coudes Leur', 'Sévéso', 'Palestine', 'ligne Maginot', 'Mais t’', 'Krivine', 'Jeanne Son', 'Bettancourt', 'Dolto', 'Saint-Cloud', 'Tourcoing', 'Pleure pas Souris', 'Sentenza', 'Abyssinie', "Sainte-Mad'lein’", 'Posse Idéal', 'parking A', 'royaume des Hommes Soudain je vois', 'These', 'Dins', 'Tbilissi', 'Lelay', 'Hôtel de Russie', 'Pérou', 'La Li', 'Nante', "Qu'un air d'", 'Kanterbrau Germaine', 'Géorgie', 'improviste Vole', "J'ai dit", 'Akkad', 'Du côté Est', 'Allemagne', 'Ghana Poètes', 'QI sage Où', 'Tape Malone', 'Eux', 'Débilos', 'Istres', "J'ai jamais", 'Holiday Inn', 'Fabien', 'Saint-Michel', 'pont des Arts', 'Pfff', 'cieux A', 'Thèbes', "J'ai beau", 'Parc Montsouris Après', 'Monténégro', 'Men', 'Reïf', "J'ai ma petite", 'Vercors', 'Tchad Natif de Dakar', 'stade On', 'Golfe de Naples', 'Ceylan', 'Clichy Son', 'pont des Arts  ', 'Danemark', 'Une escapade improvisée Nous sommes', 'Que\u2005', 'Saint-Tropez', 'Mont’ m’', 'B.Boy', 'Bric-à-brac', 'Malek', 'Irlande', 'London', 'vis Emporte', 'New Balance', 'pas de Camaret', 'Longnon', 'Tolède', 'Saint-Esprit', 'P38', 'Lachaise', 'Indochine', 'mer Libre', 'Greta Pourquoi', 'Toulon', "'Vec", 'Celle de ma chanson Elle', 'nez Est', 'Dublin City', 'A la Bastille', 'Tcherno', 'Suzon', 'Marny', "Duras J'", 'Emaciés', "Levi'", 'an Eméchés', 'Avoriaz', 'rue Davso', 'bar A', 'vieux Franco', "J'ai croisé des hommes", 'Melopheelo', 'Marie-janne', 'Afin', "J'ai dessiné", 'Bercy', 'Dublin', 'Le bitume', "J'ai troqué", 'Eh', 'D?s', 'Ness', 'Prodigal Sunn:] Yo', 'plumard Renard', 'Fichu Souleiado', 'Dare', 'Je l’', "J'ai pas aimé", 'Elsa', 'Chtbaou', "J'ai laissé des bouts", 'Capoue', 'Pactole Y', 'Quand viendras', 'Hanoï', 'Chambéry Mais Jé', 'Pays Basque', 'fi France', 'Fleury', 'Apprinds', 'Armani', 'Hélloïs', 'Californie', 'La Triumph', 'Seul dans ma chambre', 'Tyson', 'I wanted', 'Pigalle', 'Loch Ness', 'Selecto', 'Taj Mahal', 'Byzance', 'Saint-Denis', "Corne d'Aurochs", 'Movie', 'Cap Canaveral', 'Stimorol', 'Vilnius', 'Burkina', 'St Vincent', 'Vallée des Rois', 'J´', 'Serre-moi', 'Gendes', 'Tolbiac', 'Cimetière Aguichant', 'Häagen', 'Molly', 'Clamart', 'Rat Luciano', 'El Diablo', 'sourires Paranoïaques', 'Rolex', 'Atada', 'Prada', 'Reno', 'Medellin', 'Maradona', 'Arabie', 'Apollinaire A', 'Nil', 'Amsterdam', "J'te montrerai mon", 'Cythère', 'Séville', 'Derrièr', 'Fort Green', 'Bastia', "Ch'", 'Amoco', 'Submarina', 'Rue du Vieux Colombier Ton fantôme', 'Deuch', "J'ai vu des bateaux", 'B.D.', 'Washington', 'Avignon', 'Jupiter', 'chacals Pâle', 'M.I.C.', "Kro'", 'Issara', 'Olé', 'Créteil', 'lointaines Abattus', 'Atlanta', 'BN', 'C.D', "Jardin d'Eden", 'Macumba', 'Hiroshima', 'Robbie', 'Baptistain', 'Ouarzazate', 'Palerme', 'Kanaky', 'Falù', 'Votre honneur', 'Yo', 'Ravachol', 'Christ(e', "caverne d'Ali", 'Lutem', 'Manhattan', "J'ai gravé profond", 'Honduras', 'Babel Laquelle', 'Nirvana Ensorcelé', 'Lavilliers', 'Revolucion', 'Casino Secrètement', 'That', 'Sugar Hill', "La lune c'est le soleil des loups", 'I veyot', 'Vänd', 'Taïwan', 'Telecom', 'Sri Lanka Sikh', 'Mougeotte', "J'ai\u2005", 'Europe', 'Tacchini', 'Bullshit', 'Pakistan', 'Those', "Rue d'Charonne", 'Lens', 'P 38', 'Que t’', 'Mongolie', 'Pigalle Y', 'Premier Quand t’auras l’', 'Jag längtar efter mig Jag', 'Hello c’', 'Versailles', 'Ginette', 'Novotel Y', 'Nouméa ...
#
# {'passerelle’', 'fascin?s', 't’', 'j’', 'qu’', 'l´au', 'L’', 'c\x9cur', "l'6.6.6", 'l`avenir', 'jardin d’', 'm’', "aim'", 'y´en', 'océan  ', 'n´ai', "don'", 'j´le', 'he’', 'fumée', 'J’', 'marée', 'n’', 'd’', 'raclée', 'forêts', 'musé’', 'v’', '(bis)', 'sacré’', 'entr?e', '\x93', 'année', 'pays n’', 'lycéen', 'j’t’', 'l`alphabet', "see'", 'blas?s', 'l’', 'jean’', 'cœ\x9cur', 'aper?u', 'c’t’', 'T’', '’', 'He’', 'forêt de'}

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2274, 2217, 1206, 1158]
labels = ['lieux_sm', 'tri_1', 'tri_2', 'tri_3']

plt.plot(x, y)
# You can specify a rotation for the tick labels in degrees or with keywords.
plt.xticks(x, labels, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.2)
plt.title("Filtrage de l'échantillon2")
plt.ylabel("nombre de lieux")
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)
plt.show()

# %%
loc_md=[]
for texte in f1:
    try:
        doc = nlp_md(texte)
        for entity in doc.ents:
            if entity.label_ =="LOC":
                loc_md.append(entity.text)
    except:
        pass
print("lieux trouvés par le modèle medium : ",len(set(loc_md)))
print(set(loc_md))
print()
print()

tri_1 = [mot for mot in loc_md if mot not in f2]
test1 = [mot for mot in loc_md if mot in f2]
print("nombre lieux qui ne se trouvent pas dans le Glaff : ", len(set(tri_1)))
print(set(tri_1))
print()
print(set(test1))
print()

tri_2 = [mot for mot in tri_1 if mot.lower() not in f2]
test2 = [mot for mot in tri_1 if mot.lower() in f2]
print("nombre lieux en miniscules qui ne se trouvent pas dans le Glaff : ",len(set(tri_2)))
print(set(tri_2))
print()
print(set(test2))
print()



tri_3 =[mot for mot in tri_2 if mot.lower() not in tri_2] 
test3 =set(tri_2).difference(tri_3)
print("nombre de lieux obtenu dans la liste finale : ", len(set(tri_3)))
print(set(tri_3))
print()
print(set(test3))
# Out:
# lieux trouvés par le modèle medium :  1532
# {'Obscure', 'They', 'Indes', 'Garges-Les-Gonesses', 'Systématique', 'Être', 'Your', 'Belleville', 'Pyrex', 'Délavées', 'la Bastille', 'Squatte', 'Pont', 'Cliché', 'Résonnent', 'Saint-Cloud', 'Tourcoing', 'Pérou', 'Paris-la-soumise', 'Géorgie', 'Attentionné', 'Akkad', 'pont des Arts', "Ras l'bol des pizzerias Terminé  ", 'Thèbes', 'Hindou', "J'ai beau", 'Veux', 'Golfe de Naples', 'Russie', 'Anema', 'Frapadingues', 'London', 'Fourche', 'Garde', 'mer Libre', 'Toulon', "J'ai appris à voir dans le noir", 'Marny', 'Aspire', 'rue Davso', 'Camargue', 'Melopheelo', 'Marie-janne', 'Y', 'Mars Marseille', 'Rotonde', 'marée', 'Monté', 'Pays Basque', 'Taj Mahal', "J'ai couru", 'Burkina', 'Terminus Terre', 'Maire', 'Tolbiac', 'Clamart', 'Caché', 'Orphélie', 'Ivre', "Convoit'", 'Française', 'Séville', 'Les', 'Bastia', "Ch'", 'Quelle', 'le Bonheur', 'Montréal', 'Luberon  ', 'Badé', "J'ai vu les feuilles mortes des arbres", 'Jupiter', 'Abruzzes', 'Négus', 'Brasse', 'Hiroshima', 'Kanaky', "caverne d'Ali", 'Honduras', 'Suzann', 'école A', 'Casino Secrètement', 'Mougeotte', 'Man?uvres', 'Gap On', "J'ai graissé la patte", 'Novotel Y', 'Tarbes', 'Bangkok', 'Dag', 'l´Afrique du Sud', 'Dahu', 'Mettez', 'République', "J'ai ouvert les yeux", 'Hortense', 'A Saint-Sulpice', 'M’', 'Tiroir', 'Aix', 'Dame', 'El Paso', 'Pépette', 'Grandir', 'Saint-Germain-des-Prés', 'Camaret', 'Courant', 'Pin', 'Pousse', 'Planter', 'Mollah', "l'Elysée", 'Cordillère des Andes', 'Comptent', 'New York City', 'Essuyez', 'Va', 'Evêché', 'Mogador', 'Naples', 'rue Ensoleill', 'Maine', 'Sud-Est', 'Les tam', 'Ça', 'Racontez', 'usine A coté', 'O3', 'Franchissant', 'Nou', 'Olympia', 'Bolivie', 'Woody', 'Erronés', 'terre Fier', 'Perriers', 'Arrêter', 'Pochtron', 'W', 'Angers', 'Fréjus', 'Quartiers', 'Butte', 'I', 'pays Est Flora', 'Coulent', 'Ricains', 'Alpha', 'Rio', 'Hip-Hop', 'Demeure', 'Embrasse', 'Panthéon Rue Descartes', 'Saint-Malo', 'Le Picon', 'Dijon', 'Parc', 'A Longwy', 'Dupont', 'Patagonie', 'Villefranche', 'Pow Wow', 'Marchaient', 'Disneyland', 'Montmertre  ', 'Comprends', "T'", 'Rahel', 'matin Montparnasse', 'Canique', 'Aguerri', 'Viêt-Cong', 'Maghreb', 'Tri-Nitro-Toluène', 'Goose', 'Légère', 'Mali', 'Finlande', 'Lille', 'Chinois', 'Moscou', 'Animateur', 'Gaulois', 'India', 'Wallons', 'Aubusson', 'Saturne', 'Fresnes', 'Bouger', 'Pendit', 'Misère', 'Pompadour', 'Eperdue', 'Couplet 6', 'Hasta', 'Issa', 'Berne', 'Douleurs', 'Thiais', 'Bois', 'he’', 'Lyriciste', 'Mexique', 'Chouette', 'Sereine', "Corne d'Aurochs  ", "Ed'", 'La Seine', 'Gare', 'Brooklyn New York', 'Virginie', 'Envahissent', 'Loulou', 'Fuerte', 'Pearl Harbor Allez', 'Khéps', 'Angleterre', 'Cher', 'Auteuil', 'Callipyge', 'Scellées', 'as’', 'Loch Ness Noir', 'Vernis', 'Saint-Pierre', 'Tokarev', 'Rasée', 'Nam', 'Pigeot', 'Colombie', 'la Camarde', 'Distille', 'Foutaises', 'Sholdès', 'Padam', 'on Est', 'jacuzzi A', 'Rosette', 'D', 'Jubiler', 'Quartier Nord', 'Rue Rochechouart', 'Crin', 'Ré-Hor', 'MC', 'Khéops', 'Près', 'Pou', 'Sois', 'Différencie', 'Akhénathon', 'Gaillarde', 'La Rochelle', 'Zénith', 'Waco', 'Puerta', 'Re L?-haut', 'Arche', 'Étalonnée', "J'ai pas d'chance", 'Déplace', 'Pékin', 'Courbée', 'Londres', "Où l'espoir", 'Bordeaux', 'passerelle Tombant', "Grand-pèr'", 'Trop', 'Tommies', 'Etienne', 'Entre-deux-mers', 'Halles', 'Vulpes vulpes Invité', 'Rio des gows', 'Ici', 'Archange', 'Ponds', "L'Amérique du grand", 'Normandie', 'Enfernet', "J'ai ma petite concession", 'Pépette Près', 'Du parc Montsouris', "jardin d'Eden", 'Sûr', 'Charon', 'From London', 'pao Calligraphié', 'Rimbert  Refrain  ', 'Bruxelles', "J'ai beaucoup d'amour", 'Brassée', 'Heineken', 'Paris Ardisson', 'Haïkku', 'We', 'Nation', 'Te de Saint-Cloud', 'Refrain]x2', 'Élysée', 'Deviendront', 'Souillé', 'N', 'Nouvelle', 'Traîne', 'Bécassine', "Tain's", 'Franchir', 'Côte', 'Paysan', 'Abandonnée', 'temeniksKaradin Calme', 'Bihac', 'galaxie Nébuleuse', 'Tape', 'Grenade', 'Calvi', 'Achinan', 'Nord-Ouest', "roi d'Espagne", 'grenade Repentit', 'Europ ...
# nombre lieux qui ne se trouvent pas dans le Glaff :  1485
# {'Obscure', 'They', 'Indes', 'Garges-Les-Gonesses', 'Systématique', 'Être', 'Your', 'Belleville', 'Pyrex', 'Délavées', 'la Bastille', 'Squatte', 'Pont', 'Cliché', 'Résonnent', 'Saint-Cloud', 'Tourcoing', 'Pérou', 'Paris-la-soumise', 'Géorgie', 'Attentionné', 'Akkad', 'pont des Arts', "Ras l'bol des pizzerias Terminé  ", 'Thèbes', 'Hindou', "J'ai beau", 'Veux', 'Golfe de Naples', 'Russie', 'Anema', 'Frapadingues', 'London', 'Fourche', 'Garde', 'mer Libre', 'Toulon', "J'ai appris à voir dans le noir", 'Marny', 'Aspire', 'rue Davso', 'Camargue', 'Melopheelo', 'Marie-janne', 'Y', 'Mars Marseille', 'Rotonde', 'marée', 'Monté', 'Pays Basque', 'Taj Mahal', "J'ai couru", 'Burkina', 'Terminus Terre', 'Maire', 'Tolbiac', 'Clamart', 'Caché', 'Orphélie', 'Ivre', "Convoit'", 'Française', 'Séville', 'Les', 'Bastia', "Ch'", 'Quelle', 'le Bonheur', 'Montréal', 'Luberon  ', 'Badé', "J'ai vu les feuilles mortes des arbres", 'Jupiter', 'Négus', 'Brasse', 'Hiroshima', 'Kanaky', "caverne d'Ali", 'Honduras', 'Suzann', 'école A', 'Casino Secrètement', 'Mougeotte', 'Man?uvres', 'Gap On', "J'ai graissé la patte", 'Novotel Y', 'Tarbes', 'Bangkok', 'Dag', 'l´Afrique du Sud', 'Dahu', 'Mettez', 'République', "J'ai ouvert les yeux", 'Hortense', 'A Saint-Sulpice', 'M’', 'Tiroir', 'Aix', 'Dame', 'El Paso', 'Pépette', 'Grandir', 'Saint-Germain-des-Prés', 'Camaret', 'Courant', 'Pin', 'Pousse', 'Planter', 'Mollah', "l'Elysée", 'Cordillère des Andes', 'Comptent', 'New York City', 'Essuyez', 'Va', 'Evêché', 'Mogador', 'Naples', 'rue Ensoleill', 'Maine', 'Sud-Est', 'Les tam', 'Ça', 'Racontez', 'usine A coté', 'O3', 'Franchissant', 'Nou', 'Olympia', 'Bolivie', 'Woody', 'Erronés', 'terre Fier', 'Perriers', 'Arrêter', 'Pochtron', 'W', 'Angers', 'Fréjus', 'Quartiers', 'Butte', 'I', 'pays Est Flora', 'Coulent', 'Alpha', 'Rio', 'Hip-Hop', 'Demeure', 'Embrasse', 'Panthéon Rue Descartes', 'Saint-Malo', 'Le Picon', 'Dijon', 'Parc', 'A Longwy', 'Dupont', 'Patagonie', 'Villefranche', 'Pow Wow', 'Marchaient', 'Disneyland', 'Montmertre  ', 'Comprends', "T'", 'Rahel', 'matin Montparnasse', 'Canique', 'Aguerri', 'Viêt-Cong', 'Maghreb', 'Tri-Nitro-Toluène', 'Goose', 'Légère', 'Mali', 'Finlande', 'Lille', 'Chinois', 'Moscou', 'Animateur', 'Gaulois', 'India', 'Aubusson', 'Saturne', 'Fresnes', 'Bouger', 'Pendit', 'Misère', 'Pompadour', 'Eperdue', 'Couplet 6', 'Hasta', 'Issa', 'Berne', 'Douleurs', 'Thiais', 'Bois', 'he’', 'Lyriciste', 'Mexique', 'Sereine', "Corne d'Aurochs  ", "Ed'", 'La Seine', 'Gare', 'Brooklyn New York', 'Virginie', 'Envahissent', 'Loulou', 'Fuerte', 'Pearl Harbor Allez', 'Khéps', 'Angleterre', 'Cher', 'Auteuil', 'Callipyge', 'Scellées', 'as’', 'Loch Ness Noir', 'Vernis', 'Saint-Pierre', 'Tokarev', 'Rasée', 'Nam', 'Pigeot', 'Colombie', 'la Camarde', 'Distille', 'Foutaises', 'Sholdès', 'Padam', 'on Est', 'jacuzzi A', 'Rosette', 'Jubiler', 'Quartier Nord', 'Rue Rochechouart', 'Crin', 'Ré-Hor', 'Khéops', 'Près', 'Pou', 'Sois', 'Différencie', 'Akhénathon', 'Gaillarde', 'La Rochelle', 'Zénith', 'Waco', 'Puerta', 'Re L?-haut', 'Arche', 'Étalonnée', "J'ai pas d'chance", 'Déplace', 'Pékin', 'Courbée', 'Londres', "Où l'espoir", 'Bordeaux', 'passerelle Tombant', "Grand-pèr'", 'Trop', 'Tommies', 'Etienne', 'Entre-deux-mers', 'Halles', 'Vulpes vulpes Invité', 'Rio des gows', 'Ici', 'Archange', 'Ponds', "L'Amérique du grand", 'Normandie', 'Enfernet', "J'ai ma petite concession", 'Pépette Près', 'Du parc Montsouris', "jardin d'Eden", 'Sûr', 'Charon', 'From London', 'pao Calligraphié', 'Rimbert  Refrain  ', 'Bruxelles', "J'ai beaucoup d'amour", 'Brassée', 'Heineken', 'Paris Ardisson', 'Haïkku', 'We', 'Nation', 'Te de Saint-Cloud', 'Refrain]x2', 'Élysée', 'Deviendront', 'Souillé', 'Nouvelle', 'Traîne', 'Bécassine', "Tain's", 'Franchir', 'Côte', 'Paysan', 'Abandonnée', 'temeniksKaradin Calme', 'Bihac', 'galaxie Nébuleuse', 'Tape', 'Grenade', 'Calvi', 'Achinan', 'Nord-Ouest', "roi d'Espagne", 'grenade Repentit', 'Pont 1', 'Olé Les belles étrangères', 'Pont 2', 'Paules', 'Nono', ' ...
#
# {'Allemand', 'Suisse', 'Ischia', 'BM', 'Corse', 'CP', 'Broyant', 'Cologne', 'D', 'Est', 'Parisienne', 'Indien', 'Noire', 'N', 'Cancer', 'Ricains', 'MC', 'Abruzzes', 'Corses', 'Tamoul', 'État', 'Basques', 'Père', 'Gitanes', 'Africain', 'Land', 'C', 'G', 'Chouette', 'Montana', 'Aïd', 'Bretons', 'Babylone', 'Danoise', 'Panthéon', 'Bengale', 'B', 'Wallons', 'Indiens', 'Européens', 'Cheyenne', 'Argentine', 'Pontoise', 'Cheval', 'Philistins', 'Alsaciens', 'Phocéens'}
# nombre lieux en miniscules qui ne se trouvent pas dans le Glaff :  925
# {'port Blanche', 'Peauaime', 'Grèce', 'They', "Lil' Bow", 'Nord-Est Solaar', 'Montesquiou', 'Treets', 'Garges-Les-Gonesses', 'Avalon', 'Rue de la Soif', 'Tout’', 'champ Trop grand', "l'Amérique", 'Chapo', 'Le Renard', 'Your', 'Villeneuve-Saint-Georges', 'Égypte', 'c\x9coeur', 'Nivea', "Santiago T'", 'Kong Fu', 'Belleville', 'rue des Saules Rue Saint-Vincent', 'Pyrex', 'Cavan', 'Fort Greene', "l'Afrique", 'la Bastille', 'royaume des Hommes Soudain', 'Saintes-Maries', 'golfe du Lion Trempe', 'Ayato', 'Sévéso', 'Palestine', 'La Jeanne', 'li Vres', "rue Eul'", 'ligne Maginot', 'Bettancourt', 'Saint-Cloud', 'Tourcoing', "fosse all'", 'Sentenza', 'Abyssinie', "Sainte-Mad'lein’", 'Posse Idéal', 'parking A', 'globe Faut', 'Tbilissi', 'Etats-Unis', 'Refrain]×2 A', 'Vénus de barrière', 'Lelay', 'Hôtel de Russie', 'Pérou', 'Nante', 'Paris-la-soumise', 'clébard A', 'Géorgie', "J'ai dit", 'Akkad', 'Allemagne', 'Débilos', 'Ln', 'Holiday Inn', 'Fabien', 'Saint-Michel', 'pont des Arts', "Ras l'bol des pizzerias Terminé  ", 'Catane', 'La Tour Montparnasse', 'Thèbes', "J'ai beau", 'Kévin', 'Vercors', 'allée Emballé', 'Golfe de Naples', 'Big Daddy', 'Ceylan', 'Danemark', 'Russie', 'Anema', 'B.Boy', 'Irlande', 'London', 'Encastr?e', 'Tolède', 'Saint-Esprit', "Doiv'", 'Indochine', 'mer Libre', 'Toulon', 'Dublin City', "J'ai appris à voir dans le noir", 'Marny', 'Avoriaz', 'Papouasie Pipeautant', 'rue Davso', 'Akheanton', 'Melopheelo', 'plaines A', 'l´au', 'Marie-janne', 'Donc bang-bang', "J'ai creusé un tunnel de 18 mètres de long", 'Bercy', 'Dublin', 'D?s', 'Mars Marseille', 'Saint-Malo Fair', 'Terre Ta croix', 'Abscon', 'Pactole Y', 'Capoue', "J'ai maint'nant des frênes Des arbres de judée Tous de bonne graine", 'marée', 'Hanoï', 'Pouc', 'Pays Basque', 'fi France', 'Fleury', 'Armani', 'Californie', "Hortens' A", 'Pigalle', 'Selecto', 'Taj Mahal', 'Byzance', 'Lolito', 'la Chine', 'Saint-Denis', "Corne d'Aurochs", "J'ai couru", 'Cap Canaveral', 'l´église Histoire', 'Qu´ils', 'Burkina', 'Terminus Terre', 'Vallée des Rois', 'Vilnius', 'Serre-moi', 'Gendes', 'Saint Patrick', 'cap Du', 'Tolbiac', 'Paris Rouge', 'Molly', 'Clamart', 'Marbœuf', 'Orphélie', 'Zalamalek', 'Medellin', 'blas?s', 'Saint Lazare', "Convoit'", 'Nil', 'Amsterdam', 'place de parking Où gît mon', 'Cythère', 'Séville', 'trottin Tortillant', 'Fort Green', "J'ai froid", 'gare de Lyon', 'Bastia', "Ch'", 'le Bonheur', 'A Lourdes', 'Montréal', 'Washington', 'Avignon', "J'ai vu les feuilles mortes des arbres", 'Luberon  ', 'Jupiter', 'Errare', 'la Mecque', 'Hook', 'Issara', 'Olé', 'Créteil', 'Atlanta', "Jardin d'Eden", 'Ouarzazate', 'Hiroshima', 'rue du Bac Mais retenez ma place', 'Palerme', 'hôtel Grand', 'Kanaky', 'Falù', 'Fezensac', "caverne d'Ali", "J'ai gravé profond", "J'ai vu bon nombre de nombrils", "sam'di soir Où le cœur plein d'espoir", 'Honduras', 'Suzann', 'école A', 'Casino Secrètement', 'Sugar Hill', "Plaza J'", 'Taïwan', 'Telecom', 'Rimbert  ', 'Sri Lanka Sikh', 'Mougeotte', 'grand-route Ell', 'Europe', "Rue d'Charonne", 'Pakistan', 'Those', 'Lens', 'Où Naples', 'Man?uvres', 'Mongolie', 'Gap On', 'Versailles', "J'ai graissé la patte", 'Euromarché Menaçants', 'Novotel Y', 'Sardagne', 'Nouméa', 'Lison', 'la Loire', 'fascin?s', "J'ai", 'Bhopal', 'Etna Mirage', 'Tarbes', 'Bangkok', 'Dag', "Bihac'", "a- Mygdales Etre assoiffé d'eau", 'l´Afrique du Sud', "l'Irlande", 'Népal', 'Salamanque', 'Maint´nant', 'B52', "J'ai ouvert les yeux", "terril J'a toudis d'la chance d'vir ch'", 'Hortense', 'Lison Aime', 'A Saint-Sulpice', "A l'fosse nou pères", 'Remball', 'M’', 'Italie', 'Maldives', 'Aix', 'Laponie', 'El Paso', 'la Courneuve', 'Pépette', 'Coupole Les midinettes', 'E1', "L'Opinel", 'Ou mon temple', 'Saint-Germain-des-Prés', 'bastrin- Gue', 'Houston', 'Hauts-Plateaux', 'grande Ourse', 'pont des Arts Tu croises le vent', 'Camaret', 'Brooklyn', "J'ai graissé la patte au sonneur", "J'ai pas", 'Personn', 'la Pologne', "l'Elysée", 'Tennessee', "J'ai choisi ma route", 'Mentally', 'Fu', ' ...
#
# {'Obscure', 'Immonde', 'Indes', 'Spirituel', 'Sais', 'Raflés', 'Damas', 'Reggae', 'Gens', 'Rital', 'Coulés', 'Cocu', 'Tours', 'Systématique', 'Être', 'Mentons', 'Celles', 'Fastoche', 'Valence', 'Winchester', 'Halte', 'Façonné', 'Tremper', 'Délavées', 'Mars', 'Lier', 'Vois', 'Squatte', 'Horizons', 'Sire', 'Pont', 'Manie', 'Cliché', 'Reviendront', 'Résonnent', 'Féria', 'Bacchus', 'Distance', 'Fume', 'Marches', 'Attentionné', 'Dés', 'Continuer', 'Cohabitation', 'Suis', 'Sud', 'Invités', 'Décolorées', 'Refrain', 'Garez', 'Hindou', 'Flagada', 'Veux', 'Fier', 'Précieuses', 'Voie', 'Narbonne', 'Hissez', 'Margoton', 'Troussa', 'Frapadingues', 'Connemara', 'Fourche', 'Mais', 'Village', 'Panama', 'Garde', 'Quimper', 'Sparte', 'Aspire', 'Son', 'Puces', 'Fiers', 'Camargue', 'Couplet', 'Y', "N'", 'Déchanter', 'Opéra', 'Rotonde', 'Gaîté', 'Prusse', 'Monté', 'Apaches', 'Vaux', 'Et', 'Pal', 'Enfants', 'Berlin', 'Auvergne', 'Cristal', 'Méditerranéenne', 'Délaisse', 'Maire', 'Embrase', 'Opaque', 'Bastilles', 'Bicêtre', 'Bravo', 'Caché', 'Vatican', 'Ivre', 'Redescends', 'Amasse', 'Dallas', 'Française', 'Frénétique', 'Les', 'Chevauchée', 'Quelle', 'Badé', 'Toi', 'Bière', 'Négus', 'Pantin', 'Galette', 'Brasse', 'Tiercé', 'Hexagone', 'Guignol', 'Schizophrénique', 'Reverra', 'Berçant', 'Volez', 'Quelque', 'Onques', 'Tectonique', 'Miami', 'Manille', 'Sarcelles', 'Prés', 'Arnaquer', 'Bonjour', 'Belges', 'Pas', 'Monoï', 'Chouf', 'Nulle', 'Monaco', 'Privées', 'Dahu', 'Mettez', 'République', 'Brésil', 'Foule', 'Direct', 'Faisanderie', 'Tiroir', 'Danser', 'Té', 'Dame', 'Bourrez', 'Berce', 'Tarentelles', 'Maman', 'Chartre', 'Grandir', 'Supercherie', 'Funk', 'Pousse', 'Courant', 'Pin', 'Crois', 'Mai', 'Blanche', 'Planter', 'Intro', 'Mollah', 'Certifié', 'Pointu', 'Rendez', 'Comptent', 'Vienne', 'Sorbonne', 'Essuyez', 'Va', 'Exploitées', 'Électrolyse', 'Landerneau', 'Incontinent', 'Place', 'Racontez', 'Tao', 'Pastis', 'Soixante', 'Gratter', 'Franchissant', 'States', 'Fit', 'Mutiler', 'Darjeeling', 'Longe', 'Cigarillo', 'Erronés', 'Méditerranée', 'Regardez', 'Arrêter', 'Nice', 'Allez', 'Empalés', 'Font', 'Niger', 'Union', 'Quartiers', 'Reporter', 'Scratchs', 'Chœur', 'Naviguait', 'Butte', 'Passeport', 'Coulent', 'Alpha', 'Rio', 'Macao', 'Boy', 'Technique', 'Beaujolais', 'Colombe', 'Serein', 'Incompréhension', 'Rythmer', 'Demeure', 'Menuets', 'Embrasse', 'Maires', 'Perpignan', 'Enchaîné', 'Maharajas', 'Coca', 'Recto', 'Bas', 'Blague', 'Parc', 'Havres', 'Brille', 'Idéal', 'Deal', 'Pervenches', 'Millénaire', 'Marchaient', 'Lima', 'In', 'Comprends', "T'", 'Métamorphoser', 'Parme', 'Bled', 'Aguerri', 'Tsunami', 'Bagarreurs', 'Or', 'Légère', 'Mali', 'Robinet', 'Écoute', 'H', 'Chinois', 'Paris', 'Lune', 'Animateur', 'Tournoyante', 'Gaulois', 'Exorcise', 'Oxford', 'Saturne', 'Tiens', 'Bouger', 'Pendit', 'Misère', 'Louche', 'Verrouillée', 'Creeks', 'Aiment', 'Berne', 'Douleurs', 'Inde', 'Frappe', 'Psychiatrisées', 'Bois', 'Briquer', 'Hargne', 'Sereine', 'Arrêté', 'Ris', 'Nigauds', 'Prouve', 'Triangulaire', 'Gare', 'Devant', 'Salut', 'Point', 'Envahissent', 'Abattus', 'Loulou', 'Sadique', 'Are', 'Enseigne', 'Angleterre', 'Cher', 'Prophétisant', 'Chicanos', 'Callipyge', 'Transfiguré', 'Pleure', 'Carrare', 'Scellées', 'Méprisent', 'Vernis', 'Rater', 'Prévenez', 'Reluques', 'Mignonne', 'Gotha', 'Rasée', 'Ca', 'La', 'Pondus', 'Génétique', 'Gasoil', 'Philippines', 'Planète', 'Décimées', 'Distille', 'Foutaises', 'Français', 'Hong', 'Devrais', 'Pic', 'Marre', 'Grand', 'Rosette', 'Cartier', 'Jubiler', 'Samples', 'Crin', 'Grands', 'Chés', 'Près', 'Pénélope', 'Pédé', 'Pou', 'Déférence', 'Sois', 'Différencie', 'Tranquilles', 'Baffles', 'Redoute', 'Gaillarde', 'Zénith', 'Affûté', 'Hambourg', 'Arche', 'Étalonnée', 'Fac', 'Déplace', 'Pékin', 'Courbée', 'Western', 'Lolo', 'Bordeaux', 'Nouveau', 'Croyez', 'Arrache', 'Repasser', 'Moulins', 'Rouen', 'Marchant', 'Trop', 'Cong', 'Chine', 'Landes', 'Combien', 'Ligotée', 'Sardane', 'Halles', 'Microbe', 'Terminus', 'Souverains', 'Soyons', 'I ...
#
# nombre de lieux obtenu dans la liste finale :  910
# {'port Blanche', 'Peauaime', 'Grèce', 'They', "Lil' Bow", 'Nord-Est Solaar', 'Montesquiou', 'Treets', 'Garges-Les-Gonesses', 'Avalon', 'Rue de la Soif', 'Tout’', 'champ Trop grand', "l'Amérique", 'Chapo', 'Le Renard', 'Your', 'Villeneuve-Saint-Georges', 'Égypte', 'Nivea', "Santiago T'", 'Kong Fu', 'Belleville', 'rue des Saules Rue Saint-Vincent', 'Pyrex', 'Cavan', 'Fort Greene', "l'Afrique", 'la Bastille', 'royaume des Hommes Soudain', 'Saintes-Maries', 'golfe du Lion Trempe', 'Ayato', 'Sévéso', 'Palestine', 'La Jeanne', 'li Vres', "rue Eul'", 'ligne Maginot', 'Bettancourt', 'Saint-Cloud', 'Tourcoing', 'Sentenza', 'Abyssinie', "Sainte-Mad'lein’", 'Posse Idéal', 'parking A', 'globe Faut', 'Tbilissi', 'Etats-Unis', 'Refrain]×2 A', 'Vénus de barrière', 'Lelay', 'Hôtel de Russie', 'Pérou', 'Nante', 'Paris-la-soumise', 'clébard A', 'Géorgie', "J'ai dit", 'Akkad', 'Allemagne', 'Débilos', 'Ln', 'Holiday Inn', 'Fabien', 'Saint-Michel', 'pont des Arts', "Ras l'bol des pizzerias Terminé  ", 'Catane', 'La Tour Montparnasse', 'Thèbes', "J'ai beau", 'Kévin', 'Vercors', 'allée Emballé', 'Golfe de Naples', 'Big Daddy', 'Ceylan', 'Danemark', 'Russie', 'Anema', 'B.Boy', 'Irlande', 'London', 'Encastr?e', 'Tolède', 'Saint-Esprit', "Doiv'", 'Indochine', 'mer Libre', 'Toulon', 'Dublin City', "J'ai appris à voir dans le noir", 'Marny', 'Avoriaz', 'Papouasie Pipeautant', 'rue Davso', 'Akheanton', 'Melopheelo', 'plaines A', 'Marie-janne', 'Donc bang-bang', "J'ai creusé un tunnel de 18 mètres de long", 'Bercy', 'Dublin', 'D?s', 'Mars Marseille', 'Saint-Malo Fair', 'Terre Ta croix', 'Abscon', 'Pactole Y', 'Capoue', "J'ai maint'nant des frênes Des arbres de judée Tous de bonne graine", 'Hanoï', 'Pouc', 'Pays Basque', 'fi France', 'Fleury', 'Armani', 'Californie', "Hortens' A", 'Pigalle', 'Selecto', 'Taj Mahal', 'Byzance', 'Lolito', 'la Chine', 'Saint-Denis', "Corne d'Aurochs", "J'ai couru", 'Cap Canaveral', 'l´église Histoire', 'Qu´ils', 'Burkina', 'Terminus Terre', 'Vallée des Rois', 'Vilnius', 'Serre-moi', 'Gendes', 'Saint Patrick', 'cap Du', 'Tolbiac', 'Paris Rouge', 'Molly', 'Clamart', 'Marbœuf', 'Orphélie', 'Zalamalek', 'Medellin', 'Saint Lazare', "Convoit'", 'Nil', 'Amsterdam', 'place de parking Où gît mon', 'Cythère', 'Séville', 'trottin Tortillant', 'Fort Green', "J'ai froid", 'gare de Lyon', 'Bastia', "Ch'", 'le Bonheur', 'A Lourdes', 'Montréal', 'Washington', 'Avignon', "J'ai vu les feuilles mortes des arbres", 'Luberon  ', 'Jupiter', 'Errare', 'la Mecque', 'Hook', 'Issara', 'Olé', 'Créteil', 'Atlanta', "Jardin d'Eden", 'Ouarzazate', 'Hiroshima', 'rue du Bac Mais retenez ma place', 'Palerme', 'hôtel Grand', 'Kanaky', 'Falù', 'Fezensac', "caverne d'Ali", "J'ai gravé profond", "J'ai vu bon nombre de nombrils", "sam'di soir Où le cœur plein d'espoir", 'Honduras', 'Suzann', 'école A', 'Casino Secrètement', 'Sugar Hill', "Plaza J'", 'Taïwan', 'Telecom', 'Rimbert  ', 'Sri Lanka Sikh', 'Mougeotte', 'grand-route Ell', 'Europe', "Rue d'Charonne", 'Pakistan', 'Those', 'Lens', 'Où Naples', 'Man?uvres', 'Mongolie', 'Gap On', 'Versailles', "J'ai graissé la patte", 'Euromarché Menaçants', 'Novotel Y', 'Sardagne', 'Nouméa', 'Lison', 'la Loire', 'Bhopal', "J'ai", 'Etna Mirage', 'Tarbes', 'Bangkok', 'Dag', "Bihac'", "a- Mygdales Etre assoiffé d'eau", 'l´Afrique du Sud', "l'Irlande", 'Népal', 'Salamanque', 'Maint´nant', 'B52', "J'ai ouvert les yeux", "terril J'a toudis d'la chance d'vir ch'", 'Hortense', 'Lison Aime', 'A Saint-Sulpice', "A l'fosse nou pères", 'Remball', 'M’', 'Italie', 'Maldives', 'Aix', 'Laponie', 'El Paso', 'la Courneuve', 'Pépette', 'Coupole Les midinettes', 'E1', "L'Opinel", 'Ou mon temple', 'Saint-Germain-des-Prés', 'bastrin- Gue', 'Houston', 'Hauts-Plateaux', 'grande Ourse', 'pont des Arts Tu croises le vent', 'Camaret', 'Brooklyn', "J'ai graissé la patte au sonneur", "J'ai pas", 'Personn', 'la Pologne', "l'Elysée", 'Tennessee', "J'ai choisi ma route", 'Mentally', 'Fu', 'Cordillère des Andes', 'jardin du Bon Dieu', 'Donx', 'Rungis', 'New ...
#
# {'fascin?s', 'c\x9coeur', 'he’', 'op?ras', 'monts du', 'as’', 'marée', 'l´au', 'blas?s', "pont d'", "cor'", "méd'", 'métro', 'porte de', "fosse all'"}

# %%
x = [1, 2, 3, 4]
y = [1532, 1485, 925, 910]
labels = ['lieux_md', 'tri_1', 'tri_2', 'tri_3']

plt.plot(x, y)
# You can specify a rotation for the tick labels in degrees or with keywords.
plt.xticks(x, labels, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.2)
plt.title("Filtrage de l'échantillon2")
plt.ylabel("nombre de lieux")
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)
plt.show()

# %%
loc_lg=[]
for texte in f1:
    try:
        doc = nlp_lg(texte)
        for entity in doc.ents:
            if entity.label_ =="LOC":
                loc_lg.append(entity.text)
    except:
        pass
print("lieux trouvés par le modèle large : ",len(set(loc_lg)))
print(set(loc_lg))
print()
print()

tri_1 = [mot for mot in loc_lg if mot not in f2]
test1 = [mot for mot in loc_lg if mot in f2]
print("nombre lieux qui ne se trouvent pas dans le Glaff : ", len(set(tri_1)))
print(set(tri_1))
print()
print(set(test1))
print()

tri_2 = [mot for mot in tri_1 if mot.lower() not in f2]
test2 = [mot for mot in tri_1 if mot.lower() in f2]
print("nombre lieux en miniscules qui ne se trouvent pas dans le Glaff : ",len(set(tri_2)))
print(set(tri_2))
print()
print(set(test2))
print()



tri_3 =[mot for mot in tri_2 if mot.lower() not in tri_2] 
test3 =set(tri_2).difference(tri_3)
print("nombre de lieux obtenu dans la liste finale : ", len(set(tri_3)))
print(set(tri_3))
print()
print(set(test3))
# Out:
# lieux trouvés par le modèle medium :  1492
# {'They', 'Indes', 'Grossiste', 'Sur Digne', 'Garges-Les-Gonesses', "Heureus'", 'Vrille', 'Systématique', 'Belleville', 'Pyrex', 'Délavées', 'Montrant', 'la Bastille', 'Pont', 'Résonnent', 'Saint-Cloud', 'Ffu', 'Wana', 'Tourcoing', 'These', 'Pérou', 'Lerchechem', 'Paris-la-soumise', 'Géorgie', 'Akkad', 'För', 'Blaow', 'pont des Arts', 'Thèbes', 'Skiez', 'Hindou', 'Veux', 'Monténégro', "J'aim'rais mieux mourir", 'Golfe de Naples', 'Russie', 'Haine', 'Pervenches Ou', 'Frapadingues', 'London', 'Fourche', 'Dégela', 'mer Libre', 'Toulon', '‘Inti Fada', 'Montrez', 'Marny', 'Miniloubarrivistes', 'rue Davso', 'Camargue', 'Jehova', 'royaume des Hommes', 'marée', 'Monté', 'planète Mars', 'Eperdu de bonheur', 'Pays Basque', 'N.Y.C.', 'Hier soir au', 'Taj Mahal', 'Burkina', 'Raccourcissent', 'Tolbiac', 'Clamart', 'Orphélie', "J'ai dit banco", 'Atada', "rue T'", "Convoit'", 'Seine', 'Mec', 'Ré', 'Séville', 'Les', 'Bastia', 'Badé', "J'ai vu les feuilles mortes des arbres", 'Abruzzes', "Royaume Ming Pas d'apologie du Tchikipaw", 'Hiroshima', 'Malpolis', 'Lille Roubaix Tourcoing', 'Doubler', "caverne d'Ali", 'Honduras', 'Couz’', 'Croule', 'Femelles', 'Man?uvres', 'B.H.V', 'Faisais', 'Novotel Y', 'Tarbes', 'Bangkok', 'Dahu', 'République', 'Chérie', 'A Saint-Sulpice', 'Ait', 'Aix', 'Métissée', 'El Paso', 'Grandir', 'Saint-Germain-des-Prés', 'Raclant', 'Camaret', 'Pin', 'Regarde-moi AH AH AH', 'Rue du Vieux Colombier', 'Cordillère des Andes', 'Besoin', 'golf Ballesteros', 'New York City', 'Essuyez', 'Va', 'Evêché', 'Mogador', 'Ouhou', 'Tracer', 'Maine', 'Sud-Est', 'Nord-Est', 'Franchissant', 'Mesquins', 'Nou', 'Bolivie', 'Gavroche', 'métro Saint-Mandé Qui', 'Weah', 'Perriers', 'Terrée', 'Angers', 'Fréjus', 'Quartiers', 'Milliers', 'I', 'Ves D', 'Coulent', 'Ricains', 'Alpha', 'Rio', 'rue de Vanves', 'Hip-Hop', 'Profondes racines', 'Demeure', 'Rencontra', 'Panthéon Rue Descartes', 'Saint-Malo', 'Fresh', 'Le Picon', 'Dijon', 'A Longwy', 'Patagonie', 'Villefranche', 'Pow Wow', "Alhambra d'Bordeaux", 'Disneyland', 'Ve', "T'", 'Canique', 'H.O.P', 'Viêt-Cong', 'Long Kesh', 'Marylou', 'Maghreb', 'Tri-Nitro-Toluène', 'Goose', 'Légère', 'Mali', 'la Weed', 'Lille', 'Chinois', 'Moscou', 'Eloigne toi', 'Wallons', 'Saturne', 'Naples A', 'Fresnes', 'Bouger', 'c\x9cur', 'Berne', 'Ouais C.V Imperial', 'Touraine', 'Thiais', 'Lyriciste', 'Mexique', 'Fonder', 'Torse', 'Montélimar', 'Château Noir', 'Une Sardane Je suis ton homme', 'Chouette', 'Sereine', 'Chartre’ Funeste', 'Montent', "Ed'", 'Ancrée', 'La Seine', 'Gare', 'Brooklyn New York', 'Basta', 'Virginie', 'le Saint-Esprit', 'Courrut', 'Loulou', 'Fuerte', "More C'", 'Angleterre', 'Dalila', 'Cher', 'Sensualiser', 'Auteuil', 'Callipyge', 'Mourra', 'Sonde', 'Loch Ness Noir', 'Vernis', 'Saint-Pierre', 'Colombie', 'Criminosical', 'Rue sombre', 'Encre noire', 'Distille', 'Foutaises', 'forêt Chante', 'Sholdès', 'Padam', 'Test', 'Rosette', 'D', 'Jubiler', "pont Alexandre Jusqu'", 'Quartier Nord', 'Rue Rochechouart', 'Crin', 'MC', 'Fers', 'Pou', 'Sois', "Fur'", 'Gaillarde', 'La Rochelle', 'Zénith', 'Waco', 'Puerta', 'Re L?-haut', 'Étalonnée', 'La rue', 'Déplace', 'Pékin', 'Courbée', 'Londres', 'Bordeaux', 'Tifosi', 'Élysées', 'Trop', 'Tommies', 'Etienne', 'BDP Tourne', 'Pénélopes', 'île de Zalamalek', 'V', 'Ponds', "L'Amérique du grand", 'Normandie', 'Pépette Près', "jardin d'Eden", 'mer Egée', 'Épis', 'Ur', 'crever Étouffés', 'Charon', 'From London', "temple N'aies pas peur", 'Teutons', 'Bruxelles', 'Paris Ardisson', 'Oublierons', 'We', 'Nation', 'Te de Saint-Cloud', 'Mozart Du pont des Arts', 'j´m´engueule', 'Deviendront', "Amour C'", 'Souillé', 'Gre v', 'Nouvelle', 'Traîne', 'Vres', "fossé N'", 'Franchir', 'Tourner', 'Côte', 'Abandonnée', 'Bihac', 'galaxie Nébuleuse', 'Grenade', 'Calvi', 'Achinan', 'Parc Montsouris Après-midi un peu folle', 'Nord-Ouest', "roi d'Espagne", 'Européens', 'caisse A', 'Ferma', 'pays Coupée', 'Paules', 'n´en', 'Désarticulé', 'Katana', 'chemin Morte', 'Voulu', 'Basques', "Côte d'Azur", 'Sol ...
# nombre lieux qui ne se trouvent pas dans le Glaff :  1442
# {'They', 'Indes', 'Grossiste', 'Sur Digne', 'Garges-Les-Gonesses', "Heureus'", 'Vrille', 'Systématique', 'Belleville', 'Pyrex', 'Délavées', 'Montrant', 'la Bastille', 'Pont', 'Résonnent', 'Saint-Cloud', 'Ffu', 'Wana', 'Tourcoing', 'These', 'Pérou', 'Lerchechem', 'Paris-la-soumise', 'Géorgie', 'Akkad', 'För', 'Blaow', 'pont des Arts', 'Thèbes', 'Skiez', 'Hindou', 'Veux', 'Monténégro', "J'aim'rais mieux mourir", 'Golfe de Naples', 'Russie', 'Haine', 'Pervenches Ou', 'Frapadingues', 'London', 'Fourche', 'Dégela', 'mer Libre', 'Toulon', '‘Inti Fada', 'Montrez', 'Marny', 'Miniloubarrivistes', 'rue Davso', 'Camargue', 'Jehova', 'royaume des Hommes', 'marée', 'Monté', 'planète Mars', 'Eperdu de bonheur', 'Pays Basque', 'N.Y.C.', 'Hier soir au', 'Taj Mahal', 'Burkina', 'Raccourcissent', 'Tolbiac', 'Clamart', 'Orphélie', "J'ai dit banco", 'Atada', "rue T'", "Convoit'", 'Seine', 'Mec', 'Ré', 'Séville', 'Les', 'Bastia', 'Badé', "J'ai vu les feuilles mortes des arbres", "Royaume Ming Pas d'apologie du Tchikipaw", 'Hiroshima', 'Malpolis', 'Lille Roubaix Tourcoing', 'Doubler', "caverne d'Ali", 'Honduras', 'Couz’', 'Croule', 'Femelles', 'Man?uvres', 'B.H.V', 'Faisais', 'Novotel Y', 'Tarbes', 'Bangkok', 'Dahu', 'République', 'Chérie', 'A Saint-Sulpice', 'Ait', 'Aix', 'Métissée', 'El Paso', 'Grandir', 'Saint-Germain-des-Prés', 'Raclant', 'Camaret', 'Pin', 'Regarde-moi AH AH AH', 'Rue du Vieux Colombier', 'Cordillère des Andes', 'Besoin', 'golf Ballesteros', 'New York City', 'Essuyez', 'Va', 'Evêché', 'Mogador', 'Ouhou', 'Tracer', 'Maine', 'Sud-Est', 'Nord-Est', 'Franchissant', 'Mesquins', 'Nou', 'Bolivie', 'Gavroche', 'métro Saint-Mandé Qui', 'Weah', 'Perriers', 'Terrée', 'Angers', 'Fréjus', 'Quartiers', 'Milliers', 'I', 'Ves D', 'Coulent', 'Alpha', 'Rio', 'rue de Vanves', 'Hip-Hop', 'Profondes racines', 'Demeure', 'Rencontra', 'Panthéon Rue Descartes', 'Saint-Malo', 'Fresh', 'Le Picon', 'Dijon', 'A Longwy', 'Patagonie', 'Villefranche', 'Pow Wow', "Alhambra d'Bordeaux", 'Disneyland', 'Ve', "T'", 'Canique', 'H.O.P', 'Viêt-Cong', 'Long Kesh', 'Marylou', 'Maghreb', 'Tri-Nitro-Toluène', 'Goose', 'Légère', 'Mali', 'la Weed', 'Lille', 'Chinois', 'Moscou', 'Eloigne toi', 'Saturne', 'Naples A', 'Fresnes', 'Bouger', 'c\x9cur', 'Berne', 'Ouais C.V Imperial', 'Thiais', 'Lyriciste', 'Mexique', 'Fonder', 'Torse', 'Montélimar', 'Château Noir', 'Une Sardane Je suis ton homme', 'Sereine', 'Chartre’ Funeste', 'Montent', "Ed'", 'Ancrée', 'La Seine', 'Gare', 'Brooklyn New York', 'Basta', 'Virginie', 'le Saint-Esprit', 'Courrut', 'Loulou', 'Fuerte', "More C'", 'Angleterre', 'Dalila', 'Cher', 'Sensualiser', 'Auteuil', 'Callipyge', 'Mourra', 'Sonde', 'Loch Ness Noir', 'Vernis', 'Saint-Pierre', 'Colombie', 'Criminosical', 'Rue sombre', 'Encre noire', 'Distille', 'Foutaises', 'forêt Chante', 'Sholdès', 'Padam', 'Test', 'Rosette', 'Jubiler', "pont Alexandre Jusqu'", 'Quartier Nord', 'Rue Rochechouart', 'Crin', 'Fers', 'Pou', 'Sois', "Fur'", 'Gaillarde', 'La Rochelle', 'Zénith', 'Waco', 'Puerta', 'Re L?-haut', 'Étalonnée', 'La rue', 'Déplace', 'Pékin', 'Courbée', 'Londres', 'Bordeaux', 'Tifosi', 'Élysées', 'Trop', 'Tommies', 'Etienne', 'BDP Tourne', 'Pénélopes', 'île de Zalamalek', 'V', 'Ponds', "L'Amérique du grand", 'Normandie', 'Pépette Près', "jardin d'Eden", 'mer Egée', 'Épis', 'Ur', 'crever Étouffés', 'Charon', 'From London', "temple N'aies pas peur", 'Bruxelles', 'Paris Ardisson', 'Oublierons', 'We', 'Nation', 'Te de Saint-Cloud', 'Mozart Du pont des Arts', 'j´m´engueule', 'Deviendront', "Amour C'", 'Souillé', 'Gre v', 'Nouvelle', 'Traîne', 'Vres', "fossé N'", 'Franchir', 'Tourner', 'Côte', 'Abandonnée', 'Bihac', 'galaxie Nébuleuse', 'Grenade', 'Calvi', 'Achinan', 'Parc Montsouris Après-midi un peu folle', 'Nord-Ouest', "roi d'Espagne", 'caisse A', 'Ferma', 'pays Coupée', 'Paules', 'n´en', 'Désarticulé', 'Katana', 'chemin Morte', 'Voulu', "Côte d'Azur", 'Soleil', 'Permets', 'Endosser', 'Suintant', 'Brive-la-Gaillarde A', 'P', 'Tombant', 'fosse Pus', "Jardin d' ...
#
# {'Arabe', 'Allemand', 'Suisse', 'Ischia', 'Corse', 'CP', 'Ricain', 'Broyant', 'Cologne', 'D', 'Est', 'Parisienne', 'Indien', 'Noire', 'Cancer', 'Ricains', 'Corses', 'MC', 'Abruzzes', 'Chtimis', 'Égyptiens', 'Tamoul', 'État', 'Touraine', 'Basques', 'Père', 'Belles', 'C', 'Javanaise', 'Occident', 'G', 'Chouette', 'Australien', 'Montana', 'Aïd', 'Blacks', 'Babylone', 'Balance', 'Teutons', 'Bengale', 'B', 'Wallons', 'Indiens', 'Européens', 'Argentine', 'Pontoise', 'Cheval', 'Philistins', 'Alsaciens', 'Phocéens'}
# nombre lieux en miniscules qui ne se trouvent pas dans le Glaff :  901
# {'Grèce', 'They', "J'aurais pu me tendre et les prendre", 'Sur Digne', 'Treets', 'Même', 'Garges-Les-Gonesses', 'Avalon', 'Rue de la Soif', "Heureus'", "’ C'", "l'Amérique", 'Pondichéry', 'Le Renard', 'Villeneuve-Saint-Georges', 'Lorque', 'Égypte', 'Knicks', "Santiago T'", 'tour A', 'Belleville', 'rue des Saules Rue Saint-Vincent', 'Pyrex', 'Cavan', 'Mars Reléguant', 'Fort Greene', "ci N'", "l'Afrique", 'la Bastille', 'Nicaragua', 'pyramide Mets', 'Palestine', 'golfe du Lion Trempe', 'So', 'Ayato', 'Grossissait la Seine', 'Sévéso', "Boulevard de la Chapelle Sur un air d'eau d'javelle", 'ligne Maginot', 'Krasnodar', 'Bettancourt', 'Saint-Cloud', 'Ffu', 'Wana', "Paradis C't'", 'Tourcoing', 'Rasée la maison', 'Abyssinie', "Sainte-Mad'lein’", 'Nam yo', 'parking A', 'Dins', 'These', 'Tbilissi', 'Refrain]×2 A', 'cave Tu', 'Dignos', 'Nante', 'Pérou', 'Lerchechem', 'Eloigne toi Petite fille aux yeux perdus Tu', 'Saint-Eloi', 'AH AH AH', 'Paris-la-soumise', 'Géorgie', "J'ai dit", 'Akkad', 'Allemagne', 'Eux', 'Débilos', 'Istres', 'För', 'Eloigne toi Petite fille aux yeux perdus', 'Holiday Inn', 'Nent', 'Blaow', 'pont des Arts', 'Saint-Michel', "Phili' Quels", 'Catane', 'La Tour Montparnasse', 'Thèbes', 'du Nord', 'Monténégro', "J'aim'rais mieux mourir", 'Kévin', 'Reïf', 'Longjumeaux', 'Bhanghra de Katmandou', 'Golfe de Naples', 'cimes Squatteurs', 'Big Daddy', 'Ceylan', 'Danemark', 'Russie', "citadelle d'Ajaccio", 'Pervenches Ou', 'B.Boy', 'Irlande', 'London', 'Tolède', "Doiv'", 'Lachaise', 'Lololala', 'mer Libre', 'Indochine', 'Toulon', '‘Inti Fada', 'Dublin City', 'Tcherno', 'Suzon', 'mont Falù', 'Marny', 'Florence Rey', 'Emaciés', 'Miniloubarrivistes', 'Les rues', 'Avoriaz', 'La Canebière', 'rue Davso', 'rue Suzon', 'plaines A', 'l´au', 'ville Exorcise', 'Jehova', 'Bercy', 'Dublin', 'royaume des Hommes', 'Saint-Malo Fair', 'terre Père', 'Venise Où', 'Capoue', 'marée', 'rue Blondel', "J'ai lu beaucoup de books certains", 'AH AH AH Regarde', 'planète Mars', 'Hanoï', 'Eperdu de bonheur', 'Pouc', 'Pays Basque', 'Fleury', 'Bhopal Yo !', 'fi France', 'obscurité', 'Californie', 'N.Y.C.', 'Hier soir au', 'Pigalle', 'Loch Ness', 'Selecto', 'Land Bouteille cassée', 'Taj Mahal', 'Ffff', 'la Chine', 'Saint-Denis', "Corne d'Aurochs", 'Cap Canaveral', 'Byzance', 'l´église Histoire', 'Sardagne', 'Burkina', 'Vallée des Rois', 'Vénus Ris', 'Saint Patrick', 'Tolbiac', 'Cimetière Aguichant', 'Molly', 'Clamart', 'Rue du Vieux', 'Orphélie', "J'ai dit banco", 'Coudes serrés', "J'ai creusé un tunnel de 18 mètres de long J'ai atterri dans la cave d'une laiterie parisienne J'ai pris 300 carambars un kilo de madeleines", 'Atada', 'Medellin', "rue T'", 'Sublime Porte En grand Pour ta famille', "Convoit'", 'Nil', 'Amsterdam', 'Continúas serena Por', 'Cythère', 'Séville', 'Fort Green', 'gare de Lyon', 'Dépression', "N C'", 'Bastia', "Tre heureux C'", 'Passe la Heineken', 'Washington', 'Avignon', "J'ai vu les feuilles mortes des arbres", 'Amaloulous À cause de', 'la Mecque', 'M.I.C.', "Royaume Ming Pas d'apologie du Tchikipaw", "I'", 'Issara', 'Mortadan', 'Créteil', 'Atlanta', "Jardin d'Eden", 'Macumba', 'Hiroshima', 'Baptistain', 'Ouarzazate', 'Palerme', 'fortin Se', 'Lille Roubaix Tourcoing', "Medellin N'", 'Yo', "caverne d'Ali", 'Saint-Pétersbourg', 'Label 5', 'Honduras', 'Beaune', 'Couz’', 'Sugar Hill', 'Vänd', 'Taïwan', 'Telecom', 'Va caguer', 'Bien-aimées', 'Sans c\x9cur', 'Europe', "Rue d'Charonne", 'Bullshit', 'Pakistan', 'Silhouette insolite', "Ras l'bol des pizzerias", 'Lens', 'Où Naples', 'Two', 'Man?uvres', 'Mental de Viêt', 'Mongolie', 'B.H.V', 'Versailles', 'Nou terrils', 'Novotel Y', 'Nouméa', 'Lison', 'la Loire', 'Etna Mirage', 'Tarbes', 'Bangkok', "Bihac'", 'Echo', "l'Irlande", 'Népal', 'Salamanque', 'M?m', 'B52', 'A Saint-Sulpice', 'Poto', 'Bamako', 'Maldives', 'baby Blanche', 'Aix', 'Laponie', 'El Paso', 'C.O.B.de', 'la Courneuve', 'E1', 'Voil', 'Saint-Germain-des-Prés', 'bastrin- Gue', 'Houston', 'Chari Jazz', 'Hauts-Plateaux', 'grande Ou ...
#
# {'Indes', 'Grossiste', 'Vrille', 'Damas', 'Arrimé', 'Reggae', 'Coulés', 'Tours', 'Systématique', 'Mentons', 'Celles', 'Aller', 'Valence', 'Winchester', 'Halte', 'Sacré', 'Tremper', 'Délavées', 'Fréquentables', 'Montrant', 'Mars', 'Lier', 'Réchappés', 'Anticléricaux', 'Horizons', 'Manie', 'Pont', 'Reviendront', 'Résonnent', 'Ramassée', 'Naguère', 'Distance', 'Hommes', 'Censés', 'Suis', 'Sud', 'Courront', 'Décolorées', 'Ivrogne', 'Garez', 'Hindou', 'Skiez', 'Veux', 'Pourrave', 'Fier', 'Hissez', 'Narbonne', 'Margoton', 'Tourne', 'Haine', 'Frapadingues', 'Expulser', 'Tailler', 'Connemara', 'Fourche', 'Dégela', 'Panama', 'Traversé', 'Montrez', 'Quimper', 'Murmura', 'Sparte', 'Rêva', 'Puces', 'Camargue', 'Servile', "N'", 'Connais', 'Déchanter', 'Bourse', 'Opéra', 'Gaîté', 'Prusse', 'Mystifié', 'Monté', 'Vaux', 'Réquisition', 'Futile', 'Berlin', 'Auvergne', 'Méditerranéenne', 'Délaisse', 'Raccourcissent', 'Embrase', 'Opaque', 'Bastilles', 'Taf', 'Bicêtre', 'Vatican', 'Redescends', 'Amasse', 'Seine', 'Mec', 'Ré', 'Dallas', 'Dessus', 'Frénétique', 'Les', 'Présumais', 'Badé', 'Toi', 'Bière', 'Pantin', 'Galette', 'Zigzag', 'Viens', 'Rajustant', 'Tiercé', 'Cogner', 'Promenant', 'Hexagone', 'Lové', 'Malpolis', 'Doubler', 'Guignol', 'Paparazzis', 'Schizophrénique', 'Reverra', 'Berçant', 'Onques', 'Tectonique', 'Miami', 'Manille', 'Sarcelles', 'Prés', 'Croule', 'Femelles', 'Arnaquer', 'Pas', 'Faisais', 'Monoï', 'Chouf', 'Monaco', 'Persuadés', 'Privées', 'Traîné', 'Dahu', 'République', 'Val', 'Chérie', 'Ait', 'Brésil', 'Direct', 'Faisanderie', 'Trouverais', 'Té', 'Lauriers', 'Métissée', 'Bourrez', 'Tarentelles', 'Malaise', 'Grandir', 'Coller', 'Pénétrer', 'Raclant', 'Funk', 'Pin', 'Mai', 'Blanche', 'Rendez', 'Vienne', 'Sceaux', 'Besoin', 'Piétinera', 'Couteront', 'Sorbonne', 'Faites', 'Essuyez', 'Va', 'Gap', 'Tracer', 'Électrolyse', 'Landerneau', 'Place', 'Confortant', 'Gratter', 'Ternaire', 'Renverse', 'Franchissant', 'Mesquins', 'Fit', 'States', 'Mutiler', 'Finis', 'Pensais', 'Excitait', 'Fatale', 'Maquillée', 'Darjeeling', 'Pile', 'Abjurant', 'Garderons', 'Méditerranée', 'Sues', 'Regardez', 'Mille', 'Funky', 'Terrée', 'Nice', 'Forcé', 'Bâillonné', 'Cache', 'Union', 'Quartiers', 'Reporter', 'Milliers', 'Close', 'Dé', 'Coutellerie', 'Coulent', 'Venez', 'Revenir', 'Alpha', 'Rio', 'Marjolaine', 'Macao', 'Beaujolais', 'Serein', 'Demeure', 'Menuets', 'Maires', 'Perpignan', 'Rencontra', 'Maharajas', 'Coca', 'Recto', 'Canal', 'Bas', 'Lever', 'Havres', 'Brille', 'Mu', 'Idéal', 'Séquencée', 'Lima', 'In', 'Bamboula', 'Métamorphoser', "T'", 'Tes', 'Venir', 'Parme', 'Bled', 'Vlan', 'Horde', 'Bagarreurs', 'Gelé', 'Dégun', 'Légère', 'Mali', 'Baskets', 'Robinet', 'Chinois', 'Résisté', 'Paris', 'Lune', 'Jetons', 'Flou', 'Tournoyante', 'Oxford', 'Porte', 'Pluton', 'Abusant', 'Instituteurs', 'Saturne', 'Tiens', 'Perdons', 'Petit', 'Bouger', 'Lendemain', 'Pied', 'Verrouillée', 'Inde', 'Berne', 'Frappe', 'Psychiatrisées', 'Briquer', 'Fonder', 'Torse', 'Flingue', 'Balade', 'Sereine', 'Montent', 'Arrêté', 'Relater', 'Fortifier', 'Ris', 'Ancrée', 'Baissant', 'Triangulaire', 'Chacal', 'As', 'Gare', 'Basta', 'Menton', 'Dont', 'Instrumental', 'Soit', 'Loulou', 'Sadique', 'Monter', 'Guérilla', 'Ternit', 'Angleterre', 'Cher', 'Chicanos', 'Mourez', 'Callipyge', 'Gardes', 'Mourra', 'Sonde', 'Pleure', 'Vernis', 'Mignonne', 'Gotha', 'Ca', 'Ternis', 'Pondus', 'Gasoil', 'Rouler', 'Mit', 'Décimées', 'Distille', 'Foutaises', 'Cévennes', 'Français', 'Hong', 'Test', 'Pic', 'Penchée', 'Rendre', 'Rosette', 'Calculer', 'Salle', 'Jubiler', 'Patriarche', 'Crin', 'Pactole', 'Chés', 'Fers', 'Pédé', 'Pou', 'Tranquilles', 'Sois', 'Incitation', 'Gaillarde', 'Zénith', 'Ter', 'Hambourg', 'Déversent', 'Sylphes', 'Étalonnée', 'Fac', 'Pleurer', 'Déplace', 'Pékin', 'Courbée', 'Western', 'Bordeaux', 'Gisait', 'Tifosi', 'Moulins', 'Rouen', 'Trop', 'Chine', 'Landes', 'Combien', 'Ligotée', 'Soyons', 'Traverse', 'Abyssale', 'Tortillant', 'Ponds', 'Zanzibar', 'E', 'Glocks', 'Épis', 'Où', 'Ouest', 'B ...
#
# nombre de lieux obtenu dans la liste finale :  886
# {'Grèce', 'They', "J'aurais pu me tendre et les prendre", 'Sur Digne', 'Treets', 'Même', 'Garges-Les-Gonesses', 'Avalon', 'Rue de la Soif', "Heureus'", "’ C'", "l'Amérique", 'Pondichéry', 'Le Renard', 'Villeneuve-Saint-Georges', 'Lorque', 'Égypte', 'Knicks', "Santiago T'", 'tour A', 'Belleville', 'rue des Saules Rue Saint-Vincent', 'Pyrex', 'Cavan', 'Mars Reléguant', 'Fort Greene', "ci N'", "l'Afrique", 'la Bastille', 'Nicaragua', 'pyramide Mets', 'Palestine', 'golfe du Lion Trempe', 'So', 'Ayato', 'Grossissait la Seine', 'Sévéso', "Boulevard de la Chapelle Sur un air d'eau d'javelle", 'ligne Maginot', 'Krasnodar', 'Bettancourt', 'Saint-Cloud', 'Ffu', 'Wana', "Paradis C't'", 'Tourcoing', 'Rasée la maison', 'Abyssinie', "Sainte-Mad'lein’", 'Nam yo', 'parking A', 'Dins', 'These', 'Tbilissi', 'Refrain]×2 A', 'cave Tu', 'Dignos', 'Nante', 'Pérou', 'Lerchechem', 'Eloigne toi Petite fille aux yeux perdus Tu', 'Saint-Eloi', 'AH AH AH', 'Paris-la-soumise', 'Géorgie', "J'ai dit", 'Akkad', 'Allemagne', 'Eux', 'Débilos', 'Istres', 'För', 'Eloigne toi Petite fille aux yeux perdus', 'Holiday Inn', 'Nent', 'Blaow', 'pont des Arts', 'Saint-Michel', "Phili' Quels", 'Catane', 'La Tour Montparnasse', 'Thèbes', 'du Nord', 'Monténégro', "J'aim'rais mieux mourir", 'Kévin', 'Reïf', 'Longjumeaux', 'Bhanghra de Katmandou', 'Golfe de Naples', 'cimes Squatteurs', 'Big Daddy', 'Ceylan', 'Danemark', 'Russie', "citadelle d'Ajaccio", 'Pervenches Ou', 'B.Boy', 'Irlande', 'London', 'Tolède', "Doiv'", 'Lachaise', 'Lololala', 'mer Libre', 'Indochine', 'Toulon', '‘Inti Fada', 'Dublin City', 'Tcherno', 'Suzon', 'mont Falù', 'Marny', 'Florence Rey', 'Emaciés', 'Miniloubarrivistes', 'Les rues', 'Avoriaz', 'La Canebière', 'rue Davso', 'rue Suzon', 'plaines A', 'ville Exorcise', 'Jehova', 'Bercy', 'Dublin', 'royaume des Hommes', 'Saint-Malo Fair', 'terre Père', 'Venise Où', 'Capoue', 'rue Blondel', "J'ai lu beaucoup de books certains", 'AH AH AH Regarde', 'planète Mars', 'Hanoï', 'Eperdu de bonheur', 'Pouc', 'Pays Basque', 'Fleury', 'Bhopal Yo !', 'fi France', 'Californie', 'N.Y.C.', 'Hier soir au', 'Pigalle', 'Loch Ness', 'Selecto', 'Land Bouteille cassée', 'Taj Mahal', 'Ffff', 'la Chine', 'Saint-Denis', "Corne d'Aurochs", 'Cap Canaveral', 'Byzance', 'l´église Histoire', 'Sardagne', 'Burkina', 'Vallée des Rois', 'Vénus Ris', 'Saint Patrick', 'Tolbiac', 'Cimetière Aguichant', 'Molly', 'Clamart', 'Rue du Vieux', 'Orphélie', "J'ai dit banco", 'Coudes serrés', "J'ai creusé un tunnel de 18 mètres de long J'ai atterri dans la cave d'une laiterie parisienne J'ai pris 300 carambars un kilo de madeleines", 'Atada', 'Medellin', "rue T'", 'Sublime Porte En grand Pour ta famille', "Convoit'", 'Nil', 'Amsterdam', 'Continúas serena Por', 'Cythère', 'Séville', 'Fort Green', 'gare de Lyon', 'Dépression', "N C'", 'Bastia', "Tre heureux C'", 'Passe la Heineken', 'Washington', 'Avignon', "J'ai vu les feuilles mortes des arbres", 'Amaloulous À cause de', 'la Mecque', 'M.I.C.', "Royaume Ming Pas d'apologie du Tchikipaw", "I'", 'Issara', 'Mortadan', 'Créteil', 'Atlanta', "Jardin d'Eden", 'Macumba', 'Hiroshima', 'Baptistain', 'Ouarzazate', 'Palerme', 'fortin Se', 'Lille Roubaix Tourcoing', "Medellin N'", 'Yo', "caverne d'Ali", 'Saint-Pétersbourg', 'Label 5', 'Honduras', 'Beaune', 'Couz’', 'Sugar Hill', 'Vänd', 'Taïwan', 'Telecom', 'Va caguer', 'Bien-aimées', 'Sans c\x9cur', 'Europe', "Rue d'Charonne", 'Bullshit', 'Pakistan', 'Silhouette insolite', "Ras l'bol des pizzerias", 'Lens', 'Où Naples', 'Two', 'Man?uvres', 'Mental de Viêt', 'Mongolie', 'B.H.V', 'Versailles', 'Nou terrils', 'Novotel Y', 'Nouméa', 'Lison', 'la Loire', 'Etna Mirage', 'Tarbes', 'Bangkok', "Bihac'", 'Echo', "l'Irlande", 'Népal', 'Salamanque', 'M?m', 'B52', 'A Saint-Sulpice', 'Poto', 'Bamako', 'Maldives', 'baby Blanche', 'Aix', 'Laponie', 'El Paso', 'C.O.B.de', 'la Courneuve', 'E1', 'Voil', 'Saint-Germain-des-Prés', 'bastrin- Gue', 'Houston', 'Chari Jazz', 'Hauts-Plateaux', 'grande Ourse', 'Camaret', 'Brooklyn', 'Re ...
#
# {'n´en', 'marée', 'l´au', 'c\x9cur', "you'", 'aper?u', 'bande du', 'gare de', 'obscurité', "croqu'-mort", 'porte de', 'place d’', "don'", '’', 'j´m´engueule'}

# %%
x = [1, 2, 3, 4]
y = [1492, 1442, 901, 886]
labels = ['lieux_lg', 'tri_1', 'tri_2', 'tri_3']

plt.plot(x, y)
# You can specify a rotation for the tick labels in degrees or with keywords.
plt.xticks(x, labels, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.2)
plt.title("Filtrage de l'échantillon2")
plt.ylabel("nombre de lieux")
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)
plt.show()
