# %%
import json
import time
from time import perf_counter

def ouvrir_json(chemin):
    f = open(chemin, encoding="utf-8")
    toto = json.load(f)
    f.close()
    return toto

def ecrire_json(chemin, contenu):
    w = open(chemin, "w", encoding="utf-8")
    w.write(json.dumps(contenu, indent=2, ensure_ascii=False))
    w.close()

# %%
import spacy
nlp_sm = spacy.load("fr_core_news_sm")
nlp_md = spacy.load("fr_core_news_md")
nlp_lg = spacy.load("fr_core_news_lg")

# %%
f1 = ouvrir_json("/Users/mustapha/Documents/GitHub/Memoire/clean_data_echantillons/clean_echantillon2.json")
f2 = ouvrir_json("/Users/mustapha/Documents/GitHub/Memoire/Data/voc_glaff.json")

# %%
start1 =time.perf_counter()
loc_sm=[]
for texte in f1:
    try:
        doc = nlp_sm(texte)
        for entity in doc.ents:
            if entity.label_ =="LOC":
                loc_sm.append(entity.text)
    except:
        pass
end1 =time.perf_counter()
ecrire_json("/Users/mustapha/Documents/GitHub/Memoire/lieux_echantillon_aprésNettoyage/lieux_echantillon2_aprésNettoyage_sm.json",loc_sm)
print("lieux trouvés par le modèle small : ",len(set(loc_sm)))
print(set(loc_sm))
print("temps :",end1-start1)
print()
print()

tri_1 = [mot for mot in loc_sm if mot not in f2]
test1 = [mot for mot in loc_sm if mot in f2]
print("nombre lieux qui ne se trouvent pas dans le Glaff : ", len(set(tri_1)))
print(set(tri_1))
print()
print(set(test1))
print()

tri_2 = [mot for mot in tri_1 if mot.lower() not in f2]
test2 = [mot for mot in tri_1 if mot.lower() in f2]
print("nombre lieux en miniscules qui ne se trouvent pas dans le Glaff : ",len(set(tri_2)))
print(set(tri_2))
print()
print(set(test2))
print()



tri_3 =[mot for mot in tri_2 if mot.lower() not in tri_2] 
test3 =set(tri_2).difference(tri_3)
print("nombre de lieux obtenu dans la liste finale : ", len(set(tri_3)))
print(set(tri_3))
print()
print(set(test3))
ecrire_json("/Users/mustapha/Documents/GitHub/Memoire/lieux_echantillon_aprésFiltrage/lieux_echantillon2_aprésFiltrage_sm.json",tri_3)
# Out:
# lieux trouvés par le modèle small :  1901
# {'Disneyland', 'Dieppe', 'Retiens', 'Stockholm', 'Aimeras', 'Wonderbra', 'Père', 'Ficelles', 'Rue Saint-Vincent', 'Sort', 'entr?e', 'Cube', 'Abyssinie', 'Issara', 'Sahel', 'Théophile', 'Pont musical]. Trop', 'Z.A.C. Sortie', 'Darjeeling', 'Pardonne', 'Partagés', 'Vénus', 'Lutem', 'Kerouac', 'Mars', 'Sample].', 'Gavroche', 'Charité', 'F', 'B.D.', 'Dinard', 'Sologne', 'Ceylan', 'Quartiers', 'Epoque', 'Nation', 'Forgé', 'Marilyn', 'New Jacks', 'Otelo', 'MC', 'Cordillère des Andes', "l'Olympia", 'Madagascar', 'Scratches', 'Bollywood', 'Velcros', 'Cha', 'Fume des Cohíbas', "l'Espagne", 'Philippines', 'Charon', 'Saint-Michel', 'Laver', 'Embrasse', 'Foi', 'Robbie', 'Moët', 'Starflash', 'Cicatrices', 'Dolto', 'Ajoutez', 'Débilos', 'Englois', 'Wallons', 'Atlanta', 'Ismaël', 'Lamborghini', 'Chemin', 'Malone', 'Hortens', 'Délavées', 'Séville', 'jardin des Tuileries', 'Couter', 'Thai', 'Alis', 'Connemara', 'Men', 'Tokyo', 'R12', 'Plaise', 'l’Espagne', 'Tolède', 'Sri Lanka', 'Paradis', 'vieux Priape', 'Cuando', 'Fermer', 'Café du Dôme', 'Allemagne', 'Knokke-le-Zoute', 'Camarades', 'Croire', 'Turc', 'Frappe', 'P38', 'Suze', 'Intro].', 'Egotrip', 'Inutile', 'HS', 'COMPLETER', 'Lordelebem', 'd’', 'Monaco', 'Mea Culpa', 'Savigny-sur-Orge', "l'Est", 'Tours', 'Renverse', 'Butte Rouge', 'Luberon', 'Livr', 'Toulon', 'Capdevielle', 'Lourdes', 'Caroline', 'Enrôlé', 'Meccano', 'Mexique', 'Marie-Lou', 'v’', 'Passeport', 'Goldman', 'Amsterdamère', 'Libérez', 'Écœuré', 'Béaba', 'Telecom', 'Pisseuse', 'musé’', 'Dédé-le-Surineur', 'Pattaya', 'M.I.C.', 'Savais', 'Pessah', 'Amérique', 'Berlin', 'Irlandais', 'Baltique', 'Ménilmontant', 'Saint-Mandé', 'Puisse', 'Criminosical Possee', 'cadeau du Père Noël !', 'Disney', 'Baileys', 'Excuse', 'Saint-Cloud', 'Bilbao', 'Indonésie', 'Rungis', 'Fastoche', 'belle de Mai', 'Mogador', 'St Vincent de Paul', 'jardin du Luxembourg', 'Grand Manitou', 'Intro]. C’', 'Santiago', 'Attiré', 'C.I.P.', '’Dites', 'Charonne', 'Gendes', 'Indochine', 'Opéra', 'Mal', 'Ferrat', 'Slamalekoum', 'Lavilliers', 'Atlantique', 'International', 'Oreste', 'Ou', 'Ouarzazate', 'Dijon', 'Prévenez', 'Indiens', 'Brrraque', 'Olé', 'Porions', 'Mesdames', 'Tchernobyl', 'Funk', 'Sire', 'Brille', "p'tit Montparnasse", 'cagoule du Ku-Klux', 'Onques', 'Européens', 'Élaboré mon', 'Robins des Bois', 'Allongés', 'Saint Ildefonse', 'Paladins', 'Repentez', 'Tsunami', 'BO', 'Africain', 'rue Pierre Charron', 'Quelquefois', 'Fredo', 'Amour', 'Morts', 'passerelle’', 'Sardagne', 'Ulster', 'Aïd', 'Appelle', 'Auront', 'gare de Bologne', 'Ravachol', "jardin d'Eden", 'Fermé', 'fumée', 'l’Est', 'Glocks', 'Eloigne', 'Pont Neuf je me gonflais', 'Stella', 'Abandonnée', 'Clignancourt', 'Bois', 'Humanitaire', 'Shit Squad', 'notre France', 'Renard', 'Gattaca', 'Bangladesh', 'Champs Elysées', 'Bietris', 'rose"].', 'Villeneuve-Saint-Georges', 'forêt de Fontainebleau', 'Monténégro', "Lil' Bow Wow", 'Istres', 'Couplet].', 'Désarticulé', 'Écris', 'Personnes', 'Manhattan', 'Rap Genius', 'Chicago', 'n’', 'Tagada', 'Luter', 'Bally', 'jardin du Bon Dieu', 'Créteil', 'Rue sombre', 'Maharajas', 'Aubervilliers', 'Colombie', 'Phocée', 'Regardes', 'Abeba', 'War Pride', 'rue Davso', 'Bali', 'Elysées', 'Détail', 'le Remington', 'Corse', "d'Espagne", 'Jauger', 'Philistins', 'notre Terre', 'Immonde', 'Machin', 'mer Rouge', 'BANG', 'Sharengton', 'Y', 'Pologne', '-Ouais', 'Belge', 'Momo', 'Livré', 'Hong', 'Sodi', "l'6.6.6", 'Cerveza', 'Loch Ness', 'Vienne', 'Chose', 'Pontoise', 'Sad hill', 'Ronds', 'Cap Canaveral', 'Chanteur', 'planète Terre', 'Raconte', 'Souviens', 'Gance', 'Tbilissi', 'Shit !', 'pont des Arts', 'Chargez', 'Regardez', 'Ordinaires', 'Saint-Pierre', 'Fuck', 'Fils', 'Faisanderie', 'Rabbins', 'Corniche', 'Closerie', 'm’', 'Bilal', 'Jérusalem', 'Playa', 'Chœur', 'Tomahawk', "île d'", 'Kenzo', 'N Chang', 'Açores', 'Medellin', 'Place Saint-Michel', 'Le Guide', 'Ibiza', 'Long Kesh', 'Parme', 'Nord-Est', 'Tommies', 'Posse', 'Barbe', 'Acerbe', 'Sumatra', 'Melopheelo', 'Mecque', 'Montfauco ...
# temps : 111.82845279100002
# nombre lieux qui ne se trouvent pas dans le Glaff :  1831
# {'Disneyland', 'Dieppe', 'Retiens', 'Stockholm', 'Aimeras', 'Wonderbra', 'Ficelles', 'Rue Saint-Vincent', 'Sort', 'entr?e', 'Cube', 'Abyssinie', 'Issara', 'Sahel', 'Théophile', 'Pont musical]. Trop', 'Z.A.C. Sortie', 'Darjeeling', 'Pardonne', 'Partagés', 'Vénus', 'Lutem', 'Kerouac', 'Mars', 'Sample].', 'Gavroche', 'Charité', 'F', 'B.D.', 'Dinard', 'Sologne', 'Ceylan', 'Quartiers', 'Epoque', 'Nation', 'Forgé', 'Marilyn', 'New Jacks', 'Otelo', 'Cordillère des Andes', "l'Olympia", 'Madagascar', 'Scratches', 'Bollywood', 'Velcros', 'Cha', 'Fume des Cohíbas', "l'Espagne", 'Philippines', 'Charon', 'Saint-Michel', 'Laver', 'Embrasse', 'Foi', 'Robbie', 'Moët', 'Starflash', 'Cicatrices', 'Dolto', 'Ajoutez', 'Débilos', 'Englois', 'Atlanta', 'Ismaël', 'Lamborghini', 'Chemin', 'Malone', 'Hortens', 'Délavées', 'Séville', 'jardin des Tuileries', 'Couter', 'Thai', 'Alis', 'Connemara', 'Men', 'Tokyo', 'R12', 'Plaise', 'l’Espagne', 'Tolède', 'Sri Lanka', 'Paradis', 'vieux Priape', 'Cuando', 'Fermer', 'Café du Dôme', 'Allemagne', 'Knokke-le-Zoute', 'Camarades', 'Croire', 'Frappe', 'P38', 'Suze', 'Intro].', 'Egotrip', 'Inutile', 'HS', 'COMPLETER', 'Lordelebem', 'd’', 'Monaco', 'Mea Culpa', 'Savigny-sur-Orge', "l'Est", 'Tours', 'Renverse', 'Butte Rouge', 'Luberon', 'Livr', 'Toulon', 'Capdevielle', 'Lourdes', 'Caroline', 'Enrôlé', 'Mexique', 'Marie-Lou', 'v’', 'Passeport', 'Goldman', 'Amsterdamère', 'Libérez', 'Écœuré', 'Béaba', 'Telecom', 'Pisseuse', 'musé’', 'Dédé-le-Surineur', 'Pattaya', 'M.I.C.', 'Savais', 'Pessah', 'Amérique', 'Berlin', 'Irlandais', 'Baltique', 'Ménilmontant', 'Saint-Mandé', 'Puisse', 'Criminosical Possee', 'cadeau du Père Noël !', 'Disney', 'Baileys', 'Excuse', 'Saint-Cloud', 'Bilbao', 'Indonésie', 'Rungis', 'Fastoche', 'belle de Mai', 'Mogador', 'St Vincent de Paul', 'jardin du Luxembourg', 'Grand Manitou', 'Intro]. C’', 'Santiago', 'Attiré', 'C.I.P.', '’Dites', 'Charonne', 'Gendes', 'Indochine', 'Opéra', 'Mal', 'Ferrat', 'Slamalekoum', 'Lavilliers', 'Atlantique', 'International', 'Oreste', 'Ou', 'Ouarzazate', 'Dijon', 'Prévenez', 'Brrraque', 'Olé', 'Porions', 'Mesdames', 'Tchernobyl', 'Funk', 'Sire', 'Brille', "p'tit Montparnasse", 'cagoule du Ku-Klux', 'Onques', 'Élaboré mon', 'Robins des Bois', 'Allongés', 'Saint Ildefonse', 'Paladins', 'Repentez', 'Tsunami', 'rue Pierre Charron', 'Quelquefois', 'Fredo', 'Amour', 'Morts', 'passerelle’', 'Sardagne', 'Ulster', 'Appelle', 'Auront', 'gare de Bologne', 'Ravachol', "jardin d'Eden", 'Fermé', 'fumée', 'l’Est', 'Glocks', 'Eloigne', 'Pont Neuf je me gonflais', 'Stella', 'Abandonnée', 'Clignancourt', 'Bois', 'Humanitaire', 'Shit Squad', 'notre France', 'Renard', 'Gattaca', 'Bangladesh', 'Champs Elysées', 'Bietris', 'rose"].', 'Villeneuve-Saint-Georges', 'forêt de Fontainebleau', 'Monténégro', "Lil' Bow Wow", 'Istres', 'Couplet].', 'Désarticulé', 'Écris', 'Personnes', 'Manhattan', 'Rap Genius', 'Chicago', 'n’', 'Tagada', 'Luter', 'Bally', 'jardin du Bon Dieu', 'Créteil', 'Rue sombre', 'Maharajas', 'Aubervilliers', 'Colombie', 'Phocée', 'Regardes', 'Abeba', 'War Pride', 'rue Davso', 'Bali', 'Elysées', 'Détail', 'le Remington', "d'Espagne", 'Jauger', 'notre Terre', 'Immonde', 'Machin', 'mer Rouge', 'BANG', 'Sharengton', 'Y', 'Pologne', '-Ouais', 'Momo', 'Livré', 'Hong', 'Sodi', "l'6.6.6", 'Cerveza', 'Loch Ness', 'Vienne', 'Chose', 'Sad hill', 'Ronds', 'Cap Canaveral', 'Chanteur', 'planète Terre', 'Raconte', 'Souviens', 'Gance', 'Tbilissi', 'Shit !', 'pont des Arts', 'Chargez', 'Regardez', 'Ordinaires', 'Saint-Pierre', 'Fuck', 'Fils', 'Faisanderie', 'Rabbins', 'Corniche', 'Closerie', 'm’', 'Bilal', 'Jérusalem', 'Playa', 'Chœur', 'Tomahawk', "île d'", 'Kenzo', 'N Chang', 'Açores', 'Medellin', 'Place Saint-Michel', 'Le Guide', 'Ibiza', 'Long Kesh', 'Parme', 'Nord-Est', 'Tommies', 'Posse', 'Barbe', 'Acerbe', 'Sumatra', 'Melopheelo', 'Mecque', 'Montfaucon', 'Miroir', 'Sorbonne', 'République', 'Bagdad', 'Papier', 'Clichy', 'Dublin', 'Sylvie', 'Court', 'Quartier', 'Ouganda', 'Sofia', 'Miami ...
#
# {'Pontoise', 'N', 'Meccano', 'Porto', 'Babylone', 'Cologne', 'Indiens', 'Indien', 'VO', 'Danoise', 'Indiennes', 'MC', 'Lorraine', 'Montana', 'Occident', 'C', 'Wallons', 'Balance', 'Père', 'Catalane', 'Turc', 'Thaïs', 'Basques', 'Corses', 'Touraine', 'Chouette', 'Aryenne', 'Bretons', 'Gauloises', 'QI', 'Corse', 'Suisse', 'Américains', 'PV', 'Bleue', 'Philistins', 'Panthéon', 'Bengale', 'Européens', 'Allemands', 'Martiens', 'G', 'Ricains', 'B', 'Germaine', 'BO', 'Africain', 'Allemand', 'Beau', 'Noire', 'Abruzzes', 'Cheyenne', 'Belle', 'Alsaciens', 'Belge', 'Parisienne', 'Eucharistie', 'KO', 'Parisien', 'CP', 'Phocéens', 'Est', 'Lucien', 'État', 'MCs', 'L', 'Aïd', 'Argentine', 'Renaissance', 'Suisses'}
# nombre lieux en miniscules qui ne se trouvent pas dans le Glaff :  1108
# {'Empty', 'du Sud', 'Sambre-et-Meuse', 'Chhht', 'Tipaza', 'Dieppe', 'Disneyland', 'Stockholm', 'Zembla', 'Wonderbra', 'Achinan', 'jardin d’Eden', 'pont Mirabeau', 'Lille', 'Amway', 'Le Renard', 'Dalida', 'grande Bretagne', 'Rue Saint-Vincent', 'entr?e', 'Sentenza', 'Clemenceau', 'BN', 'Budapest', 'Abyssinie', 'Man?uvres', 'Tokarev', 'Quito', 'Issara', 'Morrison', 'La Rochelle', 'Grèce', 'Faubourg-Saint-Honoré', 'Népal', "Jardin d'Eden", 'New York', 'Apprinds', 'Saint-Malo', 'Dj Daz', 'la Rotonde', 'Listen', 'Lipstick', 'Londres', 'Grand Plazza', 'Théophile', 'Rue du Vieux Colombier', 'Mental de Viêt-Cong', 'Sodome et Gomorrhe', 'Pont musical]. Trop', 'Z.A.C. Sortie', 'Sandrine', "Intro]. Bons baisers d'Mars", 'es du Vatican', 'J.M.', 'Lutem', 'Kerouac', 'Robins des Bois', 'Sample].', 'Gavroche', 'B.D.', 'F', 'Dinard', 'Perriers', 'Haïkku', 'la Pologne', 'Sologne', 'toi Colombe', 'Lacroix', 'Nil', 'Goa', 'Ceylan', 'M16', 'Brest', 'Epoque', 'Marilyn', 'New Jacks', 'Otelo', 'Cordillère des Andes', 'Finistère', 'Meuse', 'Montfavet', 'VC', "l'Olympia", 'Puerta', 'Madagascar', 'Pondichéry', 'Montmertre', 'golfe de Tchernobyl', 'Maradona', 'métro Saint Michel', 'Tour Magne', 'Bollywood', 'Iblis', 'Brazza', 'Arabie', 'l’Etna', 'Akhti', 'Cha', 'Éthiopie', 'Twix', 'Ricard', 'Eternel', 'Fume des Cohíbas', "l'Espagne", 'Elaborates', 'Irak', 'Charon', 'n´ai', 'B.J', 'Honduras', 'Saint-Michel', 'La Courneuve', "pas d'Anglaises", 'L?-l?-l', 'Vem', 'Arc-en-Ciel', 'Hanoï', 'Storm', 'Ayato', 'Les Affranchis', 'Californie', 'Independenza', 'Ginette', 'Saint-Tropez', 'La France', 'Courrèges', 'la Seine', 'Rex', 'Dieu!.', 'Prodigal Sunn', 'Robbie', 'Moët', 'L`Europe', 'Piennes', 'Starflash', 'Sète', 'Crozemarie', 'Lievin', 'Angers', 'Ycon', 'Dolto', 'from Rennes', 'Malek', 'Rue Descartes', 'Bettancourt', 'H.L.M.', 'Aid', 'Débilos', 'Englois', 'golfe du Lion', 'Colorado', 'Atlanta', 'jean’', 'Marseille c’', 'Saint-Jean', 'Vietnam', 'Ismaël', 'Serai Orly', 'Italie', 'Dominique', 'Bab El Oued', 'Boulevard Barbes', 'Lamborghini', 'Bamako', 'Prague', 'Malone', 'Häagen', 'cœ\x9cur', 'Hortens', 'Bhopal', 'Séville', 'Byzance', 'z´en', 'de France', 'Bagneux', 'Marsala', 'Eille', 'Yanis', 'Pont 1].', 'Thai', "viaduc d'Auteuil", 'Alis', 'Sugar Hill', 'antiquit?s', 'Greenwitch Village', 'Louisiane', 'Ness', 'Men', 'Tokyo', 'Quartier Nord', 'Pylade', 'Babel', 'Heineken', 'R12', 'Krivine', 'Teresa', 'Budweiser', 'Triumph', 'l’Espagne', 'Darren', 'Tolède', 'Médine', 'Sri Lanka', 'Viandox', 'Kanaky', 'Macumba', 'Delano', 'Evangile', 'vieux Priape', 'Côtes-du-Rhône', 'Cuando', 'cordillère des Andes', 'François', 'Play-Boy', 'la Pravda', 'Singapour', 'Plaza', 'Bultex', 'Café du Dôme', 'Allemagne', 'Kader', 'Omotesandō', 'Vallée des Rois', 'New Orléans', 'Mont Royal', 'Villette', "Bud'", 'Rue de la Soif', 'Knokke-le-Zoute', '”', 'P38', 'Nabil', 'Bibi-la-Purée', 'Intro].', 'London', 'Egotrip', 'Suze', "l'Europe", 'HS', 'COMPLETER', 'Taïwan', 'vieux Gavroche', 'rue du Four', 'Lordelebem', 'd’', 'Parisien Libéré', "l'Afrique", 'Majax', 'He', 'Tour Montparnasse', 'Daz', 'Atada', 'Guide du Routard', 'Ajaccio', 'Mea Culpa', 'Rience', 'Palestine', 'Savigny-sur-Orge', 'Goose', "l'Est", 'MoMA', "Kro'", 'Butte Rouge', 'He’', 'Luberon', 'Livr', 'Toulon', 'j’', 'du Nord', 'Aragon', 'Miners', 'Outro].', 'Knacki', 'Capdevielle', 'Sheitan', 'Ziza', 'Mont Falu', 'Tri-Nitro-Toluène', 'Mojze', 'Moyen-âge', 'Ça', 'Mexique', 'Marny', 'Mougeotte', 'Marie-Lou', 'Fort Green', 'Thiais', 'v’', 'Scudetto', 'Molly', 'Mulholland Drive', 'Lac Lancelot', 'Goldman', 'Amsterdamère', 'Brabus', 'Evêché', 'Deuch', 'chichon\u2005', 'F.M.', 'Ruth', 'Hold', 'Telecom', 'Lens', 'Capoue', 'Ebola', 'musé’', 'Dédé-le-Surineur', "autoroute Porte d'Orléans", 'Bretagne', 'Pattaya', 'Gambetta', 'Elsa', 'Archipiades', 'M.I.C.', 'Lac Salé', 'Pessah', 'C.I.A. Sont', 'Woody', 'Europe', 'Zulu', 'Esmeralada', 'Amérique', 'Occitants', 'I', 'Aix', 'Ménilmontant', 'Tcherno', 'Saint-Mandé', 'Concidence', 'vieux Corneille ...
#
# {'Pleure', 'Distance', 'Tifosi', 'Voltigeur', 'Tendu', 'Retiens', 'Aimeras', 'Allergique', 'Souvenez', 'Pondus', 'Tuileries', 'Ficelles', 'Barbarie', 'Badé', 'Avez', 'Bravo', 'Chante', 'Sort', 'Cube', 'Ola', 'Sahel', 'Genoux', 'Ivrogne', 'Tresse', 'Casino', 'Lever', 'Enfoiré', 'Pouvais', 'Merde', 'Pense', 'Vieux', 'Entends', 'Darjeeling', 'Pardonne', 'Partagés', 'Vénus', 'Mars', 'Bastille', 'Dites', 'Charité', 'Pactole', 'Gasoil', 'Jalouse', 'Faucheuse', 'Tombeau', 'Rital', 'Ouest', 'Quartiers', 'Nation', 'Bénie', 'Forgé', 'As', 'Bosse', 'Telle', 'Scratches', 'Golf', 'Restez', 'Magique', 'Pénétrer', 'Règle', 'Velcros', 'Loulou', 'Roulerez', 'Balaises', 'Volailles', 'Close', 'Rendre', 'Faunes', 'Direct', 'Philippines', 'Cévennes', 'Authentique', 'Titi', 'Block', 'Sylphes', 'Essuyez', 'Laver', 'Flagada', 'Embrasse', 'Méditerranée', 'Manœuvres', 'Foi', 'Concédons', 'Damas', 'Union', 'Laisse', 'Brésil', 'Pentagone', 'Stresse', 'Cicatrices', 'Crin', 'Pâle', 'Redescends', 'Fraternité', 'Ajoutez', 'Écoutez', 'Cherchez', 'Picon', 'Bestial', 'Merveilleux', 'Chemin', 'Propre', 'Canebière', 'Pages', 'Perdus', 'Lève', 'Pareille', 'Délavées', 'Rapper', 'Import', 'Couter', 'Ca', 'Tchatche', 'Connemara', 'Déploie', 'Takana', 'Blonds', 'Cocagne', 'Aigris', 'Plaise', 'Grand', 'Comanches', 'Graines', 'Aimerais', 'Nice', 'Paradis', 'Pantin', 'Fermer', 'Morte', 'Zénith', 'Brigue', 'Barracuda', 'Chanta', 'Tourne', 'Gardien', 'Camarades', 'Croire', 'Dansez', 'Frappe', 'Bingo', 'Inutile', 'Papa', 'Bonjour', 'In', 'Premier', 'Monaco', 'Perçois', 'Champs', 'Gentilshommes', 'Casa', 'Traînez', 'Verrouillée', 'Avait', 'Ponds', 'Tours', 'Renverse', 'Afros', 'Arrache', 'Régie', 'Brûle', 'Iles', 'Lulu', 'Lourdes', 'Caroline', 'Fausse', 'Enrôlé', 'Accepta', 'Blanche', 'Striée', 'Pondais', 'Errer', 'Passeport', 'Foutez', 'Spirituel', 'Pékin', 'Électrolyse', 'Enchaîné', 'Mai', 'Boules', 'Buttes', 'Libérez', 'Invité', 'Te', 'Poètes', 'Jasmin', 'Mourra', 'Écœuré', 'Béaba', 'Aimes', 'Méditerranéenne', 'Désolé', 'Mignonne', 'Assassin', 'Fasse', 'Cliquez', 'Cartouche', 'Maroc', 'Niger', 'Pisseuse', 'Triangulaire', 'Ter', 'Mettez', 'Costes', 'Savais', 'Emporte', 'Larmes', 'Chine', 'Robinet', 'Berlin', 'Vagabonds', 'Baltique', 'Irlandais', 'Fréquentables', 'Puisse', 'Boulettes', 'Provoqué', 'Guérilla', 'Grandir', 'Terminus', 'Excuse', 'Moulin', 'Venez', 'Pastis', 'Yang', 'Carême', 'Margoton', 'Fastoche', 'Once', 'Faire', 'Prends', 'Fatigué', 'Braves', 'Lin', 'Accepte', 'Manille', 'Coutellerie', 'Mourir', 'Cliché', 'Attiré', 'Chili', 'Mémo', 'Opéra', 'Lampistes', 'Trouille', 'Mal', 'Oublie', 'Côte', 'Épouvantail', 'Vlan', 'Mimi', 'Attirés', 'Verso', 'Malik', 'Comprends', 'Expédie', 'Atlantique', 'International', 'Bastilles', 'Bilan', 'Ou', 'Taf', 'Madone', 'Féria', 'Prévenez', 'Quel', 'Grenade', 'Femmes', 'Géantes', 'Lise', 'Porions', 'Mercure', 'Veut', 'Conservons', 'Paris', 'Tiens', 'Rio', 'Funky', 'Vrille', 'Volez', 'Funk', 'Sire', 'Brille', 'Mise', 'Lilliputiens', 'Attaque', 'Val', 'Don', 'Onques', 'Fatma', 'Allongés', 'Paladins', 'Repentez', 'Tsunami', 'Graff', 'Vrai', 'Deviens', 'Éteignez', 'Quelquefois', 'Pétales', 'Pourrais', 'Coupole', 'Amour', 'Obscure', 'Genre', 'Morts', 'Pin', 'Redoute', 'Crois', 'Terre', 'Canal', 'Vive', 'Sois', 'Ulster', 'Appelle', 'Systématique', 'Rires', 'Hindou', 'Auront', 'Chacal', 'Zanzibar', 'Serais', 'Fermé', 'Nègre', 'Auvergne', 'Sereine', 'Micro', 'PE', 'Prusse', 'Sales', 'Laquelle', 'Glocks', 'Majorette', 'Règne', 'Concept', 'Attablé', 'Croix', 'Scarabée', 'Boom', 'Pénélope', 'Sache', 'Moiti', 'Bac', 'Panier', 'Soleil', 'Gestes', 'Abandonnée', 'Flora', 'Pluton', 'Travers', 'Taciturne', 'Polo', 'Accrochées', 'Assis', 'Semble', 'Bois', 'Va', 'Sobre', 'Mirage', 'Tousse', 'Psychiatrisées', 'Humanitaire', 'Traverse', 'Renard', 'Sceaux', 'Seraient', 'Coca', 'Pensais', 'Mollah', 'Refrain', 'Menuets', 'Bushido', 'Marjolaine', 'Mademoiselle', 'Pont', 'Peintures', 'Hargne', 'Butte', 'Perpignan', 'Cher', 'Désarticulé', 'Écris', 'Nord', 'C ...
#
# nombre de lieux obtenu dans la liste finale :  1041
# {'Empty', 'du Sud', 'Sambre-et-Meuse', 'Chhht', 'Tipaza', 'Dieppe', 'Disneyland', 'Stockholm', 'Zembla', 'Wonderbra', 'Achinan', 'jardin d’Eden', 'pont Mirabeau', 'Lille', 'Amway', 'Le Renard', 'Dalida', 'grande Bretagne', 'Rue Saint-Vincent', 'Sentenza', 'BN', 'Clemenceau', 'Budapest', 'Abyssinie', 'Man?uvres', 'Tokarev', 'Quito', 'Issara', 'Morrison', 'La Rochelle', 'Grèce', 'Faubourg-Saint-Honoré', 'Népal', "Jardin d'Eden", 'New York', 'Apprinds', 'Saint-Malo', 'Dj Daz', 'la Rotonde', 'Listen', 'Lipstick', 'Londres', 'Grand Plazza', 'Théophile', 'Rue du Vieux Colombier', 'Mental de Viêt-Cong', 'Sodome et Gomorrhe', 'Pont musical]. Trop', 'Z.A.C. Sortie', 'Sandrine', "Intro]. Bons baisers d'Mars", 'es du Vatican', 'J.M.', 'Lutem', 'Kerouac', 'Sample].', 'Gavroche', 'B.D.', 'F', 'Dinard', 'Perriers', 'Haïkku', 'la Pologne', 'Sologne', 'toi Colombe', 'Lacroix', 'Nil', 'Goa', 'Ceylan', 'M16', 'Brest', 'Epoque', 'Marilyn', 'New Jacks', 'Otelo', 'Cordillère des Andes', 'Finistère', 'Meuse', 'Montfavet', 'VC', "l'Olympia", 'Puerta', 'Madagascar', 'Pondichéry', 'Montmertre', 'golfe de Tchernobyl', 'Maradona', 'métro Saint Michel', 'Tour Magne', 'Bollywood', 'Iblis', 'Brazza', 'Arabie', 'l’Etna', 'Akhti', 'Cha', 'Éthiopie', 'Twix', 'Ricard', 'Eternel', 'Fume des Cohíbas', "l'Espagne", 'Elaborates', 'Irak', 'Charon', 'La Courneuve', 'B.J', 'Honduras', 'Saint-Michel', "pas d'Anglaises", 'L?-l?-l', 'Vem', 'Arc-en-Ciel', 'Hanoï', 'Storm', 'Ayato', 'Les Affranchis', 'Californie', 'Independenza', 'Ginette', 'Saint-Tropez', 'La France', 'Courrèges', 'la Seine', 'Rex', 'Dieu!.', 'Prodigal Sunn', 'Robbie', 'Moët', 'L`Europe', 'Piennes', 'Starflash', 'Sète', 'Crozemarie', 'Lievin', 'Angers', 'Ycon', 'Dolto', 'from Rennes', 'Malek', 'Rue Descartes', 'Bettancourt', 'H.L.M.', 'Aid', 'Débilos', 'Englois', 'golfe du Lion', 'Colorado', 'Atlanta', 'Marseille c’', 'Saint-Jean', 'Vietnam', 'Ismaël', 'Serai Orly', 'Italie', 'Dominique', 'Bab El Oued', 'Boulevard Barbes', 'Lamborghini', 'Bamako', 'Prague', 'Malone', 'Häagen', 'Hortens', 'Bhopal', 'Séville', 'Byzance', 'de France', 'Bagneux', 'Marsala', 'Eille', 'Yanis', 'Pont 1].', 'Thai', "viaduc d'Auteuil", 'Alis', 'Sugar Hill', 'jardin des Tuileries', 'Greenwitch Village', 'Louisiane', 'Ness', 'Men', 'Tokyo', 'Quartier Nord', 'Pylade', 'Babel', 'Heineken', 'R12', 'Krivine', 'Teresa', 'Budweiser', 'Triumph', 'l’Espagne', 'Darren', 'Tolède', 'Médine', 'Sri Lanka', 'Viandox', 'Kanaky', 'Macumba', 'Delano', 'Evangile', 'vieux Priape', 'Côtes-du-Rhône', 'Cuando', 'cordillère des Andes', 'François', 'Play-Boy', 'la Pravda', 'Singapour', 'Plaza', 'Bultex', 'Café du Dôme', 'Allemagne', 'Kader', 'Omotesandō', 'Vallée des Rois', 'New Orléans', 'Mont Royal', 'Villette', "Bud'", 'Rue de la Soif', 'Knokke-le-Zoute', 'P38', 'Nabil', 'Bibi-la-Purée', 'Intro].', 'London', 'Egotrip', 'Suze', "l'Europe", 'HS', 'COMPLETER', 'Taïwan', 'vieux Gavroche', 'rue du Four', 'Lordelebem', 'Parisien Libéré', "l'Afrique", 'Majax', 'He', 'Tour Montparnasse', 'Daz', 'Atada', 'Guide du Routard', 'Ajaccio', 'Mea Culpa', 'Rience', 'Palestine', 'Savigny-sur-Orge', 'Goose', "l'Est", 'MoMA', "Kro'", 'Butte Rouge', 'Luberon', 'Livr', 'Toulon', 'du Nord', 'Aragon', 'Miners', 'Outro].', 'Knacki', 'Capdevielle', 'Sheitan', 'Ziza', 'Mont Falu', 'Tri-Nitro-Toluène', 'Mojze', 'Moyen-âge', 'Ça', 'Mexique', 'Marny', 'Mougeotte', 'Marie-Lou', 'Fort Green', 'Thiais', 'Scudetto', 'Molly', 'Mulholland Drive', 'Lac Lancelot', 'Goldman', 'Amsterdamère', 'Brabus', 'Evêché', 'Deuch', 'F.M.', 'Ruth', 'Hold', 'Telecom', 'Lens', 'Capoue', 'Ebola', 'Dédé-le-Surineur', "autoroute Porte d'Orléans", 'Bretagne', 'Pattaya', 'Gambetta', 'Elsa', 'Archipiades', 'M.I.C.', 'Lac Salé', 'Pessah', 'C.I.A. Sont', 'Woody', 'Europe', 'Zulu', 'Esmeralada', 'Amérique', 'Occitants', 'I', 'Aix', 'Ménilmontant', 'Tcherno', 'Saint-Mandé', 'Concidence', 'vieux Corneille', 'Hôtel de Russie', 'Criminosical Possee', 'tour Magne', 'Re', 'cadeau du Père Noël !', 'Disney', 'R 16', 'Dea ...
#
# {'pas!.', 'c\x9cur', "aim'", 'v’', "tit'", 'raclée', 'fin!.', 'blas?s', 'rose"].', 'con!.', 'N’', 'L’', 'chichon\u2005', 'jean’', 'entr?e', 'C’t’', "see'", 'feu!.', 'musé’', 'z´en', 't´es', 'n’', 'cœ\x9cur', 'qu’', 'antiquit?s', "vid'", 'm’', 'passerelle’', 'fascin?s', 'pays n’', 'brouillard.;.', 'forêts', 'tarpé.', 'béton gris', 'he’', 'T’', 'autr’', "île d'", 'fumée', 'purée', 'sacré’', 't’', '”', 'op?ras', 'télé.', 'd’', 'lit!.', 'l’', '’', 'ciel!.', 'enti?re', 'aper?u', 'j’t’', 'n´ai', 'marée', 'l´au', 'c’', '\x93', 'cieux\u2005', "l'6.6.6", 'He’', 'c’t’', 'j’', 'héroïne', "don'", 'l`alphabet', 'année'}

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1901, 1831, 1108, 1041]
labels = ['lieux_sm', 'tri_1', 'tri_2', 'tri_3']

plt.plot(x, y)
# You can specify a rotation for the tick labels in degrees or with keywords.
plt.xticks(x, labels, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.2)
plt.title("Filtrage de l'échantillon2")
plt.ylabel("nombre de lieux")
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)
plt.show()

# %%
start2 =time.perf_counter()
loc_md=[]
for texte in f1:
    try:
        doc = nlp_md(texte)
        for entity in doc.ents:
            if entity.label_ =="LOC":
                loc_md.append(entity.text)
    except:
        pass
end2 =time.perf_counter()

ecrire_json("/Users/mustapha/Documents/GitHub/Memoire/lieux_echantillon_aprésNettoyage/lieux_echantillon2_aprésNettoyage_md.json",loc_md)
print("lieux trouvés par le modèle medium : ",len(set(loc_md)))
print(set(loc_md))
print("temps :",end2-start2)
print()
print()

tri_1 = [mot for mot in loc_md if mot not in f2]
test1 = [mot for mot in loc_md if mot in f2]
print("nombre lieux qui ne se trouvent pas dans le Glaff : ", len(set(tri_1)))
print(set(tri_1))
print()
print(set(test1))
print()

tri_2 = [mot for mot in tri_1 if mot.lower() not in f2]
test2 = [mot for mot in tri_1 if mot.lower() in f2]
print("nombre lieux en miniscules qui ne se trouvent pas dans le Glaff : ",len(set(tri_2)))
print(set(tri_2))
print()
print(set(test2))
print()



tri_3 =[mot for mot in tri_2 if mot.lower() not in tri_2] 
test3 =set(tri_2).difference(tri_3)
print("nombre de lieux obtenu dans la liste finale : ", len(set(tri_3)))
print(set(tri_3))
print()
print(set(test3))
ecrire_json("/Users/mustapha/Documents/GitHub/Memoire/lieux_echantillon_aprésFiltrage/lieux_echantillon2_aprésFiltrage_md.json",tri_3)
# Out:
# lieux trouvés par le modèle medium :  1424
# {'Berçant', 'avenue Foch', 'Disneyland', 'Dieppe', 'Freeman]. Rogaye', 'Retiens', 'Issara].', 'Stockholm', 'Wonderbra', 'Père', 'Ficelles', 'Rue Saint-Vincent', 'Heaven', 'entr?e', 'Abyssinie', 'Issara', 'Sahel', 'Darjeeling', 'Vénus', 'Mars', 'Sample].', 'F', 'Lolito', 'Dinard', 'Sologne', 'Ceylan', 'Quartiers', 'Nation', 'balanc?e', 'Marilyn', 'Firmament', 'New Jacks', "pont d'Avignon", 'MC', 'Cordillère des Andes', 'Refrain]. Tape', "l'Olympia", 'Es', 'Madagascar', 'Harangues', 'Scratches', 'Décolorées', 'Division', 'Bollywood', "l'Espagne", 'Fume des Cohíbas', 'Kung', 'Philippines', 'Charon', 'Saint-Michel', 'la Mecque', 'Patrie', "emm'na", 'U.S.A.', 'Débilos', 'Wallons', 'Foutaises', 'Atlanta', 'Chemin', 'Hortens', 'Délavées', 'Séville', 'jardin des Tuileries', 'Alis', 'Connemara', 'Tokyo', 'Vre', 'l’Espagne', 'El Pais', 'Tolède', 'Sri Lanka', 'Lucas', 'Paradis', 'Bacchus', 'Pigeot', 'Café du Dôme', 'Allemagne', "cor'", 'Knokke-le-Zoute', 'Tectonique', 'Qu´il', 'Belles', 'Turc', 'Frappe', 'Suze', 'Intro].', 'Monaco', 'Golfe', 'Savigny-sur-Orge', "l'Est", 'RapGenius France', 'Tours', 'rue de Vanves', 'Butte Rouge', 'Toulon', 'Lourdes', 'Caroline', 'Camaret', 'Mexique', 'Brute', 'Égyptiens', 'Akhnaton].', 'Telecom', 'Western', 'Dédé-le-Surineur', 'Pattaya', 'Amérique', 'Berlin', 'Irlandais', 'Baltique', 'Ménilmontant', 'Saint-Mandé', 'Criminosical Possee', 'Refrain].', 'Pal', 'Disney', 'Saint-Cloud', 'Bilbao', 'Indonésie', 'Rungis', 'Fastoche', 'Mogador', 'St Vincent de Paul', 'jardin du Luxembourg', 'Chapo', 'Grand Manitou', 'Santiago', 'Charonne', 'Gendes', 'Indochine', 'Opéra', 'Lavilliers', 'Atlantique', 'Beauvau', 'Ouarzazate', 'Cigarillo', 'Denfert', 'Dijon', 'Montesquiou', 'Indiens', 'Olé', 'Porions', 'Initiales', 'La Seine', 'Dés', 'Tchernobyl', 'Funk', 'Brille', 'Marchant', 'Onques', 'Européens', 'Coulent', 'Paladins', 'Mont', 'Tsunami', 'Africain', 'Amour', 'Sardagne', 'Endosser', 'Ulster', 'Aïd', 'gare de Bologne', "jardin d'Eden", 'l’Est', 'Sardane', 'Pont Neuf je me gonflais', 'Stella', 'Rochereau', 'Journaliste].', 'cools!.', 'Clignancourt', 'Bois', 'La Camarde', 'W', 'notre France', 'Bangladesh', 'Champs Elysées', 'Bietris', 'Recto', 'rose"].', 'Villeneuve-Saint-Georges', 'Gelé', 'forêt de Fontainebleau', 'A majuscule', 'Monténégro', "Lil' Bow Wow", 'Couplet].', 'Istres', 'Désarticulé', 'Manhattan', 'Tiercé', 'Refrain]×2', 'Chicago', 'Ressens', 'jardin du Bon Dieu', 'Créteil', 'Décimées', 'Maharajas', 'Ves', 'Aubervilliers', "Convoit'", 'Colombie', 'Phocée', 'Abeba', 'rue Davso', 'Supérieur', 'Nothing', 'Bali', 'Grâces', 'Chouf', 'Corse', "d'Espagne", 'notre Terre', 'Philistins', 'Immonde', 'mer Rouge', 'Sharengton', 'Pologne', 'Belge', 'Hong', 'Hissez', 'Loch Ness', 'Vienne', 'Chose', 'Pontoise', 'le M.I.C.', 'Cap Canaveral', 'planète Terre', 'porte de', 'c\x9coeur', 'Ris', 'Puces', 'Tbilissi', 'pont des Arts', 'Légère', 'Regardez', 'Bourbon', 'Cong', 'We', 'Saint-Pierre', 'Pou', 'Faisanderie', 'Corniche', 'Jérusalem', 'Lisieux', 'Playa', 'Nivea', "île d'", 'Kenzo', 'Açores', 'Medellin', 'Place Saint-Michel', 'Zamzam', 'Ibiza', 'Parme', 'Nord-Est', 'Tommies', 'Sumatra', 'Passe-moi', 'Montfaucon', 'Sorbonne', 'République', 'Bagdad', 'Malaise', 'Clichy', 'Dublin', 'Dame', 'Quartier', 'Ouganda', 'Sofia', 'Miami', 'gare de Lyon', 'Courbée', "aim'", 'Lola', 'New Balance', 'Saint-Germain-des-Près', 'Franchit', 'Himalaya', 'AIWA', 'Bicêtre', 'Tour Eiffel', 'Gitanes', 'Bud', 'Finlande', 'Lilas', 'quartier Latin', 'Monoï', 'El Paso', 'Couplet 2 - Uptown', 'Fac', 'Belges', "caverne d'Ali", 'Pakistan', 'Dag', 'Kodwa', 'Landes', 'Donx', 'Saintes-Maries', 'Harponnées', 'Freeman].', "Porte d'Italie", 'Cherche', "Parc'", 'Bogota', 'Akheanton].', 'Navrés', 'Franchir', 'Vénus de Milo', "Place de l'Horloge", 'Fleury', 'Provence', 'Meudon', 'Di', 'B52', 'Mali', 'Squad', 'H', 'Iéna', 'Lumière', 'Nam', 'Bonhomme', 'Jordanie', 'Valence', 'Imperial', 'Sumer', 'Auteuil', 'Fort Greene', 'Digne', 'Lerchechem', 'Vilnius', 'Pyrex', 'Ca ...
# temps : 86.88705845100003
# nombre lieux qui ne se trouvent pas dans le Glaff :  1357
# {'Berçant', 'avenue Foch', 'Disneyland', 'Dieppe', 'Freeman]. Rogaye', 'Retiens', 'Issara].', 'Stockholm', 'Wonderbra', 'Ficelles', 'Rue Saint-Vincent', 'Heaven', 'entr?e', 'Abyssinie', 'Issara', 'Sahel', 'Darjeeling', 'Vénus', 'Mars', 'Sample].', 'F', 'Lolito', 'Dinard', 'Sologne', 'Ceylan', 'Quartiers', 'Nation', 'balanc?e', 'Marilyn', 'Firmament', 'New Jacks', "pont d'Avignon", 'Cordillère des Andes', 'Refrain]. Tape', "l'Olympia", 'Es', 'Madagascar', 'Harangues', 'Scratches', 'Décolorées', 'Division', 'Bollywood', "l'Espagne", 'Fume des Cohíbas', 'Kung', 'Philippines', 'Charon', 'Saint-Michel', 'la Mecque', 'Patrie', "emm'na", 'U.S.A.', 'Débilos', 'Foutaises', 'Atlanta', 'Chemin', 'Hortens', 'Délavées', 'Séville', 'jardin des Tuileries', 'Alis', 'Connemara', 'Tokyo', 'Vre', 'l’Espagne', 'El Pais', 'Tolède', 'Sri Lanka', 'Lucas', 'Paradis', 'Bacchus', 'Pigeot', 'Café du Dôme', 'Allemagne', "cor'", 'Knokke-le-Zoute', 'Tectonique', 'Qu´il', 'Frappe', 'Suze', 'Intro].', 'Monaco', 'Golfe', 'Savigny-sur-Orge', "l'Est", 'RapGenius France', 'Tours', 'rue de Vanves', 'Butte Rouge', 'Toulon', 'Lourdes', 'Caroline', 'Camaret', 'Mexique', 'Brute', 'Akhnaton].', 'Telecom', 'Western', 'Dédé-le-Surineur', 'Pattaya', 'Amérique', 'Berlin', 'Irlandais', 'Baltique', 'Ménilmontant', 'Saint-Mandé', 'Criminosical Possee', 'Refrain].', 'Pal', 'Disney', 'Saint-Cloud', 'Bilbao', 'Indonésie', 'Rungis', 'Fastoche', 'Mogador', 'St Vincent de Paul', 'jardin du Luxembourg', 'Chapo', 'Grand Manitou', 'Santiago', 'Charonne', 'Gendes', 'Indochine', 'Opéra', 'Lavilliers', 'Atlantique', 'Beauvau', 'Ouarzazate', 'Cigarillo', 'Denfert', 'Dijon', 'Montesquiou', 'Olé', 'Porions', 'Initiales', 'La Seine', 'Dés', 'Tchernobyl', 'Funk', 'Brille', 'Marchant', 'Onques', 'Coulent', 'Paladins', 'Mont', 'Tsunami', 'Amour', 'Sardagne', 'Endosser', 'Ulster', 'gare de Bologne', "jardin d'Eden", 'l’Est', 'Sardane', 'Pont Neuf je me gonflais', 'Stella', 'Rochereau', 'Journaliste].', 'cools!.', 'Clignancourt', 'Bois', 'La Camarde', 'W', 'notre France', 'Bangladesh', 'Champs Elysées', 'Bietris', 'Recto', 'rose"].', 'Villeneuve-Saint-Georges', 'Gelé', 'forêt de Fontainebleau', 'A majuscule', 'Monténégro', "Lil' Bow Wow", 'Couplet].', 'Istres', 'Désarticulé', 'Manhattan', 'Tiercé', 'Refrain]×2', 'Chicago', 'Ressens', 'jardin du Bon Dieu', 'Créteil', 'Décimées', 'Maharajas', 'Ves', 'Aubervilliers', "Convoit'", 'Colombie', 'Phocée', 'Abeba', 'rue Davso', 'Supérieur', 'Nothing', 'Bali', 'Chouf', "d'Espagne", 'notre Terre', 'Immonde', 'mer Rouge', 'Sharengton', 'Pologne', 'Hong', 'Hissez', 'Loch Ness', 'Vienne', 'Chose', 'le M.I.C.', 'Cap Canaveral', 'planète Terre', 'porte de', 'c\x9coeur', 'Ris', 'Puces', 'Tbilissi', 'pont des Arts', 'Légère', 'Regardez', 'Bourbon', 'Cong', 'We', 'Saint-Pierre', 'Pou', 'Faisanderie', 'Corniche', 'Jérusalem', 'Lisieux', 'Playa', 'Nivea', "île d'", 'Kenzo', 'Açores', 'Medellin', 'Place Saint-Michel', 'Zamzam', 'Ibiza', 'Parme', 'Nord-Est', 'Tommies', 'Sumatra', 'Passe-moi', 'Montfaucon', 'Sorbonne', 'République', 'Bagdad', 'Malaise', 'Clichy', 'Dublin', 'Dame', 'Quartier', 'Ouganda', 'Sofia', 'Miami', 'gare de Lyon', 'Courbée', "aim'", 'Lola', 'New Balance', 'Saint-Germain-des-Près', 'Franchit', 'Himalaya', 'AIWA', 'Bicêtre', 'Tour Eiffel', 'Bud', 'Finlande', 'Lilas', 'quartier Latin', 'Monoï', 'El Paso', 'Couplet 2 - Uptown', 'Fac', 'Belges', "caverne d'Ali", 'Pakistan', 'Dag', 'Kodwa', 'Landes', 'Donx', 'Saintes-Maries', 'Harponnées', 'Freeman].', "Porte d'Italie", 'Cherche', "Parc'", 'Bogota', 'Akheanton].', 'Navrés', 'Franchir', 'Vénus de Milo', "Place de l'Horloge", 'Fleury', 'Provence', 'Meudon', 'Di', 'B52', 'Mali', 'Squad', 'H', 'Iéna', 'Lumière', 'Nam', 'Bonhomme', 'Jordanie', 'Valence', 'Imperial', 'Sumer', 'Auteuil', 'Fort Greene', 'Digne', 'Lerchechem', 'Vilnius', 'Pyrex', 'Carpentras', 'le Pentagone', 'Marre', 'Dallas', 'Avalon', 'Tahiti', 'Nashville', 'Suzann', 'Evry City', 'Carrare', 'Starshooter', 'la Terre', 'Classique', 'Dublin Cit ...
#
# {'Pontoise', 'N', 'Porto', 'Babylone', 'Cologne', 'Indiens', 'Indien', 'Danoise', 'Indiennes', 'MC', 'Montana', 'C', 'Ischia', 'Égyptiens', 'Wallons', 'Balance', 'Père', 'Javanaise', 'Belles', 'Catalane', 'Turc', 'Basques', 'Ricain', 'Corses', 'Tamoul', 'Touraine', 'Chtimis', 'Chouette', 'Bretons', 'Grâces', 'Corse', 'Suisse', 'Américains', 'Bengale', 'Philistins', 'Panthéon', 'Allemands', 'Européens', 'Martiens', 'G', 'Ricains', 'B', 'Gitanes', 'Africain', 'BM', 'Allemand', 'Belge', 'Noire', 'Abruzzes', 'Cheyenne', 'GI', 'Alsaciens', 'Cheval', 'Parisienne', 'Parisien', 'CP', 'Viêt', 'Phocéens', 'D', 'Est', 'État', 'L', 'Gentil', 'Aïd', 'Argentine', 'Renaissance', 'Suisses'}
# nombre lieux en miniscules qui ne se trouvent pas dans le Glaff :  897
# {'du Sud', 'Sambre-et-Meuse', 'avenue Foch', 'Tipaza', 'Dieppe', 'Vres', 'la Marne', 'Disneyland', 'Freeman]. Rogaye', 'Cité Mireille Mathieu', 'Issara].', 'Stockholm', 'Zembla', 'Achinan', 'Wonderbra', 'jardin d’Eden', 'pont Mirabeau', 'Lille', 'Le Renard', 'Heaven', 'Rue Saint-Vincent', 'entr?e', "bois d'Clamart", 'Sentenza', 'Clemenceau', 'Budapest', 'Abyssinie', 'ligne bleue des Vosges', 'Tokarev', 'Freeman]. Ici', 'Issara', 'Quito', 'La Rochelle', 'Ballesteros', 'Grèce', 'Népal', 'Encastr?e', "Jardin d'Eden", 'New York', 'Saint-Malo', 'la Rotonde', 'E1', 'Londres', 'Sodome et Gomorrhe', 'Tout’', 'Sample].', 'B.A.C.', 'F', 'Lolito', 'donne"].', 'Dinard', 'Perriers', 'Haïkku', 'la Pologne', 'Sologne', 'pont du Clemenceau', 'Kersauson', 'Tienanmen', 'Nil', 'Goa', 'Ceylan', 'Brest', 'Peauaime', 'balanc?e', 'Marilyn', 'New Jacks', 'El', "pont d'Avignon", 'Cordillère des Andes', 'Meuse', 'Refrain]. Tape', 'Montfavet', 'B.H.V.', 'VC', 'Finistère', "l'Olympia", 'Puerta', 'Madagascar', 'Branches échevelées', 'Refrain]x2', 'Pondichéry', 'Montmertre', 'golfe de Tchernobyl', 'Tour Magne', 'P´t´être', 'Bollywood', 'Arabie', 'la Margot', 'Brazza', 'Éthiopie', "l'Espagne", 'Fume des Cohíbas', 'Vulpes vulpes', 'Kung', 'Charon', 'La Courneuve', 'Honduras', 'Saint-Michel', 'New Starflash Laserlight', 'Hanoï', 'Refräng]. Vem var jag innan dig', 'la Mecque', 'Californie', 'Te de Saint-Cloud', 'Independenza', 'O3', 'La France', 'avenue des Champs-Élysées', 'la Seine', 'Africa', 'Rahel', 'L`Europe', 'Crozemarie', 'Piennes', 'Sète', "emm'na", 'U.S.A.', 'Lievin', 'Angers', 'Riguidel', 'la Bastille', 'Anema', 'Rue Descartes', 'Bettancourt', 'Débilos', 'Soy el papel del', 'golfe du Lion', 'J.A.Z.Z.', 'Colorado', 'Abscon', 'Atlanta', 'Saint-Jean', 'Vietnam', 'Serai Orly', 'Italie', 'Bab El Oued', 'Boulevard Barbes', 'Prague', 'Bamako', 'Hortens', 'Bhopal', 'Séville', 'Catane', 'Byzance', 'de France', 'Bagneux', 'Marsala', 'Eille', 'jardin des Tuileries', "viaduc d'Auteuil", 'Alis', 'Sugar Hill', 'Louisiane', 'Tokyo', 'Quartier Nord', 'Babel', 'Lavomatic', 'Heineken', 'Maint´nant', 'Vre', 'Dù', 'l’Espagne', 'El Pais', 'Tolède', 'Sri Lanka', 'Kanaky', 'Lucas', 'J', 'Côtes-du-Rhône', 'cordillère des Andes', 'Pigeot', 'la Pravda', 'Singapour', 'Plaza', 'Boulevard de la Chapelle', 'Café du Dôme', 'Allemagne', 'Kader', 'Guèr', 'Vallée des Rois', 'New Orléans', "cor'", 'Mont Royal', 'Villette', 'Rue de la Soif', 'Knokke-le-Zoute', 'Haremburgis', 'Qu´il', 'Hasta', 'Bibi-la-Purée', 'Intro].', 'London', 'Suze', 'Taïwan', 'C.O.B.de', 'Le Très', 'rue du Four', 'le Bonheur', "l'Afrique", 'Antéquarra', 'He', 'Tour Montparnasse', 'Ajaccio', 'Black Hills', 'Palestine', 'Savigny-sur-Orge', 'Goose', 'Pompadour', "l'Est", 'MoMA', 'RapGenius France', 'rue de Vanves', 'Butte Rouge', 'Toulon', 'du Nord', 'Sheitan', 'Camaret', 'Mont Falu', 'Tri-Nitro-Toluène', '501 Posse', 'Mexique', 'Hâkem', 'Marny', 'Fort Green', 'Thiais', 'Scudetto', "fosse all'", 'Molly', 'Mulholland Drive', 'Lac Lancelot', 'ra Lin', 'Akhnaton].', 'Clap', 'Burstin', 'Sholdès', 'Mea culpa!.', 'Telecom', 'tit Montparnasse', 'Ligue Lombarde', 'Lens', 'Capoue', 'Dédé-le-Surineur', "autoroute Porte d'Orléans", 'Bretagne', 'Pattaya', 'Gambetta', 'Elsa', 'Lac Salé', 'Woody', 'Europe', 'Amérique', 'Roche Greau', 'Paules', 'Saint Denis', 'I', 'Aix', 'Ménilmontant', 'Couplet 3', 'Saint Lazare', 'Criminosical Possee', 'Place Vichy', 'Hôtel de Russie', 'Saint-Mandé', 'Refrain].', 'tour Magne', 'Beaune', 'Disney', 'Pensamos', 'Deauville', 'Laponie', 'Egypte', 'Shalamar', "Jardin d'Adam", 'Saint-Cloud', 'Bilbao', 'Recouvrance', 'la Courneuve', 'Soweto', 'Saint-Emilion', 'Indonésie', 'Rungis', 'Tours Jumelles', 'Sicile', 'Bosnie', 'Mogador', 'purée', 'St Vincent de Paul', 'Nante', 'Lison !', 'Tourcoing', 'jardin du Luxembourg', 'Chapo', 'Grand Manitou', 'Rio des gows', 'Couplet 2', "Sainte-Mad'lein’", 'Normandie', 'Santiago', 'Jupiter', 'Clara', 'Louvre', 'Nuttea].', 'Enfernet', 'as’', 'Clamart', "Grand-pèr'", "l' ...
#
# {'Berçant', 'Troussa', 'Basses', 'Distance', 'Retiens', 'Allergique', 'Pondus', 'Ficelles', 'Tuileries', 'Bravo', 'Rater', 'Dépenser', 'Embrase', 'Sahel', 'Casino', 'Pense', 'Vieux', 'Darjeeling', 'Vénus', 'Mars', 'Bastille', 'Pactole', 'Gasoil', 'Faucheuse', 'Suprême', 'Rital', 'Certifié', 'Ouest', "M'", 'Quartiers', 'Nation', 'Firmament', 'Bosse', 'Es', 'Harangues', 'Tire', 'Scratches', 'Décolorées', 'Division', 'Restez', 'Conditionne', 'Loulou', 'Direct', 'Palpable', 'Philippines', 'Cévennes', 'Croyez', 'Essuyez', 'Buffalo', 'Tranquilles', 'Flagada', 'Méditerranée', 'Union', 'Damas', 'Piétinant', 'Brésil', 'Patrie', 'Redescends', 'Grimpe', 'Sorgue', 'Foutaises', 'Gaillarde', 'Chemin', 'Perdus', 'Fume', 'Délavées', 'Tape', 'Prés', 'Ca', 'Connemara', 'Takana', 'Cocagne', 'Aigris', 'Juillet', 'Cataclysme', 'Nice', 'Paradis', 'Pantin', 'Technique', 'Lolo', 'Vernis', 'Bacchus', 'Zénith', 'Brigue', 'Coute', 'Comportâtes', 'Enfanté', 'Manie', 'Tectonique', 'Frappe', 'Mecton', 'Bonjour', 'In', 'Tombant', 'Coucou', 'Monaco', 'Tortillant', 'Champs', 'Casa', 'Golfe', 'Ben', 'Verrouillée', 'Ponds', 'Cimetière', 'Tours', 'Chope', 'Trip', 'Galette', 'Régie', 'Lourdes', 'Caroline', 'Skiez', 'Blanche', 'Frénétique', 'Brute', 'Mai', 'Spirituel', 'Enchaîné', 'Buttes', 'Pékin', 'Schizophrénique', 'Impitoyables', 'Te', 'Jasmin', 'Cramé', 'Méditerranéenne', 'Mignonne', 'Cliquez', 'Cartouche', 'Maroc', 'Niger', 'Western', 'Triangulaire', 'Ter', 'Intro', 'Mettez', 'Costes', 'Manitou', 'Chine', 'Robinet', 'Berlin', 'Irlandais', 'Baltique', 'Verse', 'Fréquentables', 'Vendetta', 'Pal', 'Guérilla', 'Pointu', 'Terminus', 'Moulin', 'Pastis', 'Yang', 'Margoton', 'Descend', 'Fastoche', 'Claquer', 'Louange', 'Manille', 'Chiale', 'Cliché', 'Chili', 'Larigot', 'Opéra', 'Côte', 'Verso', 'Veux', 'Atlantique', 'Beauvau', 'Bastilles', 'Cigarillo', 'Madone', 'Féria', 'Grenade', 'Pistolet', 'Porions', 'Mercure', 'Initiales', 'Paris', 'Tiens', 'Rio', 'Profondes', 'Volez', 'Salut', 'Rayon', 'Funk', 'Dés', 'Brille', 'Lilliputiens', 'Suis', 'Marchant', 'Onques', 'Coulent', 'Paladins', 'Mont', 'Tsunami', 'Arnaquer', 'Ligotée', 'Repentit', 'Coupole', 'Amour', 'Boys', 'Pin', 'Redoute', 'Terre', 'Endosser', 'Ulster', 'Grossissait', 'Hindou', 'Zanzibar', 'Serais', 'Haut', 'Auvergne', 'Jé', 'Prusse', 'Varenne', 'Cagne', 'Briquer', 'Chartre', 'Sardane', 'Préfèrerait', 'Pénélope', 'Sûr', 'Danser', 'Panier', 'Soleil', 'Gestes', 'Transfiguré', 'Bois', 'Matées', 'Gaffe', 'Psychiatrisées', 'Sceaux', 'Coca', 'Recto', 'Triple', 'Mollah', 'Exorcise', 'Refrain', 'Pont', 'Gelé', 'Hargne', 'Butte', 'Perpignan', 'Cher', 'Désarticulé', 'Reverra', 'Nord', 'Longe', 'Tiercé', 'Ressens', 'Rendez', 'Sarcelles', 'Quimper', 'More', 'Pré', 'Paisse', 'Décimées', 'Maharajas', 'Sud', 'Remplacez', 'Berne', 'Margot', 'Tao', 'Élysée', 'Are', 'Supérieur', 'Mesquins', 'Bali', 'Morne', 'Traîne', 'Tranquille', 'Chouf', 'Patriarche', 'Mathusalem', 'Contenir', 'Immonde', 'Reviendront', 'Reluques', 'A', 'Lune', 'Hong', 'Panama', 'Hissez', 'Les', 'Textiles', 'Privées', 'Bagarreurs', 'Vienne', 'Chose', 'Raisonne', 'Chinois', 'Passeront', 'Nettoyées', 'Animateur', 'Ris', 'Puces', 'Gaulois', 'Bécassine', 'Pervenches', 'Jubiler', 'Légère', 'Celles', 'Regardez', 'Bourbon', 'Cong', 'Landerneau', 'Unis', 'Tremper', 'Pou', 'Faisanderie', 'Inde', 'Corniche', 'Microbe', 'Chés', 'Mentons', 'Haschich', 'Halte', 'Bas', 'Beaujolais', 'Creeks', 'Rasée', 'Assimile', 'Parme', 'Hexagone', 'Mangeais', 'Saturne', 'Centre', 'Montfaucon', 'Reggae', 'Bavière', 'Sorbonne', 'République', 'Hambourg', 'Winchester', 'Planète', 'Malaise', 'Dame', 'Blague', 'Angleterre', 'Chapelle', 'Quartier', 'Servir', 'Scellées', 'Cocu', 'Miami', 'Doux', 'Courbée', 'Lola', 'Franchit', 'Vaux', 'Maman', 'Gap', 'Garde', 'Français', 'Baffles', 'Négus', 'Bicêtre', 'Fier', 'Fit', 'Couplet', 'Alpha', 'Mutiler', 'States', 'Cercle', 'Sirocco', 'Ramèneront', 'Macao', 'Colombe', 'Amasse', 'Pays', 'Moulins', 'Lilas', 'Monoï', 'Callipyge', 'Seine', 'Fac', 'Tache', ...
#
# nombre de lieux obtenu dans la liste finale :  865
# {'du Sud', 'Sambre-et-Meuse', 'avenue Foch', 'Tipaza', 'Dieppe', 'Vres', 'la Marne', 'Disneyland', 'Freeman]. Rogaye', 'Cité Mireille Mathieu', 'Issara].', 'Stockholm', 'Zembla', 'Achinan', 'Wonderbra', 'jardin d’Eden', 'pont Mirabeau', 'Lille', 'Le Renard', 'Heaven', 'Rue Saint-Vincent', 'Sentenza', "bois d'Clamart", 'Clemenceau', 'Budapest', 'Abyssinie', 'ligne bleue des Vosges', 'Tokarev', 'Freeman]. Ici', 'Issara', 'Quito', 'La Rochelle', 'Ballesteros', 'Grèce', 'Népal', 'Encastr?e', "Jardin d'Eden", 'New York', 'Saint-Malo', 'la Rotonde', 'E1', 'Londres', 'Sodome et Gomorrhe', 'Tout’', 'Sample].', 'B.A.C.', 'F', 'Lolito', 'pont du Clemenceau', 'Dinard', 'Perriers', 'Haïkku', 'la Pologne', 'Sologne', 'Tienanmen', 'Kersauson', 'Nil', 'Goa', 'Ceylan', 'Brest', 'Peauaime', 'Marilyn', 'New Jacks', 'El', "pont d'Avignon", 'Cordillère des Andes', 'Meuse', 'Refrain]. Tape', 'Montfavet', 'B.H.V.', 'VC', 'Finistère', "l'Olympia", 'Puerta', 'Madagascar', 'Branches échevelées', 'Refrain]x2', 'Pondichéry', 'Montmertre', 'golfe de Tchernobyl', 'Tour Magne', 'P´t´être', 'Bollywood', 'Arabie', 'la Margot', 'Brazza', 'Éthiopie', "l'Espagne", 'Fume des Cohíbas', 'Vulpes vulpes', 'Kung', 'Charon', 'La Courneuve', 'Honduras', 'Saint-Michel', 'New Starflash Laserlight', 'Hanoï', 'Refräng]. Vem var jag innan dig', 'la Mecque', 'Californie', 'Te de Saint-Cloud', 'Independenza', 'O3', 'La France', 'avenue des Champs-Élysées', 'la Seine', 'Africa', 'Rahel', 'L`Europe', 'Crozemarie', 'Piennes', 'Sète', 'U.S.A.', 'Lievin', 'Angers', 'Riguidel', 'la Bastille', 'Anema', 'Rue Descartes', 'Bettancourt', 'Débilos', 'Soy el papel del', 'golfe du Lion', 'J.A.Z.Z.', 'Colorado', 'Abscon', 'Atlanta', 'Saint-Jean', 'Vietnam', 'Serai Orly', 'Italie', 'Bab El Oued', 'Boulevard Barbes', 'Prague', 'Bamako', 'Hortens', 'Bhopal', 'Séville', 'Catane', 'Byzance', 'de France', 'Bagneux', 'Marsala', 'Eille', 'jardin des Tuileries', "viaduc d'Auteuil", 'Sugar Hill', 'Alis', 'Louisiane', 'Tokyo', 'Quartier Nord', 'Babel', 'Lavomatic', 'Heineken', 'Maint´nant', 'Vre', 'Dù', 'l’Espagne', 'El Pais', 'Tolède', 'Sri Lanka', 'Kanaky', 'Lucas', 'J', 'Côtes-du-Rhône', 'cordillère des Andes', 'Pigeot', 'la Pravda', 'Singapour', 'Plaza', 'Boulevard de la Chapelle', 'Café du Dôme', 'Allemagne', 'Kader', 'Guèr', 'Vallée des Rois', 'New Orléans', 'Mont Royal', 'Villette', 'Rue de la Soif', 'Knokke-le-Zoute', 'Haremburgis', 'Qu´il', 'Hasta', 'Bibi-la-Purée', 'Intro].', 'London', 'Suze', 'Taïwan', 'C.O.B.de', 'Le Très', 'rue du Four', 'le Bonheur', "l'Afrique", 'Antéquarra', 'He', 'Tour Montparnasse', 'Ajaccio', 'Black Hills', 'Palestine', 'Savigny-sur-Orge', 'Goose', 'Pompadour', "l'Est", 'MoMA', 'RapGenius France', 'rue de Vanves', 'Butte Rouge', 'Toulon', 'du Nord', 'Sheitan', 'Camaret', 'Mont Falu', 'Tri-Nitro-Toluène', '501 Posse', 'Mexique', 'Hâkem', 'Marny', 'Fort Green', 'Thiais', 'Scudetto', 'Molly', 'Mulholland Drive', 'Lac Lancelot', 'ra Lin', 'Akhnaton].', 'Clap', 'Burstin', 'Sholdès', 'Mea culpa!.', 'Telecom', 'tit Montparnasse', 'Ligue Lombarde', 'Lens', 'Capoue', 'Dédé-le-Surineur', "autoroute Porte d'Orléans", 'Bretagne', 'Pattaya', 'Gambetta', 'Elsa', 'Lac Salé', 'Woody', 'Europe', 'Amérique', 'Roche Greau', 'Paules', 'Saint Denis', 'I', 'Aix', 'Ménilmontant', 'Couplet 3', 'Saint Lazare', 'Criminosical Possee', 'Place Vichy', 'Hôtel de Russie', 'Saint-Mandé', 'Refrain].', 'tour Magne', 'Beaune', 'Disney', 'Pensamos', 'Deauville', 'Laponie', 'Egypte', 'Shalamar', "Jardin d'Adam", 'Saint-Cloud', 'Bilbao', 'Recouvrance', 'la Courneuve', 'Soweto', 'Saint-Emilion', 'Indonésie', 'Rungis', 'Tours Jumelles', 'Sicile', 'Bosnie', 'Mogador', 'St Vincent de Paul', 'Nante', 'Lison !', 'Tourcoing', 'jardin du Luxembourg', 'Chapo', 'Grand Manitou', 'Rio des gows', 'Couplet 2', "Sainte-Mad'lein’", 'Normandie', 'Santiago', 'Jupiter', 'Clara', 'Louvre', 'Nuttea].', 'Enfernet', 'Clamart', "Grand-pèr'", "l'Italie", 'Charonne', 'Gendes', 'Vercors', 'Agadir', 'Big Daddy', 'Fu', 'Indochine', ...
#
# {"emm'na", "port d'", 'pont du', "aim'", 'balanc?e', "île d'", "fosse all'", 'raclée', "cor'", 'vétérinaires', 'blas?s', 'purée', 'rose"].', 'métro', 'porte de', "l'14ème", 'c\x9coeur', "fum'", 'op?ras', 'entr?e', "méd'", 'he’', 'as’', 'marée', 'bourgeois!.', 'l´au', 'cools!.', 'fascin?s', "all'mand", 'd´la', 'donne"].', 'l´ai'}

# %%
x = [1, 2, 3, 4]
y = [1424, 1357, 897, 865]
labels = ['lieux_md', 'tri_1', 'tri_2', 'tri_3']

plt.plot(x, y)
# You can specify a rotation for the tick labels in degrees or with keywords.
plt.xticks(x, labels, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.2)
plt.title("Filtrage de l'échantillon2")
plt.ylabel("nombre de lieux")
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)
plt.show()

# %%
start3 =time.perf_counter()
loc_lg=[]
for texte in f1:
    try:
        doc = nlp_lg(texte)
        for entity in doc.ents:
            if entity.label_ =="LOC":
                loc_lg.append(entity.text)
    except:
        pass
end3 =time.perf_counter()
ecrire_json("/Users/mustapha/Documents/GitHub/Memoire/lieux_echantillon_aprésNettoyage/lieux_echantillon2_aprésNettoyage_lg.json",loc_lg)
print("lieux trouvés par le modèle large : ",len(set(loc_lg)))
print(set(loc_lg))
print("temps :",end3-start3)
print()
print()

tri_1 = [mot for mot in loc_lg if mot not in f2]
test1 = [mot for mot in loc_lg if mot in f2]
print("nombre lieux qui ne se trouvent pas dans le Glaff : ", len(set(tri_1)))
print(set(tri_1))
print()
print(set(test1))
print()

tri_2 = [mot for mot in tri_1 if mot.lower() not in f2]
test2 = [mot for mot in tri_1 if mot.lower() in f2]
print("nombre lieux en miniscules qui ne se trouvent pas dans le Glaff : ",len(set(tri_2)))
print(set(tri_2))
print()
print(set(test2))
print()



tri_3 =[mot for mot in tri_2 if mot.lower() not in tri_2] 
test3 =set(tri_2).difference(tri_3)
print("nombre de lieux obtenu dans la liste finale : ", len(set(tri_3)))
print(set(tri_3))
print()
print(set(test3))
ecrire_json("/Users/mustapha/Documents/GitHub/Memoire/lieux_echantillon_aprésFiltrage/lieux_echantillon2_aprésFiltrage_lg.json",tri_3)
# Out:
# lieux trouvés par le modèle large :  1413
# {'Berçant', 'avenue Foch', 'Disneyland', 'Dieppe', 'Stockholm', 'Père', 'Ficelles', 'Rue Saint-Vincent', 'Abyssinie', 'Sahel', 'Darjeeling', 'Vénus', 'colline de', "Heureus'", 'Mars', 'Gavroche', 'F', 'Dinard', 'Sologne', 'Ceylan', 'Saint-Bernard', 'Nation', 'Firmament', "pont d'Avignon", 'MC', 'Cordillère des Andes', "l'Olympia", 'Madagascar', 'Décolorées', "l'Espagne", 'Philippines', 'Charon', 'Saint-Michel', 'la Mecque', '‘Inti Fada', 'Continuer', 'Boutonneux', 'U.S.A.', 'Débilos', 'Imothep', 'Foutaises', 'Atlanta', 'Chemin', 'Hortens', 'Délavées', 'Séville', 'jardin des Tuileries', 'Alis', 'Connemara', 'Tokyo', 'Vre', 'l’Espagne', 'Tolède', 'Sri Lanka', 'Paradis', 'Excitait', 'Café du Dôme', 'Allemagne', 'Knokke-le-Zoute', 'Qu´il', 'Voltigent', 'Turc', 'Suze', 'Confortant', 'Monaco', 'So', 'Golfe', 'Savigny-sur-Orge', 'Tours', 'rue de Vanves', 'Butte Rouge', 'Toulon', 'Capdevielle', 'Lourdes', 'Caroline', 'Camaret', 'DSU', 'Mexique', 'Égyptiens', 'Telecom', 'Dévorées', 'Western', 'Dédé-le-Surineur', 'Pattaya', 'M.I.C.', 'Amérique', 'Berlin', 'Irlandais', 'Baltique', 'Ménilmontant', 'Saint-Mandé', 'Baileys', 'Nébuleuse', 'Saint-Cloud', 'Bilbao', 'Eeeeeh!.', 'Indonésie', 'Rungis', 'Mogador', 'St Vincent de Paul', 'jardin du Luxembourg', 'Grand Manitou', 'Santiago', 'Freeman]. Regarde', 'C.I.P.', 'Charonne', 'Gendes', 'Indochine', 'Opéra', 'Empalés', 'Lavilliers', 'RZA].', 'Atlantique', 'Ouarzazate', 'Bourse', 'Dijon', 'Nou terrils', 'cette Bastille', 'Indiens', 'Porions', 'Bancs', 'La Seine', 'Tchernobyl', 'Funk', 'Brille', 'Onques', 'Européens', 'Robins des Bois', "you'", 'Insultant', 'MacDo', 'Pleurer', 'Amour', 'Morts', 'Sardagne', 'Métamorphoser', 'Endosser', 'Ulster', 'Aïd', 'gare de Bologne', "jardin d'Eden", 'H.O.P', 'Stella', 'Trou de la pomme de pin', 'Croyais', 'Clignancourt', 'bande du', 'notre France', 'Bangladesh', 'Champs Elysées', 'Quipe', 'Bietris', 'Recto', 'Villeneuve-Saint-Georges', 'Gelé', 'forêt de Fontainebleau', 'Monténégro', "Lil' Bow Wow", 'Couplet].', 'Istres', 'Désarticulé', "Brill'", 'Test', 'Tiercé', 'Refrain]×2', 'Mière Parisienne', 'Tagada', 'Chicago', 'jardin du Bon Dieu', 'Créteil', 'Décimées', 'Maharajas', 'Ves', "Convoit'", 'Colombie', 'Phocée', 'Hola', 'Abeba', 'rue Davso', 'Supérieur', 'Bali', 'Saint-Eloi', 'Grâces', 'Chouf', 'Corse', "d'Espagne", 'notre Terre', 'Philistins', 'Sublime Porte', 'Sharengton', 'Naguère', 'Pologne', 'Belge', 'Hong', 'Poto', 'Hissez', 'Loch Ness', 'Vienne', 'Pontoise', 'Cap Canaveral', 'planète Terre', 'Gisait', 'Ris', 'Puces', 'Tbilissi', 'pont des Arts', 'Bourbon', 'We', 'Saint-Pierre', 'Fuck', 'Pou', 'Faisanderie', 'Corniche', 'Jérusalem', 'Lisieux', 'Playa', 'Été 77', 'Garde-à-vue', 'Inamicale', 'Açores', 'Medellin', 'Zamzam', 'Place Saint-Michel', 'Ibiza', 'Long Kesh', 'Parme', 'Nord-Est', 'Tommies', 'n´en', 'Acerbe', 'Sumatra', 'Dénonçaient', 'Montfaucon', 'Sorbonne', 'République', 'Sensualiser', 'Bagdad', 'Malaise', 'Clichy', 'Dublin', 'Ver', 'Quartier', 'Ouganda', 'Dins', 'Grattant', 'Sofia', 'Symbolisé', 'Miami', 'gare de Lyon', 'Eiche', 'Courbée', 'Lola', 'New Balance', 'Himalaya', 'Dise', 'Bicêtre', 'Tour Eiffel', 'Revolucion', 'Pont Neuf', 'Ffff', 'Pauvr', 'Elam', 'Probabl', 'Poses', 'Finlande', 'Monoï', 'quartier Latin', 'Pile', 'El Paso', 'XXX Paname', 'Fac', 'Belges', 'Pakistan', 'Kodwa', 'Landes', 'Donx', 'Combien', 'Saintes-Maries', 'Harponnées', 'Distille', "Porte d'Italie", 'Belfast mill', 'Drumbar', 'Une Sardane', 'Cherche', 'AH AH AH', "Parc'", 'Bogota', 'Rimplachant', 'Navrés', 'Big Brother', 'Franchir', 'Vénus de Milo', "Place de l'Horloge", 'Chartre’', 'Fleury', 'Provence', 'Trouverais', 'Meudon', 'B52', 'Gare', 'Mali', "Shurik'", 'Panthéon !', 'H', 'porte des Lilas', 'Iéna', 'Pagais', 'Minto', 'Jordanie', 'Valence', 'Imperial', 'Sumer', 'Crament', 'Deviendront', 'Auteuil', 'Fort Greene', 'Digne', 'Ternit', 'Lerchechem', 'Vilnius', 'Pyrex', 'Carpentras', 'le Pentagone', 'Fonder', 'Dallas', 'Avalon', 'Réquisition', 'Tahiti', 'Nashville',  ...
# temps : 79.550103111
# nombre lieux qui ne se trouvent pas dans le Glaff :  1349
# {'Berçant', 'avenue Foch', 'Disneyland', 'Dieppe', 'Stockholm', 'Ficelles', 'Rue Saint-Vincent', 'Abyssinie', 'Sahel', 'Darjeeling', 'Vénus', 'colline de', "Heureus'", 'Mars', 'Gavroche', 'F', 'Dinard', 'Sologne', 'Ceylan', 'Saint-Bernard', 'Nation', 'Firmament', "pont d'Avignon", 'Cordillère des Andes', "l'Olympia", 'Madagascar', 'Décolorées', "l'Espagne", 'Philippines', 'Charon', 'Saint-Michel', 'la Mecque', '‘Inti Fada', 'Continuer', 'Boutonneux', 'U.S.A.', 'Débilos', 'Imothep', 'Foutaises', 'Atlanta', 'Chemin', 'Hortens', 'Délavées', 'Séville', 'jardin des Tuileries', 'Alis', 'Connemara', 'Tokyo', 'Vre', 'l’Espagne', 'Tolède', 'Sri Lanka', 'Paradis', 'Excitait', 'Café du Dôme', 'Allemagne', 'Knokke-le-Zoute', 'Qu´il', 'Voltigent', 'Suze', 'Confortant', 'Monaco', 'So', 'Golfe', 'Savigny-sur-Orge', 'Tours', 'rue de Vanves', 'Butte Rouge', 'Toulon', 'Capdevielle', 'Lourdes', 'Caroline', 'Camaret', 'DSU', 'Mexique', 'Telecom', 'Dévorées', 'Western', 'Dédé-le-Surineur', 'Pattaya', 'M.I.C.', 'Amérique', 'Berlin', 'Irlandais', 'Baltique', 'Ménilmontant', 'Saint-Mandé', 'Baileys', 'Nébuleuse', 'Saint-Cloud', 'Bilbao', 'Eeeeeh!.', 'Indonésie', 'Rungis', 'Mogador', 'St Vincent de Paul', 'jardin du Luxembourg', 'Grand Manitou', 'Santiago', 'Freeman]. Regarde', 'C.I.P.', 'Charonne', 'Gendes', 'Indochine', 'Opéra', 'Empalés', 'Lavilliers', 'RZA].', 'Atlantique', 'Ouarzazate', 'Bourse', 'Dijon', 'Nou terrils', 'cette Bastille', 'Porions', 'Bancs', 'La Seine', 'Tchernobyl', 'Funk', 'Brille', 'Onques', 'Robins des Bois', "you'", 'Insultant', 'MacDo', 'Pleurer', 'Amour', 'Morts', 'Sardagne', 'Métamorphoser', 'Endosser', 'Ulster', 'gare de Bologne', "jardin d'Eden", 'H.O.P', 'Stella', 'Trou de la pomme de pin', 'Croyais', 'Clignancourt', 'bande du', 'notre France', 'Bangladesh', 'Champs Elysées', 'Quipe', 'Bietris', 'Recto', 'Villeneuve-Saint-Georges', 'Gelé', 'forêt de Fontainebleau', 'Monténégro', "Lil' Bow Wow", 'Couplet].', 'Istres', 'Désarticulé', "Brill'", 'Test', 'Tiercé', 'Refrain]×2', 'Mière Parisienne', 'Tagada', 'Chicago', 'jardin du Bon Dieu', 'Créteil', 'Décimées', 'Maharajas', 'Ves', "Convoit'", 'Colombie', 'Phocée', 'Hola', 'Abeba', 'rue Davso', 'Supérieur', 'Bali', 'Saint-Eloi', 'Chouf', "d'Espagne", 'notre Terre', 'Sublime Porte', 'Sharengton', 'Naguère', 'Pologne', 'Hong', 'Poto', 'Hissez', 'Loch Ness', 'Vienne', 'Cap Canaveral', 'planète Terre', 'Gisait', 'Ris', 'Puces', 'Tbilissi', 'pont des Arts', 'Bourbon', 'We', 'Saint-Pierre', 'Fuck', 'Pou', 'Faisanderie', 'Corniche', 'Jérusalem', 'Lisieux', 'Playa', 'Été 77', 'Garde-à-vue', 'Inamicale', 'Açores', 'Medellin', 'Zamzam', 'Place Saint-Michel', 'Ibiza', 'Long Kesh', 'Parme', 'Nord-Est', 'Tommies', 'n´en', 'Acerbe', 'Sumatra', 'Dénonçaient', 'Montfaucon', 'Sorbonne', 'République', 'Sensualiser', 'Bagdad', 'Malaise', 'Clichy', 'Dublin', 'Ver', 'Quartier', 'Ouganda', 'Dins', 'Grattant', 'Sofia', 'Symbolisé', 'Miami', 'gare de Lyon', 'Eiche', 'Courbée', 'Lola', 'New Balance', 'Himalaya', 'Dise', 'Bicêtre', 'Tour Eiffel', 'Revolucion', 'Pont Neuf', 'Ffff', 'Pauvr', 'Elam', 'Probabl', 'Poses', 'Finlande', 'Monoï', 'quartier Latin', 'Pile', 'El Paso', 'XXX Paname', 'Fac', 'Belges', 'Pakistan', 'Kodwa', 'Landes', 'Donx', 'Combien', 'Saintes-Maries', 'Harponnées', 'Distille', "Porte d'Italie", 'Belfast mill', 'Drumbar', 'Une Sardane', 'Cherche', 'AH AH AH', "Parc'", 'Bogota', 'Rimplachant', 'Navrés', 'Big Brother', 'Franchir', 'Vénus de Milo', "Place de l'Horloge", 'Chartre’', 'Fleury', 'Provence', 'Trouverais', 'Meudon', 'B52', 'Gare', 'Mali', "Shurik'", 'Panthéon !', 'H', 'porte des Lilas', 'Iéna', 'Pagais', 'Minto', 'Jordanie', 'Valence', 'Imperial', 'Sumer', 'Crament', 'Deviendront', 'Auteuil', 'Fort Greene', 'Digne', 'Ternit', 'Lerchechem', 'Vilnius', 'Pyrex', 'Carpentras', 'le Pentagone', 'Fonder', 'Dallas', 'Avalon', 'Réquisition', 'Tahiti', 'Nashville', 'Evry City', 'Tipp', 'la Terre', 'Dublin City', 'la Vache', 'Calvi', 'Pont-de-Sèvre', 'Babou', 'Irlande', 'Rennes', 'Sam ...
#
# {'Pontoise', 'Crie', 'Porto', 'Babylone', 'Cologne', 'Indiens', 'Indien', 'Danoise', 'Indiennes', 'MC', 'Montana', 'Occident', 'C', 'Ischia', 'Égyptiens', 'Balance', 'Père', 'Javanaise', 'Catalane', 'Turc', 'Basques', 'Ricain', 'Corses', 'Tamoul', 'Arabe', 'Touraine', 'Chouette', 'Grâces', 'Blacks', 'Corse', 'Suisse', 'Américains', 'Bengale', 'Philistins', 'Panthéon', 'Allemands', 'Européens', 'G', 'CV', 'Ricains', 'B', 'Australien', 'Teutons', 'Paimpolaise', 'Allemand', 'Belge', 'Noire', 'Abruzzes', 'Romain', 'Alsaciens', 'Cheval', 'Parisien', 'CP', 'Viêt', 'Phocéens', 'D', 'Est', 'État', 'Broyant', 'Aïd', 'Argentine', 'Ourse', 'Suisses', 'Land'}
# nombre lieux en miniscules qui ne se trouvent pas dans le Glaff :  881
# {'avenue des Champs', 'du Sud', 'Sambre-et-Meuse', 'avenue Foch', 'La Canebière', 'Tipaza', 'Dieppe', 'Vres', 'Disneyland', 'Stockholm', 'B.I.E.M.', 'Achinan', 'jardin d’Eden', 'petite Delphine', 'pont Mirabeau', 'Lille', 'Amway', 'Rue Saint-Vincent', 'Sentenza', "bois d'Clamart", 'Budapest', 'Abyssinie', 'Man?uvres', 'ligne bleue des Vosges', 'Quito', 'La Rochelle', 'Grèce', 'Faubourg-Saint-Honoré', 'Encastr?e', "Jardin d'Eden", 'New York', 'Népal', 'Saint-Malo', 'Schengen', 'la Rotonde', 'Londres', 'Le Manimal', 'Grand Plazza', 'Rue du Vieux Colombier', 'Sodome et Gomorrhe', 'colline de', 'Tout’', "Heureus'", 'Lololala', 'Gavroche', 'F', 'pont du Clemenceau', 'Dinard', 'Perriers', 'Sologne', 'Nil', 'Goa', 'Ceylan', 'Saint-Bernard', 'Brest', "pont d'Avignon", 'Cordillère des Andes', 'Meuse', 'B.H.V.', 'VC', 'Finistère', "l'Olympia", 'Como yo', 'Puerta', 'Madagascar', 'Branches échevelées', 'Pondichéry', 'Montmertre', 'golfe de Tchernobyl', 'métro Saint Michel', 'Tour Magne', 'Refrain]. Sad Hill', 'Arabie', 'Brazza', 'Éthiopie', "l'Espagne", 'Ténéré', 'Irak', 'Charon', 'Mortadan', 'La Courneuve', 'Honduras', 'Saint-Michel', 'Sunday', 'Arc-en-Ciel', 'Hanoï', 'la Mecque', 'Ayato', 'Californie', 'Te de Saint-Cloud', 'Independenza', 'La France', '‘Inti Fada', 'K', 'Paz', 'Rex', 'Africa', 'la Seine', 's´en', 'Voil', 'Crozemarie', 'Piennes', 'Sète', 'Recordar', 'U.S.A.', 'Froidevaux', 'Angers', 'Lievin', 'la Bastille', 'Bettancourt', 'Aid', 'Débilos', 'golfe du Lion', 'Imothep', 'Colorado', 'Abscon', 'Atlanta', 'Farang', 'Saint-Jean', 'Vietnam', 'Serai Orly', 'Italie', 'Bab El Oued', 'Prague', 'Bamako', 'Hortens', 'Bhopal', 'Séville', 'Catane', 'Byzance', 'la Sorgue', 'de France', 'Marsala', 'Bagneux', 'jardin des Tuileries', 'Mélanie', "viaduc d'Auteuil", 'Alis', 'Sugar Hill', 'Greenwitch Village', 'Louisiane', 'Tokyo', 'Quartier Nord', 'Babel', 'Maint´nant', 'Vre', 'Dù', 'l’Espagne', 'Tolède', 'Médine', 'Sri Lanka', 'J', 'Macumba', 'Côtes-du-Rhône', 'cordillère des Andes', 'Laintenanmic', 'Singapour', 'Plaza', 'Ve', 'Café du Dôme', 'Allemagne', 'Kader', 'Guèr', 'Omotesandō', 'Vallée des Rois', 'New Orléans', 'Mont Royal', 'Villette', 'Hauts-Plateaux', 'Knokke-le-Zoute', 'Rue de la Soif', 'Haremburgis', 'Qu´il', 'Bibi-la-Purée', 'London', 'Suze', "l'Europe", 'Taïwan', 'C.O.B.de', 'rue du Four', "l'Afrique", "Sirima]. N'", 'So', 'He', 'Tour Montparnasse', 'Atada', 'Ajaccio', 'le Saint-Esprit', 'Rience', 'Palestine', 'Savigny-sur-Orge', 'Goose', 'MoMA', 'gare de', 'rue Blondel', 'rue de Vanves', 'pont de la Villette', 'Butte Rouge', 'Toulon', 'Buffalo Bill', 'du Nord', 'Capdevielle', 'Camaret', 'métro Saint-Mandé', 'Mont Falu', 'DSU', 'Pearl Harbor', 'Tri-Nitro-Toluène', 'Mexique', 'Marny', 'Fort Green', 'Thiais', 'Chari Jazz', 'Jordans', 'Lac Lancelot', 'Euhmm', 'Clap', 'Evêché', 'Sholdès', 'Telecom', 'Lens', 'Capoue', 'Ffu', 'Blooooooondiiiiin', 'Dédé-le-Surineur', 'Bretagne', 'Pattaya', 'M.I.C.', 'Lac Salé', 'Occitants', 'Europe', 'Amérique', 'Esmeralada', 'Paules', 'I', 'Aix', 'Ménilmontant', 'Tcherno', 'Saint-Mandé', 'Concidence', 'Place Vichy', 'Hôtel de Russie', 'tour Magne', 'Beaune', 'Pensamos', 'Deauville', 'Laponie', 'Baileys', 'Egypte', 'Shalamar', "Jardin d'Adam", 'Saint-Cloud', 'Bilbao', 'Eeeeeh!.', 'Pays de Co', 'Recouvrance', 'Welcome Gorby', 'Elégante', 'la Courneuve', 'Saint-Emilion', 'Indonésie', 'Rungis', 'Tours Jumelles', 'Sicile', 'Bosnie', 'Mogador', "Vincenn's", 'St Vincent de Paul', 'CO', 'Nante', 'Tourcoing', 'This', 'jardin du Luxembourg', 'Neptune', 'Grand Manitou', 'Suzon', "Sainte-Mad'lein’", 'Normandie', 'Santiago', 'Jupiter', 'Elysée', 'Louvre', 'Freeman]. Regarde', 'Nuttea].', 'Enfernet', 'KCP', 'C.I.P.', 'Clamart', "l'Italie", 'Charonne', 'Gendes', 'Vercors', 'Silhouette insolite', 'Agadir', 'Big Daddy', 'Indochine', "Rue d'Charonne", 'Katmandou', 'l´au', 'Turlututu', 'Ur', 'Salamanque', 'Versailles', 'Lavilliers', 'RZA].', 'Longwy', 'Chambéry', 'From London', 'Ouarzazate', 'R', 'Rhondda', 'La-la-la' ...
#
# {'Berçant', 'Basses', 'Distance', 'Tifosi', 'Voltigeur', 'Allergique', 'Frissonnant', 'Pondus', 'Tuileries', 'Ficelles', 'Barbarie', 'Badé', 'Versant', 'Embrase', 'Sahel', 'Souillé', 'Casino', 'Darjeeling', 'Vénus', 'Mars', 'Horloge', 'Déplace', 'Bastille', 'Pactole', 'Intouchable', 'Gasoil', 'Ouest', 'Nation', 'Firmament', 'Bosse', 'Rêva', 'Euromarché', 'Décolorées', 'Flore', 'Conditionne', 'Loulou', 'Close', 'Rendre', 'Cité', 'Direct', 'Palpable', 'Philippines', 'Cévennes', 'Sylphes', 'Essuyez', 'Sacré', 'Continuer', 'Méditerranée', 'Boutonneux', 'Union', 'Damas', 'Piétinant', 'Brésil', 'Bourrez', 'Noir', 'Crin', 'Redescends', 'Grimpe', 'Raclant', 'Foutaises', 'Garderons', 'Arrimé', 'Picon', 'Perdons', 'Gaillarde', 'Chemin', 'Traîné', 'Délavées', 'Creusez', 'Résisté', 'Ca', 'Connemara', 'Welsh', 'Takana', 'Blonds', 'Cocagne', 'Aimerais', 'Nice', 'Paradis', 'Pantin', 'Morte', 'Vernis', 'Faisais', 'Excitait', 'Brigue', 'Zénith', 'Tourne', 'Comportâtes', 'Enfanté', 'Manie', 'Fine', 'Voltigent', 'Rouler', 'Tiendront', 'Levant', 'Mettait', 'Menton', 'Confortant', 'In', 'Tombant', 'Coucou', 'Monaco', 'Tortillant', 'Champs', 'Casa', 'Golfe', 'Traînez', 'Verrouillée', 'Ponds', 'Cimetière', 'Tours', 'Afros', 'Trip', 'Galette', 'Sensoriel', 'Lourdes', 'Caroline', 'Monter', 'Skiez', 'Blanche', 'Frénétique', 'Mai', 'Buttes', 'Enchaîné', 'Pékin', 'Électrolyse', 'Schizophrénique', 'Te', 'Mourra', 'Positive', 'Cramé', 'Méditerranéenne', 'Mignonne', 'Maroc', 'Niger', 'Western', 'Dévorées', 'Triangulaire', 'Ter', 'Chérie', 'Désemparé', 'Pédé', 'Chine', 'Robinet', 'Berlin', 'Irlandais', 'Baltique', 'Verse', 'Fréquentables', 'Guérilla', 'Moulin', 'Couteront', 'Nébuleuse', 'Venez', 'Toi', 'Pastis', 'Futile', 'Yang', 'Aprés', 'Margoton', 'Once', 'Deviné', 'Malpolis', 'Manille', 'Coutellerie', 'Flinguer', 'Chili', 'Séquencée', 'Opéra', 'Côte', 'Flingue', 'Empalés', 'Oublierons', 'Verso', 'Expédie', 'Atlantique', 'Bastilles', 'Instituteurs', 'Taf', 'Bourse', 'Féria', 'Grenade', 'Porions', 'Mercure', 'Lendemain', 'Paris', 'Bancs', 'Rio', 'Funk', 'Brille', 'Lilliputiens', 'Suis', 'Val', 'Ça', 'Onques', 'Insultant', 'Trouvait', 'Pétales', 'Ligotée', 'Pleurer', 'Coupole', 'Amour', 'Boys', 'Pâquerette', 'Morts', 'Pin', 'Métamorphoser', 'Terre', 'Canal', 'Endosser', 'Ulster', 'Creuser', 'Lauriers', 'Sommeille', 'Systématique', 'Hindou', 'Chacal', 'Zanzibar', 'Auvergne', 'Prusse', 'Posé', 'Cagne', 'Olives', 'Katana', 'Préfèrerait', 'Moiti', 'Panier', 'Soleil', 'Pluton', 'Croyais', 'Cogner', 'Matées', 'Partir', 'Traverse', 'Sceaux', 'Coca', 'Recto', 'Instrumental', 'Exorcise', 'Menuets', 'Marjolaine', 'Pont', 'Gelé', 'Hargne', 'Butte', 'Perpignan', 'Cher', 'Désarticulé', 'Croule', 'Nord', 'Kalash', 'Test', 'Tiercé', 'Oie', 'Rendez', 'Marais', 'Sarcelles', 'Quimper', 'More', 'Fané', 'Étouffés', 'Baba', 'Horizons', 'Pré', 'Décimées', 'Maharajas', 'Pleurez', 'Sud', 'Berne', 'Répondez', 'Cognée', 'Élysée', 'Supérieur', 'Mesquins', 'Bali', 'Morne', 'Flèche', 'Musette', 'Traîne', 'Relater', 'Tranquille', 'Chouf', 'Patriarche', 'Rencontra', 'Champ', 'Mandarines', 'Reviendront', 'Reposerais', 'Naguère', 'Bic', 'A', 'Lune', 'Hong', 'Panama', 'Populace', 'Hissez', 'Privées', 'Bagarreurs', 'Vienne', 'Chinois', 'Passeront', 'Animateur', 'Gisait', 'Ris', 'Puces', 'Gaulois', 'Pervenches', 'Jubiler', 'Mental', 'Celles', 'Bourbon', 'Landerneau', 'Unis', 'Tremper', 'Pou', 'Faisanderie', 'Inde', 'Corniche', 'Hardcore', 'Chés', 'Mentons', 'Garez', 'Inamicale', 'Bas', 'Sonde', 'Beaujolais', 'Ait', 'Assimile', 'Parme', 'Hexagone', 'Acerbe', 'Mangeais', 'Dénonçaient', 'Saturne', 'Centre', 'Torse', 'Montfaucon', 'Reggae', 'Bavière', 'Sorbonne', 'République', 'Basta', 'Hambourg', 'Winchester', 'Malaise', 'Blague', 'Ver', 'Angleterre', 'Chapelle', 'Quartier', 'Épis', 'Ré', 'Grattant', 'Scellées', 'Symbolisé', 'Miami', 'Tait', 'Courbée', 'Lola', 'Matérialistes', 'Reléguant', 'Dégueulasser', 'Vaux', 'Gap', 'Valda', 'Français', 'Sut', 'Dise', 'Maquillée', 'Venir', 'Fier', 'Bicêtre', ...
#
# nombre de lieux obtenu dans la liste finale :  862
# {'avenue des Champs', 'du Sud', 'Sambre-et-Meuse', 'avenue Foch', 'La Canebière', 'Tipaza', 'Dieppe', 'Vres', 'Disneyland', 'Stockholm', 'B.I.E.M.', 'Achinan', 'jardin d’Eden', 'petite Delphine', 'pont Mirabeau', 'Lille', 'Amway', 'Rue Saint-Vincent', 'Sentenza', "bois d'Clamart", 'Budapest', 'Abyssinie', 'Man?uvres', 'ligne bleue des Vosges', 'Quito', 'La Rochelle', 'Grèce', 'Faubourg-Saint-Honoré', 'Encastr?e', "Jardin d'Eden", 'New York', 'Népal', 'Saint-Malo', 'Schengen', 'la Rotonde', 'Londres', 'Le Manimal', 'Grand Plazza', 'Rue du Vieux Colombier', 'Sodome et Gomorrhe', 'Tout’', "Heureus'", 'Lololala', 'Gavroche', 'F', 'pont du Clemenceau', 'Dinard', 'Perriers', 'Sologne', 'Nil', 'Goa', 'Ceylan', 'Saint-Bernard', 'Brest', "pont d'Avignon", 'Cordillère des Andes', 'Meuse', 'B.H.V.', 'VC', 'Finistère', "l'Olympia", 'Como yo', 'Puerta', 'Madagascar', 'Branches échevelées', 'Pondichéry', 'Montmertre', 'golfe de Tchernobyl', 'métro Saint Michel', 'Tour Magne', 'Refrain]. Sad Hill', 'Arabie', 'Brazza', 'Éthiopie', "l'Espagne", 'Ténéré', 'Irak', 'Charon', 'Mortadan', 'La Courneuve', 'Honduras', 'Saint-Michel', 'Sunday', 'Arc-en-Ciel', 'Hanoï', 'la Mecque', 'Ayato', 'Californie', 'Te de Saint-Cloud', 'Independenza', 'La France', '‘Inti Fada', 'K', 'Paz', 'Rex', 'Africa', 'la Seine', 'Voil', 'Crozemarie', 'Piennes', 'Sète', 'Recordar', 'U.S.A.', 'Froidevaux', 'Angers', 'Lievin', 'la Bastille', 'Bettancourt', 'Aid', 'Débilos', 'golfe du Lion', 'Imothep', 'Colorado', 'Abscon', 'Atlanta', 'Farang', 'Saint-Jean', 'Vietnam', 'Serai Orly', 'Italie', 'Bab El Oued', 'Prague', 'Bamako', 'Hortens', 'Bhopal', 'Séville', 'Catane', 'Byzance', 'la Sorgue', 'de France', 'Marsala', 'Bagneux', 'jardin des Tuileries', 'Mélanie', "viaduc d'Auteuil", 'Alis', 'Sugar Hill', 'Greenwitch Village', 'Louisiane', 'Tokyo', 'Quartier Nord', 'Babel', 'Maint´nant', 'Vre', 'Dù', 'l’Espagne', 'Tolède', 'Médine', 'Sri Lanka', 'J', 'Macumba', 'Côtes-du-Rhône', 'cordillère des Andes', 'Laintenanmic', 'Singapour', 'Plaza', 'Ve', 'Café du Dôme', 'Allemagne', 'Kader', 'Guèr', 'Omotesandō', 'Vallée des Rois', 'New Orléans', 'Mont Royal', 'Villette', 'Hauts-Plateaux', 'Knokke-le-Zoute', 'Rue de la Soif', 'Haremburgis', 'Qu´il', 'Bibi-la-Purée', 'London', 'Suze', "l'Europe", 'Taïwan', 'C.O.B.de', 'rue du Four', "l'Afrique", "Sirima]. N'", 'So', 'He', 'Tour Montparnasse', 'Atada', 'Ajaccio', 'le Saint-Esprit', 'Rience', 'Palestine', 'Savigny-sur-Orge', 'Goose', 'MoMA', 'rue Blondel', 'rue de Vanves', 'pont de la Villette', 'Butte Rouge', 'Toulon', 'Buffalo Bill', 'du Nord', 'Capdevielle', 'Camaret', 'métro Saint-Mandé', 'Mont Falu', 'DSU', 'Pearl Harbor', 'Tri-Nitro-Toluène', 'Mexique', 'Marny', 'Fort Green', 'Thiais', 'Chari Jazz', 'Jordans', 'Lac Lancelot', 'Euhmm', 'Clap', 'Evêché', 'Sholdès', 'Telecom', 'Lens', 'Capoue', 'Ffu', 'Blooooooondiiiiin', 'Dédé-le-Surineur', 'Bretagne', 'Pattaya', 'M.I.C.', 'Lac Salé', 'Occitants', 'Europe', 'Amérique', 'Esmeralada', 'Paules', 'I', 'Aix', 'Ménilmontant', 'Tcherno', 'Saint-Mandé', 'Concidence', 'Place Vichy', 'Hôtel de Russie', 'tour Magne', 'Beaune', 'Pensamos', 'Deauville', 'Laponie', 'Baileys', 'Egypte', 'Shalamar', "Jardin d'Adam", 'Saint-Cloud', 'Bilbao', 'Eeeeeh!.', 'Pays de Co', 'Recouvrance', 'Welcome Gorby', 'Elégante', 'la Courneuve', 'Saint-Emilion', 'Indonésie', 'Rungis', 'Tours Jumelles', 'Sicile', 'Bosnie', 'Mogador', "Vincenn's", 'St Vincent de Paul', 'CO', 'Nante', 'Tourcoing', 'This', 'jardin du Luxembourg', 'Neptune', 'Grand Manitou', 'Suzon', "Sainte-Mad'lein’", 'Normandie', 'Santiago', 'Jupiter', 'Elysée', 'Louvre', 'Freeman]. Regarde', 'Nuttea].', 'Enfernet', 'KCP', 'C.I.P.', 'Clamart', "l'Italie", 'Charonne', 'Gendes', 'Vercors', 'Silhouette insolite', 'Agadir', 'Big Daddy', 'Indochine', "Rue d'Charonne", 'Katmandou', 'Turlututu', 'Ur', 'Salamanque', 'Versailles', 'Lavilliers', 'RZA].', 'Longwy', 'Chambéry', 'From London', 'Ouarzazate', 'R', 'Rhondda', 'La-la-la', 'Dijon', 'Jaffar', 'Caire', 'Nou terril ...
#
# {'c\x9cur', "port d'", 'aper?u', "croqu'-mort", 'marée', 'la\u2005', "you'", 'l´au', 'v´nu', 'raclée', 'branlée', 'gare de', 'colline de', 's´en', 'n´en', 'd´l´école', 'bande du', "don'", '’'}

# %%
x = [1, 2, 3, 4]
y = [1413, 1349, 881, 862]
labels = ['lieux_lg', 'tri_1', 'tri_2', 'tri_3']

plt.plot(x, y)
# You can specify a rotation for the tick labels in degrees or with keywords.
plt.xticks(x, labels, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.2)
plt.title("Filtrage de l'échantillon2")
plt.ylabel("nombre de lieux")
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)
plt.show()
