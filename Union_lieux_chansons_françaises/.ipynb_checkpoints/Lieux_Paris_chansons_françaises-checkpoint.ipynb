# %%
import json
import codecs
import re
import spacy
import glob
from time import perf_counter

nlp_sm = spacy.load("fr_core_news_sm")
nlp_md = spacy.load("fr_core_news_md")
nlp_lg = spacy.load("fr_core_news_lg")

def ouvrir_json(path):
    f = codecs.open(path, encoding="utf-8")
    toto = json.load(f)
    f.close()
    return toto

def decouper_mots(texte):
    mots = re.findall("[a-zA-ZÀ-ÿ][a-zA-ZÀ-ÿ-]*", texte)
    return mots

def ecrire_fichier(chemin, contenu):
    w = open(chemin, "w", encoding="utf-8")
    w.write(contenu)
    w.close()

def lire_fichier(chemin):
    f = open(chemin, "r", encoding="utf-8")
    chaine = f.read()
    f.close()
    return chaine

def ecrire_json(chemin, contenu):
    w = open(chemin, "w", encoding="utf-8")
    w.write(json.dumps(contenu, indent=2, ensure_ascii=False))
    w.close()

# %%
liste_fichier = glob.glob("/Users/mustapha/Documents/GitHub/28002878/Lyrics_all/*")
print("On traite %i fichiers"%len(liste_fichier))
# Out:
# On traite 1249 fichiers

# %%
infos       = []
lieux_sm    = []
lieux_md    = []
lieux_lg    = []
lieux_union = []
start =time.perf_counter()
for path in liste_fichier:
    d = dict(ouvrir_json(path))
    chansons = d.get("songs")
    artiste = d.get("name")

    for l in chansons:
        paroles = l.get("lyrics")
        if paroles != None:
            date = l.get("release_date")
            titre = l.get("title")
            clean_paroles = re.sub("\n", ". ", paroles) 
            doc1 = nlp_sm(clean_paroles)
            for entity in doc1.ents:
                if entity.label_ =="LOC":
                    lieux = entity.text
                    lieux_sm.append(lieux)
            
            doc2 = nlp_md(clean_paroles)
            for entity in doc2.ents:
                if entity.label_ =="LOC":
                    lieux = entity.text
                    lieux_md.append(lieux)
                    
            doc3 = nlp_lg(clean_paroles)
            for entity in doc3.ents:
                if entity.label_ =="LOC":
                    lieux = entity.text
                    lieux_lg.append(lieux)
            
            lieux_union = (lieux_sm+lieux_md+lieux_lg)
            
            infos.append([{"artiste" :artiste , "titre de la chanson" : titre, "date" : date,"lyrics" : clean_paroles, "lieux" : [l for l in set(lieux_union) if l in clean_paroles]}])

            
        ecrire_json("/Users/mustapha/Documents/GitHub/Memoire/infos&stats/infos_all_data.json",infos)
end = time.perf_counter()
print("temps :",end-start)

# %%
def trouver_lieux(artiste):
    test = ouvrir_json("/Users/mustapha/Documents/GitHub/Memoire/infos&stats/infos_all_data.json")
    list_lieux = []
    for i in test:
        for k in i:
            if k["artiste"] == artiste:
                list_lieux.append(k["lieux"])
    return sum(list_lieux,[])

# %%
trouver_lieux("Ninho")
# Out:
# ['Croquer',
#  'Rose',
#  'I',
#  'O',
#  'Couplet',
#  'J',
#  'Ava',
#  'La',
#  'V',
#  'C',
#  'Paroles',
#  'S',
#  'Refrain',
#  "J'",
#  'D',
#  'Cro',
#  'Ref',
#  'I.',
#  'U',
#  'Refrain].',
#  'N',
#  'R',
#  'Paro',
#  "J's",
#  'M',
#  'Tu',
#  'Mai',
#  'B',
#  'A',
#  'Billie',
#  'Couplet 1].',
#  'P',
#  'Mama',
#  'L',
#  'Ne',
#  'Rose"].',
#  'T',
#  'Portes',
#  'I',
#  'O',
#  'Paris',
#  'Couplet',
#  'Uh',
#  'J',
#  'Let',
#  'La',
#  'In',
#  'C',
#  'Paroles',
#  'S',
#  'Moi',
#  'Mo',
#  'Refrain',
#  "J'",
#  'Qui',
#  'Outro].',
#  'E',
#  'Q',
#  'H',
#  'Ref',
#  'Port',
#  'Elle',
#  'Intro].',
#  'F',
#  'U',
#  'NI',
#  'Refrain].',
#  'N',
#  'Y',
#  'R',
#  'Paro',
#  'M',
#  'G',
#  'Ha',
#  'Po',
#  'Classe S',
#  'El',
#  'Mai',
#  'Classe',
#  'Couplet 1].',
#  'P',
#  'L',
#  'Wi',
#  'Ne',
#  'Afrique',
#  'I',
#  'O',
#  'Paris',
#  'Couplet',
#  'Emilio',
#  'J',
#  'eau"].',
#  'La',
#  'In',
#  'C',
#  'Paroles',
#  'S',
#  'Les',
#  "J'",
#  'D',
#  'Beckham',
#  'Outro].',
#  'E',
#  'I.',
#  'Intro].',
#  'Sheitan',
#  'Classe E',
#  'Be',
#  'N',
#  'Ouai',
#  'Goutte',
#  'R',
#  'Paro',
#  "J's",
#  'M',
#  'G',
#  'Tu',
#  'Rotte',
#  'Mai',
#  'B',
#  'A',
#  'Classe',
#  'Bah',
#  'Ouais',
#  'P',
#  'L',
#  'K',
#  'She',
#  'Regarde',
#  'T',
#  'Pont',
#  'Ca',
#  'I',
#  'O',
#  'S.',
#  'To',
#  'Évry',
#  'Briganté',
#  'Couplet',
#  'J',
#  'Iblis',
#  'Retiens',
#  'Niska',
#  'Laisse',
#  'Parigot',
#  'Nouveau',
#  'Face',
#  'A.L',
#  'Mada',
#  'Ti',
#  'La',
#  'In',
#  'C',
#  'Paroles',
#  'Tiens',
#  'S',
#  'Attends',
#  'Refrain',
#  'Les',
#  'Madam',
#  'Lai',
#  'D',
#  'l’',
#  'E',
#  'J’',
#  'Cro',
#  'Niska].',
#  'Pon',
#  'H',
#  'c’',
#  'Ref',
#  'F',
#  'N',
#  'Ouai',
#  'j’',
#  'Cayenne S. Parigot',
#  'R',
#  'Paro',
#  'A.',
#  'M',
#  'Ni',
#  'Fac',
#  'Po',
#  'Cayenne',
#  'Crois',
#  'B',
#  'A',
#  '’',
#  'S.A.L',
#  'Ouais',
#  'P',
#  'Mama',
#  'L',
#  'Balmain',
#  'T',
#  'Ca',
#  'I',
#  'Sevran',
#  'O',
#  'To',
#  'Couplet',
#  'J',
#  'Mal',
#  'La',
#  'C',
#  'Paroles',
#  'S',
#  'Refrain',
#  "J'",
#  'D',
#  'E',
#  'Q',
#  'Beaucoup',
#  'Beau',
#  'Ref',
#  'Fumée',
#  'F',
#  'Fumé',
#  'Refrain].',
#  'Faut',
#  'Be',
#  'N',
#  'Y',
#  'R',
#  'Paro',
#  'M',
#  'G',
#  'Demande',
#  'Beaudottes',
#  'B',
#  'A',
#  'Couplet 1].',
#  'P',
#  'L',
#  'T',
#  'Pont',
#  'Ca',
#  'I',
#  'O',
#  'To',
#  'Sha',
#  'Couplet',
#  "Y'",
#  'la Mecque',
#  'J',
#  'San',
#  'Santa Monica',
#  'Donc',
#  'La',
#  'In',
#  'C',
#  'S',
#  'Moi',
#  'Di',
#  'Mo',
#  'Bar',
#  'Shaquille',
#  'Les',
#  'Mont',
#  "J'",
#  'D',
#  'Judas',
#  'Donne',
#  'Outro].',
#  'E',
#  'Barcelonais',
#  'Q',
#  'Pon',
#  'H',
#  'Die',
#  'Elle',
#  'Intro].',
#  'U',
#  'Don',
#  'Santa',
#  'Poi',
#  'Monte',
#  'N',
#  'Y',
#  'R',
#  "J's",
#  'Quel',
#  'Business',
#  'M',
#  'G',
#  'Po',
#  'Gan',
#  'Tu',
#  'Peut',
#  'El',
#  'Mai',
#  'B',
#  'A',
#  'Mecque',
#  'Couplet 1].',
#  'P',
#  'L',
#  'K',
#  'Ne',
#  'Makélélé',
#  'T',
#  'I',
#  'O',
#  'Couplet',
#  'J',
#  'La',
#  'In',
#  'Sure',
#  'C',
#  'S',
#  'Pour',
#  'Di',
#  'Refrain',
#  'So',
#  'Les',
#  "J'",
#  'D',
#  'Outro].',
#  'l’',
#  'Haut',
#  'E',
#  'Très',
#  'Con',
#  'H',
#  'Ref',
#  'Surement',
#  'Die',
#  'Intro].',
#  'F',
#  'Plume',
#  'Refrain].',
#  'Faut',
#  'R',
#  'M',
#  'Ha',
#  'Po',
#  'Mai',
#  'Perdu',
#  'A',
#  '’',
#  'Couplet 1].',
#  'P',
#  'Mama',
#  'L',
#  'T',
#  'I',
#  'Mouss',
#  'Coca',
#  'For',
#  'Paname',
#  'Panam',
#  'Couplet',
#  'J',
#  'F430',
#  'Bois',
#  'Laisse',
#  'Rotterdam',
#  'Panamera',
#  'La',
#  'V',
#  'C',
#  'Paroles',
#  'S',
#  'Pour',
#  'Pas',
#  'Mo',
#  'Refrain',
#  'So',
#  'Les',
#  "J'",
#  'Lai',
#  'D',
#  'E',
#  'F4',
#  'Cha',
#  'Ref',
#  'Elle',
#  'F',
#  'U',
#  'Personne',
#  'Poi',
#  'Meda',
#  'Alicante',
#  'Agadir',
#  'N',
#  'Bakyl',
#  'R',
#  'Paro',
#  "J's",
#  'M',
#  'Rif',
#  'Ni',
#  'Po',
#  'Pana',
#  'Tu',
#  'Rotte',
#  'Champs',
#  'El',
#  'Breda',
#  'Seigneur',
#  'B',
#  'Pointe-à-Pitre',
#  'A',
#  'Vrai',
#  'P',
#  'L',
#  'T',
#  'I',
#  'O',
#  'Couplet',
#  'J',
#  'Es',
#  'Ti',
#  'La',
#  'In',
#  'C',
#  'Tiens',
#  'S',
#  'Pour',
#  'Mo',
#  'Bar',
#  'Les',
#  "J'",
#  'Travaille',
#  'R8',
#  'E',
#  'Nelles',
#  'Barre',
#  'Très',
#  'Sec',
#  'H',
#  'I.',
#  'Elle',
#  'Intro].',
#  'F',
#  'U',
#  'Not',
#  'N',
#  'Ouai',
#  'He',
#  'Bin',
#  'R',
#  "J's",
#  'M',
#  'G',
#  'Ha',
#  'Po',
#  'Pre',
#  'Tu',
#  'Est',
#  'El',
#  'Mai',
#  'B',
#  'Travail',
#  'Couplet 1].',
#  'Ouais',
#  'P',
#  'L',
#  'Hag',
#  'Ne',
#  'Seconde',
#  'Regarde',
#  'T',
#  'Ca',
#  'I',
#  'O',
#  'To',
#  'For',
#  'Paname',
#  'Panam',
#  'Couplet',
#  'Man',
#  'J',
#  'Air',
#  'Jack',
#  'Donc',
#  'Ton',
#  'MC',
#  'La',
#  'In',
#  'V',
#  'C',
#  'Paroles',
#  'S',
#  'Moi',
#  'Nique',
#  'Bercy',
#  'Di',
#  'Mo',
#  'Hummer',
#  'Aaliyah',
#  'Grosse',
#  'Les',
#  "J'",
#  'Dis',
#  'D',
#  'Nike Air',
#  'Outro].',
#  'E',
#  'Q',
#  'Beaucoup',
#  'Mystérieux',
#  'm’',
#  'H',
#  'Beau',
#  'I.',
#  'Intro].',
#  'F',
#  'Don',
#  'Be',
#  'N',
#  'Tupac',
#  'R',
#  'Paro',
#  "J's",
#  'Tony',
#  'M',
#  'G',
#  'Ni',
#  'Pana',
#  'Manny',
#  'Tu',
#  'Daniel',
#  'Hu',
#  'Mai',
#  'B',
#  'A',
#  '’',
#  'Bah',
#  'Toulouse',
#  'P',
#  'L',
#  'T',
#  'I',
#  'Gal',
#  'O',
#  'Couplet',
#  'J',
#  'Faouzia].',
#  'd’',
#  'In',
#  'C',
#  'Paroles',
#  'S',
#  'Te',
#  'Di',
#  'Mo',
#  'Refrain',
#  'Tell',
#  "J'",
#  'qu’',
#  'Dis',
#  'D',
#  'E',
#  'Tel',
#  'Got',
#  'J’',
#  'H',
#  'Ref',
#  'Elle',
#  'F',
#  'U',
#  'N',
#  'j’',
#  'Music',
#  'He',
#  'I know',
#  'Y',
#  'R',
#  'Paro',
#  'M',
#  'G',
#  'Ni',
#  'El',
#  '’',
#  'Yeah',
#  'P',
#  'K',
#  'T',
#  't’',
#  'Ca',
#  'I',
#  'O',
#  'Hey',
#  'Couplet',
#  'J',
#  'Vive',
#  'RS',
#  'Z',
#  'Sinatra',
#  'La',
#  'In',
#  'V',
#  'C',
#  'Paroles',
#  'S',
#  'Givenchy',
#  'Refrain',
#  "J'",
#  'Outro].',
#  'E',
#  'Con',
#  'H',
#  'Ok',
#  'Ref',
#  'Guadeloupe',
#  'Cayenne A',
#  'I.',
#  'Intro].',
#  'F',
#  'Carla',
#  'Refrain].',
#  'Zipette',
#  'Faut',
#  'Lambo',
#  'He',
#  'Y',
#  'Eh',
#  'R',
#  'Paro',
#  "J's",
#  'M',
#  'G',
#  'MB',
#  'Cayenne',
#  'Tu',
#  "Lambo'",
#  'François',
#  'B',
#  'A',
#  '’',
#  'P',
#  'L',
#  'K',
#  'Saïdia',
#  'T',
#  'Pont',
#  'I',
#  'O',
#  'Coca',
#  'To',
#  'Couplet',
#  "Y'",
#  'J',
#  'Donc',
#  'Ti',
#  'La',
#  'In',
#  'V',
#  'C',
#  'Tiens',
#  'Moi',
#  'Tic',
#  'Mo',
#  'Refrain',
#  'Les',
#  "J'",
#  'LA',
#  'Qui',
#  'D',
#  'AP',
#  'E',
#  'Q',
#  'Pon',
#  'Cherche',
#  'Wallaye',
#  'Ref',
#  'Toi',
#  'I.',
#  'Russie',
#  'Intro].',
#  'F',
#  'U',
#  'Don',
#  'Ré',
#  'MK',
#  'Refrain].',
#  'Cher',
#  'N',
#  'Ouai',
#  'Bin',
#  'Y',
#  'R',
#  'Roubaix',
#  "J's",
#  'Viens',
#  'A.',
#  'M',
#  'G',
#  'Po',
#  'Tu',
#  'Mai',
#  'B',
#  'A',
#  'Couplet 1].',
#  'Ouais',
#  'P',
#  'L',
#  'K',
#  'Ring',
#  'T',
#  'Pont',
#  'I',
#  'O',
#  'Couplet',
#  "Y'",
#  'J',
#  'Mal',
#  'In',
#  'C',
#  'Paroles',
#  'S',
#  'Pour',
#  'Mo',
#  'Refrain',
#  'Les',
#  "J'",
#  'Qui',
#  'D',
#  'E',
#  'Malaga',
#  'Q',
#  'm’',
#  'Pon',
#  'Encore',
#  'Ref',
#  'Intro].',
#  'U',
#  'Ré',
#  'Refrain].',
#  'N',
#  'Y',
#  'R',
#  'Paro',
#  'M',
#  'Ni',
#  'Po',
#  'Twitte',
#  'Tu',
#  'Broliqué',
#  'Mai',
#  'Mala',
#  'B',
#  'A',
#  '’',
#  'Couplet 1].',
#  'P',
#  'Mama',
#  'L',
#  'T',
#  'Ca',
#  'Rio',
#  'I',
#  'O',
#  'To',
#  'Couplet',
#  'J',
#  'Casa',
#  'Adidas',
#  'Ava',
#  'La',
#  'In',
#  'V',
#  'C',
#  'Paroles',
#  'S',
#  'Pas',
#  'Refrain',
#  'Les',
#  "J'",
#  'D',
#  'E',
#  'L.A',
#  'Q',
#  'Ref',
#  'Toi',
#  'Elle',
#  'Bang',
#  'F',
#  'Don',
#  'Tom',
#  'N',
#  'L.A.',
#  'Y',
#  'Dom',
#  'Vendre',
#  'R',
#  'Paro',
#  "J's",
#  'Ya',
#  'A.',
#  'M',
#  'Ni',
#  'Tu',
#  'El',
#  'B',
#  'A',
#  'Bien',
#  '’',
#  'Bah',
#  'P',
#  'L',
#  'T',
#  'I',
#  'O',
#  'To',
#  'Puce',
#  'RMT',
#  'Plaquette',
#  'Couplet',
#  'J',
#  'Boloss',
#  'Z',
#  'Pelé',
#  'Ton',
#  'Ti',
#  'La',
#  'Bolo',
#  'V',
#  'C',
#  'S',
#  'Te',
#  'Pochtar',
#  'Mo',
#  'Bar',
#  'So',
#  'Grosse',
#  "J'",
#  'D',
#  'RM',
#  'Bare',
#  'E',
#  'Gare',
#  'Parle',
#  'Q',
#  'Garette',
#  'Ok',
#  'Algérie',
#  'Elle',
#  'F',
#  'U',
#  'Personne',
#  'Frappe',
#  'Shit',
#  'Mass',
#  'N',
#  'R',
#  "J's",
#  'M',
#  'G',
#  'Algérien',
#  'Ni',
#  'Po',
#  'Algé',
#  'Tu',
#  '75',
#  'El',
#  'Mai',
#  'B',
#  'Oui',
#  'A',
#  'P',
#  'L',
#  'Ne',
#  'T',
#  'I',
#  'O',
#  'To',
#  'Couplet',
#  'J',
#  'Mona',
#  'Z',
#  'Ton',
#  'Mada',
#  'V',
#  'C',
#  'Paroles',
#  'S',
#  'Mo',
#  'Refrain',
#  'So',
#  "J'",
#  'Madam',
#  'Derrière',
#  'D',
#  'His',
#  'Quattro',
#  'Outro].',
#  'E',
#  'Q',
#  'TP',
#  'H',
#  'Ref',
#  'Elle',
#  'Audi',
#  'F',
#  'U',
#  'Sosa',
#  'Monaco',
#  'Refrain].',
#  'N',
#  'O.',
#  'Ouai',
#  'Hi',
#  'Music',
#  'R',
#  'Paro',
#  "J's",
#  'VI',
#  'Tony',
#  'M',
#  'Tu',
#  'El',
#  'Mai',
#  'A',
#  'Couplet 1].',
#  'Ouais',
#  'P',
#  'L',
#  'K',
#  'T',
#  'Élysées',
#  'I',
#  'O',
#  'Hey',
#  'Couplet',
#  'Man',
#  'J',
#  'Z',
#  'Jack',
#  'La',
#  'In',
#  'V',
#  'C',
#  'Paroles',
#  'S',
#  'Pas',
#  'Mental',
#  'Refrain',
#  'So',
#  'Les',
#  "J'",
#  'Qui',
#  'D',
#  'E',
#  'Cha',
#  'Q',
#  'Beaucoup',
#  'H',
#  'Beau',
#  'Encore',
#  'Ref',
#  'Champs Élysées',
#  'I.',
#  'Elle',
#  'Intro].',
#  'F',
#  'Menta',
#  'U',
#  'Lo',
#  'Viano',
#  'Refrain].',
#  'Be',
#  'Élysée',
#  'Pluton',
#  'He',
#  'R',
#  'Paro',
#  "J's",
#  'Papa',
#  'Quel',
#  'Ze',
#  'M',
#  'G',
#  'Ély',
#  'Manny',
#  'Tu',
#  'Igo',
#  'Quelque',
#  'Champs',
#  'El',
#  'Mai',
#  'Seigneur',
#  'B',
#  'A',
#  'Men',
#  'Bah',
#  'Couplet 1].',
#  'P',
#  'L',
#  'T',
#  'Ca',
#  'I',
#  'O',
#  'To',
#  'Nord',
#  'Couplet',
#  'J',
#  'Retiens',
#  'RS',
#  ...]

# %%
IDF_json = glob.glob("/Users/mustapha/Documents/GitHub/Memoire/Data/lieux_paris/*.json")
list_lieux_IDF = []
for fichier in IDF_json:
    lp = ouvrir_json(fichier)
    for lieu in lp:
        list_lieux_IDF.append(lieu)
print(list_lieux_IDF)
# Out:
# ["Pointe de l'Arsenal", 'Pointe Saint-Eustache', 'Pointe Trigano', 'Porte Brancion', 'Porte Brunet', 'Porte Chaumont', 'Porte Dauphine', 'Porte Didot', 'Porte Dorée', 'porte de Picpus', 'Porte Jaune', 'Porte Maillot', 'Porte Pouchet', 'Porte Saint-James', "Porte d'Arcueil", "Porte d'Asnières", "Porte d'Aubervilliers", "Porte d'Auteuil", "Porte d'Issy", "Porte d'Italie", "Porte d'Ivry", "Porte d'Orléans", 'Porte de Bagatelle', 'Porte de Bagnolet', 'Porte de Bercy', 'Porte de Boulogne', 'Porte de Champerret', 'Porte de Charenton', 'Porte de Choisy', 'Porte de Châtillon', 'Porte de Clichy', 'Porte de Clignancourt', 'Porte de Courcelles', 'Porte de Gentilly', 'Porte de Madrid', 'Porte de Montempoivre', 'Porte de Montmartre', 'Porte de Montreuil', 'Porte de Montrouge', 'Porte de Ménilmontant', 'Porte de Neuilly', 'Porte de Pantin', 'Porte de Passy', 'Porte de Plaisance', 'Porte de Reuilly', 'Porte de Saint-Cloud', 'Porte de Saint-Mandé', 'Porte de Saint-Ouen', 'Porte de Sèvres', 'Porte de Vanves', 'Porte de Versailles', 'Porte de Villiers', 'Porte de Vincennes', 'Porte de Vitry', "Porte de l'Hippodrome", 'Porte de la Chapelle', 'Porte de la Gare', 'Porte de la Muette', 'Porte de la Plaine', 'Porte de la Seine', 'Porte de la Villette', 'Porte des Lilas', 'Porte des Lilas', 'Porte des Poissonniers', 'Porte des Sablons', 'Porte des Ternes', 'Porte du Bas-Meudon', 'Porte du Bel-Air', 'Porte du Point-du-Jour', 'Porte du Pré-Saint-Gervais', 'Abbaye Sainte-Geneviève', 'Abbaye du Val de Grâce', 'Abbaye Saint-Victor', 'Abbaye Saint-Germain des Prés', 'Abbaye de Panthemont', 'Abbaye Saint-Antoine des Champs', 'Abbaye de Port-Royal', 'Abbaye de Longchamp', 'Abbaye de Montmartre', 'Cathédrale Notre-Dame de Paris', 'Basilique Sainte-Clotilde', 'Basilique du Sacré-Cœur de Montmartre', 'Basilique Notre-Dame des Victoires', "Basilique Sainte-Jeanne d'Arc", 'Carmel de la place Maubert', 'couvent des Capucins', 'Cathédrale Notre-Dame de Paris', 'Cathédrale Saint-Étienne de Paris', 'hôpital de la Charité', 'Cathédrale Saint-Louis des Invalides', 'Cathédrale Saint-Jean-Baptiste de Paris', 'Sainte-Chapelle du Palais', 'Chapelle Saint-Éloi', 'Chapelle Saint-Michel du Palais', "Chapelle de Sainte-Marie l'Égyptienne", "Chapelle de l'Humanité\u200f\u200e", 'Chapelle Saint-Julien des Enfants Rouges', 'Chapelle Saint-Aignan', 'Chapelle Saint-Bon', 'Chapelle Saint-Luc', 'Chapelle de la Sorbonne', 'Chapelle Saint-Vincent de Paul', 'Chapelle expiatoire', 'Chapelle Notre-Dame de Consolation', 'Bazar de la Charité', 'Chapelle Notre-Dame de Lorette', 'Chapelle Saint Louis de la Salpêtrière', 'Chapelle Saint-Yves', 'Chapelle Saint-Ferdinand', 'Chapelle du Père-Lachaise', 'Cimetières de Paris existants et disparus', 'Collège des Bons Enfants', 'Couvent et collège des Bernardins', 'Collège des Écossois', 'Collège Fortet', 'Collège Louis le Grand\u200f\u200e', 'Collège Royal', 'Collège Sainte Barbe', 'Collège de Sorbonne', 'Collège des Trentre trois', "Collège d'Arras", "Collège de l'Ave Maria", 'Collège de Bayeux', 'Collège de Beauvais\u200f\u200e', 'Collège de Boncour', 'Collège des Bons Enfants', 'Collège du Cardinal Lemoine\u200f\u200e\u200f\u200e', 'Collège des Cholets', 'Collège de Cluny', 'Collège de Cornouailles', 'Collège des Grassins', "Collège d'Harcourt", 'Collège de Justice', 'Collège de Laon', 'Collège de Lisieux', 'Collège des Lombards\u200f\u200e', 'Collège de Maître Gervais\u200f\u200e', 'Collège du Mans\u200f\u200e', 'Collège de la Marche', 'Collège de la Merci', 'Collège de Montaigu', 'Collège de Narbonne', 'Collège de Navarre', 'Collège du Plessis', 'Collège de Presle', 'Collège de Rheims', 'Collège Saint-Michel', 'Collège de Séez', 'Collège des Trésoriers', 'Collège des Trois Évêques', 'collège de Cambrai', 'Collège de Bourgogne', 'Collège Mazarin', 'Collège des Quatre Nations', "Collège d'Autun", 'Collège de Boissy', 'Collège Dainville', 'Collège de Gramont', 'Collège Mignon\u200f\u200e', 'Collège des Prémontrés', 'Collège de Tours', 'Commanderie ...

# %%
def lieux_Paris(artiste, list_lieux_IDF):
    lieux_Paris = []
    for lieu in trouver_lieux(artiste):
        for lp in list_lieux_IDF:
            if lp.lower() == lieu.lower():
                lieux_Paris.append(lp)
    return lieux_Paris

# %%
print(set(lieux_Paris("MC Solaar",list_lieux_IDF)))
# Out:
# {'Amérique', 'Us', 'Saint-Georges', 'Seine', 'Fresnes', 'Bondy', 'Pologne', 'Halles', 'Baby', 'moulin', 'Paris'}

# %% [markdown]
# Fréquence d’apparition d’un lieu dans le corpus
# -----------------

# %%
def occurrence_lieu(lieu):
    lieux_corpus = ouvrir_json("/Users/mustapha/Documents/GitHub/Memoire/infos&stats/infos_all_data.json")
    list_lieux = []
    freq = {}
    for i in lieux_corpus:
        for e in i:
            list_lieux.append(e["lieux"])
    lieux = sum(list_lieux,[])

    for e in lieux:
        if e.lower() == lieu:
            freq.setdefault(e, 0)
            freq[e]+=1
    return freq

# %%
print(occurrence_lieu("paris"),occurrence_lieu("porte de la chapelle"),occurrence_lieu("rue des ecoles"))
# Out:
# {'Paris': 832} {'Porte de la Chapelle': 1} {'rue des Ecoles': 1}

# %%
def fonction_bonus(lieu):
    infos = ouvrir_json("/Users/mustapha/Documents/GitHub/Memoire/infos&stats/infos_all_data.json")
    informations = []
    for i in infos:
        for k in i:
             for e in k["lieux"]:
                    for lp in list_lieux_IDF:
                        if e.lower() == lieu and lp.lower() == lieu:
                            informations.append([k["artiste"],k["titre de la chanson"],k["date"]])
    return informations

# %%
fonction_bonus("paris")
# Out:
# [['Octobre Rouge', 'Week-end à Meda', '2002-09-03'],
#  ['Octobre Rouge', 'Nuits blanches', '2004-10-27'],
#  ['Octobre Rouge', 'Air Guinée', '2004-10-27'],
#  ['Octobre Rouge', 'Décollement pulmonaire', '2004-10-27'],
#  ['Octobre Rouge', 'J’quitte le tiécar', '2007-03-26'],
#  ['Octobre Rouge', 'Uniformatage', '2004-10-27'],
#  ['Octobre Rouge', 'L’enfer', '2002-09-03'],
#  ['Guesch Patti', 'Bon Anniversaire', None],
#  ['Guesch Patti', 'Manque Un Détail', None],
#  ['Yves Simon', 'L’aérogramme de Los Angeles', '1975-01-01'],
#  ['Yves Simon', 'Les Gauloises bleues', None],
#  ['Yves Simon', 'Tu ne dis plus rien', None],
#  ['Yves Simon', 'Les Brumes de la Seine', None],
#  ['Yves Simon', 'De l’autre côté de ton âme', None],
#  ['Yves Simon', 'Police parano blues', None],
#  ['Yves Simon', 'Africain', None],
#  ['Yves Simon', 'Petite fille, p’tite misère', None],
#  ['Yves Simon', 'Oublie-moi', None],
#  ['Bilal Hassani', 'BOOM x3', '2019-04-26'],
#  ['Tété (FRA)', 'De ce côté-ci du bonheur', None],
#  ['Tété (FRA)', 'Les Rallyes', None],
#  ['Big Red', 'Deenastyle', '1999-06-08'],
#  ['Jenn Ayache', 'J’ai Voyagé', '2014-09-22'],
#  ['Cléa Vincent', 'N’allez pas travailler', '2020-04-30'],
#  ['Cléa Vincent', 'Ton voyage est fini', '2014-03-10'],
#  ['Rachid Taha', 'Barbès', None],
#  ['Joe Dassin', 'La bande à Bonnot', None],
#  ['Joe Dassin', 'La Rue Marie-Laurence', None],
#  ['Joe Dassin', 'La complainte de l’heure de pointe', None],
#  ['Joe Dassin', 'C’est ma tournée', None],
#  ['Joe Dassin', 'Allez, roulez!', None],
#  ['Joe Dassin',
#   'La complainte de l’heure de pointe (A vŽlo dans Paris)',
#   None],
#  ['A2H', 'Les yeux d’un rider', '2016-06-06'],
#  ['A2H', 'Décisions', '2016-04-15'],
#  ['A2H', 'Classic Rework #1 (Suga Suga)', '2017-04-19'],
#  ['A2H', 'Palace Paradise', '2017-02-24'],
#  ['A2H', 'Aie aie aie', '2017-07-21'],
#  ['A2H', 'Tantine', '2014-05-26'],
#  ['A2H', 'Océan', '2017-07-21'],
#  ['A2H', 'Champagne', '2014-05-26'],
#  ['A2H', 'Clio Grise', None],
#  ['A2H', 'Bouger', None],
#  ['A2H', 'Itinéraire', '2011-12-01'],
#  ['A2H', 'Soda', None],
#  ['A2H', 'Booska Rédemption', '2020-10-19'],
#  ['A2H', 'En attendant l’album (Episode 2)', '2013-12-27'],
#  ['Dorothée', 'Vive Les Vacances', None],
#  ['Jean-Louis Aubert', 'Dis quand reviendras tu ?', None],
#  ['Leny Escudero', 'Paris la Seine', None],
#  ['Leny Escudero', 'Rue de Belleville', None],
#  ['Leny Escudero', 'Tout Ce Qu’Il A Fallu', None],
#  ['Caroline Costa', 'Ailleurs', '2017-06-24'],
#  ['Mathieu Saïkaly', 'Je t’ai cherchée', '2015-09-28'],
#  ['Sacha Distel', 'Monsieur Cannibale', None],
#  ['Kelly Joyce', 'Vivre La Vie', None],
#  ['Serge Lama', 'Femme Femme Femme', None],
#  ['Thierry Pastor', 'Magic Music', None],
#  ['Christine and the Queens', 'Photos Souvenirs', None],
#  ['Lomepal', 'Yeux disent', '2017-06-19'],
#  ['Lomepal', 'Billet', '2017-06-30'],
#  ['Lomepal', 'Deux', '2018-05-16'],
#  ['Lomepal', 'Enter the void', '2014-09-01'],
#  ['Lomepal', 'Roule', '2013-09-02'],
#  ['Lomepal', 'Citroën', '2013-09-09'],
#  ['Lomepal',
#   'Freestyle 18/12/2017 - Lomepal, Georgio, Limsa, L’affreux Jojo, Fixpen Sill, Bohemian Club',
#   '2017-12-18'],
#  ['Lomepal', 'R2D2 (Superpopoze Remix)', '2016-05-27'],
#  ['Lomepal', 'Étrange journée', None],
#  ['Columbine', 'Cache-Cache', '2018-07-13'],
#  ['Columbine', 'Eric & Dylan (Dirty)', '2015-11-08'],
#  ['Dadju', 'Paire d’As', '2019-11-15'],
#  ['Dadju', 'Sous contrôle', '2017-11-24'],
#  ['Dadju', 'Compliqué', '2019-06-28'],
#  ['Dadju', 'Freestyle Booska’Gentleman', '2017-11-23'],
#  ['Marie-Paule Belle', 'Les bigoudis', None],
#  ['Marie-Paule Belle', 'L’hiver des cœurs', None],
#  ['Marie-Paule Belle', 'Paris, fais-toi faire un lifting', None],
#  ['Cyril Mokaiesh', 'Clôture', '2017-01-20'],
#  ['Cyril Mokaiesh', 'Novembre à Paris', '2017-01-20'],
#  ['Cyril Mokaiesh', 'Jeux de la vie', '2014-05-05'],
#  ['Cyril Mokaiesh', 'Pardon Paris', '2020-01-09'],
#  ['Cyril Mokaiesh', 'L’origine', '2020-01-09'],
#  ['Lady Laistee', 'Les keufs me matent', None],
#  ['Lady Laistee', 'Interlude', '2002-10-07'],
#  ['Lady Laistee', 'Second souffle', '2005-12-01'],
#  ['Lilian Renaud', 'Le Loir-et-Cher', None],
#  ['Minuit', 'Paris Tropical', None],
#  ['Julien Clerc', 'La cavalerie', None],
#  ['Julien Clerc', 'Weekend', None],
#  ['Julien Clerc', 'Nouveau big bang', None],
#  ['Julien Clerc', 'Place Clichy', '2005-10-03'],
#  ['Julien Clerc', 'Je suis mal', None],
#  ['Julien Clerc', 'Ivanovitch', None],
#  ['Julien Clerc', 'Souvenez-vous', '2008-09-16'],
#  ['Julien Clerc', 'La rue blanche, le petit matin bleu', '2008-09-16'],
#  ['Julien Clerc', 'Black Out (Faire L’Amour Ici)', None],
#  ['Julien Clerc', 'Free Demo', '1992-12-08'],
#  ['Julien Clerc', 'La Rue Blacnhe, Le Petit Matin Bleu', None],
#  ['Féfé', 'Mes Héros - Version Acoustique', None],
#  ['Vanessa Paradis', 'Papa Paris', None],
#  ['Vanessa Paradis', 'Papa Paname', '2011-10-12'],
#  ['Matmatah', 'Casi el silencio', None],
#  ['Carmen Maria Vega', 'Le fourbe', None],
#  ['Georges Chelon', 'Je n’suis pas la Seine', None],
#  ['Georges Chelon', 'Vacances romaines', None],
#  ['La Fouine', 'Va Bene', '2014-10-31'],
#  ['La Fouine', 'Reste en chien', '2007-03-12'],
#  ['La Fouine', 'Intro (CDC4)', '2014-11-24'],
#  ['La Fouine', 'T’es mort dans l’film', '2011-11-28'],
#  ['La Fouine', 'Banlieue Sale', '2007-03-12'],
#  ['La Fouine', 'Mes repères', '2009-02-23'],
#  ['La Fouine', 'La Fouine VS Laouni', '2016-03-04'],
#  ['La Fouine', 'On se refait', '2011-11-28'],
#  ['La Fouine', 'Je l’aime quand même', '2016-03-04'],
#  ['La Fouine', 'Trappes', '2016-03-04'],
#  ['La Fouine', 'Fouiny dance', '2017-06-02'],
#  ['La Fouine', 'Freestyle Skyrock (Planète Rap)', None],
#  ['La Fouine', 'La danse du ghetto', '2007-03-12'],
#  ['La Fouine', 'Dans nos quartiers', '2010-07-12'],
#  ['La Fouine', 'Tire sur les gens', '2008-02-18'],
#  ['La Fouine', 'Veni, vidi, vici - Remix', '2011-06-27'],
#  ['Sloane', 'Down From Here', '2020-07-24'],
#  ['Aya Nakamura', 'Gang', '2018-11-02'],
#  ['La Grande Sophie', 'Dis, quand reviendras-tu ?', '2009-01-26'],
#  ['La Grande Sophie', 'Chanson Demi Minute', None],
#  ['Jena Lee', 'US Boy', '2010-01-01'],
#  ['Michel Polnareff', 'Je Suis Un Homme', None],
#  ['Alexis Hk', 'Cyclopède', '2002-10-16'],
#  ['Bernard Lavilliers', 'Borinqueño', None],
#  ['Bernard Lavilliers', 'Préface', None],
#  ['Bernard Lavilliers', 'Paris', None],
#  ['Bernard Lavilliers', 'Paris-redingote de plomb', None],
#  ['Bernard Lavilliers', 'Paris La Grise', None],
#  ['Anne Sylvestre', 'Plus personne à Paris', '1974-01-01'],
#  ['Rouda', 'Paris canaille... Paris racaille', '2007-10-25'],
#  ['William Baldé', 'Le quartier', None],
#  ['Thomas Fersen', 'Au café de la paix', None],
#  ['Gilles Dreu', 'Je reviens chez nous', '1997-08-03'],
#  ['Lucienne Delyle', 'Le Moulin de la galette', None],
#  ['Lucienne Delyle', 'Mimi La Rose', None],
#  ['Lucienne Delyle', 'Le Monsieur Aux Lilas', None],
#  ['MC Solaar', 'Nouveau Western', '1994-02-09'],
#  ['MC Solaar', 'Obsolète', '1994-02-07'],
#  ['MC Solaar', 'Gangster Moderne', '1997-07-07'],
#  ['MC Solaar', 'Géopoétique', '2017-09-29'],
#  ['MC Solaar', 'Si je meurs ce soir', None],
#  ['MC Solaar', 'Samedi Soir (sur un banc)', None],
#  ['MC Solaar', 'Ben Oui !', None],
#  ['MC Solaar', 'Superstarr', '1994-02-09'],
#  ['MC Solaar', 'Protège tibia', '1997-07-07'],
#  ['MC Solaar', 'Je me souviens', None],
#  ['MC Solaar', 'Represent (inédit)', '1995-01-01'],
#  ['Sylvie Vartan', 'La Maritza', None],
#  ['Sylvie Vartan', 'Nicolas', None],
#  ['Sylvie Vartan', 'Back to L-A', None],
#  ['Têtes Raides', 'L’Iditenté', None],
#  ['Têtes Raides', 'Pas à Pas', None],
#  ['Têtes Raides', 'Chanson Marrante Pour Les Enfants Trit’stes', None],
#  ['Têtes Raides', 'Les Clampettes', None],
#  ['Alkpote', 'Chiens', '2010-11-11'],
#  ['Alkpote', 'Gainzbeur', '2012-03-19'],
#  ['Alkpote', 'Super fluxxx', '2016-06-24'],
#  ['Alkpote', 'Bourguiba', '2012-03-19'],
#  ['Alkpote', 'Faire du gent-ar', '2015-05-11'],
#  ['Alkpote', 'J’suis die', '2012-11-26'],
#  ['Alkpote', 'L’envahisseur', '2008-05-10'],
#  ['Alkpote', '#EVRY', '2015-05-11'],
#  ['Alkpote', 'Session freestyle monumentale', '2019-11-11'],
#  ['Alkpote', 'Frissonnez', '2006-04-19'],
#  ['Alkpote', 'Mongoldorak (Remix)', '2014-04-07'],
#  ['Alkpote', 'Égaré', '2014-04-07'],
#  ['Alkpote', 'Appel privé', '2012-03-19'],
#  ['Alkpote', 'Kalash & lance-pierres', '2010-09-13'],
#  ['Alkpote', 'La crème du 91 - Morceau caché', '2009-06-15'],
#  ['Alkpote', '91 trop violent', '2009-06-01'],
#  ['Alkpote', 'La crasse d’Île de France', '2009-06-01'],
#  ['Dario Moreno', 'CEst Magnifique', None],
#  ['Axel Bauer', 'Rien ne s’oublie', None],
#  ['Guizmo', 'C’est tout', None],
#  ['Guizmo', 'Alcool et bédo', '2011-10-03'],
#  ['Guizmo', 'J’te déteste', '2011-10-03'],
#  ['Guizmo', 'Dans ma ruche', '2014-12-15'],
#  ['Guizmo', 'Le café', None],
#  ['Guizmo', 'Escort girl', '2017-11-03'],
#  ['Guizmo', 'Grand Final', '2017-08-04'],
#  ['Guizmo', 'On est au calme', '2013-06-19'],
#  ['Guizmo', 'C’est pas la même', '2012-04-16'],
#  ['Guizmo', 'Pistolet à eau', '2013-03-15'],
#  ['Guizmo', 'Le masque', '2013-10-28'],
#  ['Guizmo', 'Baby', '2016-06-03'],
#  ['Guizmo', 'Guizbourg', '2018-07-13'],
#  ['Guizmo', '92', '2019-06-07'],
#  ['Guizmo', 'Freestyle Booska-Public Enemy', '2013-07-31'],
#  ['Guizmo', 'Salut les musclés', '2013-10-28'],
#  ['Guizmo', 'Freestyle Planète Rap Jamais 203', '2013-05-05'],
#  ['Mickey 3D', '2-3 Jours à Paris', None],
#  ['Java', 'Paris Musée', '2009-04-27'],
#  ['Ben Mazué', 'Mes monuments', None],
#  ['Ben Mazué',
#   'La princesse et le dictateur, Pt. 8 (Live à L’Olympia)',
#   '2020-04-16'],
#  ['Mathieu Boogaerts', 'Petit a petit b', None],
#  ['Eddy de Pretto', 'Bateaux-Mouches', '2021-01-06'],
#  ['Vincent Baguian', 'Elle du matin lui du soir', None],
#  ['Bandolero', 'Paris Latino', None],
#  ['TSR Crew', 'Bouteille à la Seine', '2015-04-13'],
#  ['TSR Crew', 'Tu connais le tarif', None],
#  ['TSR Crew', 'Des rêves j’en ai plus', None],
#  ['TSR Crew', 'Dur Comme Un Père', '2007-10-22'],
#  ['TSR Crew', 'TSR Au Complet', None],
#  ['TSR Crew', 'Ignorance', None],
#  ['TSR Crew', 'Toujours sur les rails', '2013-10-26'],
#  ['TSR Crew', 'Tise, shit & rap', '2007-10-22'],
#  ['TSR Crew', 'Garde la tête froide', None],
#  ['TSR Crew', 'Anticop', None],
#  ['TSR Crew', 'Cris sans thème', '2004-06-01'],
#  ['TSR Crew', 'Faut qu’on taille', None],
#  ['TSR Crew', 'Ligne de Mire', None],
#  ['TSR Crew', 'Imagine', '2008-05-20'],
#  ['TSR Crew', 'Faut tenir', None],
#  ['TSR Crew', 'Faut Pas S’en Faire', '2009-04-05'],
#  ['IAM', 'Planète mars', '1991-03-25'],
#  ['IAM', 'Non Soumis à l’Etat', None],
#  ['IAM', 'La guerre sainte du rap', None],
#  ['IAM', 'Crécelle', None],
#  ['IAM', 'Planète mars - Homère Mix', '1992-05-18'],
#  ['Georgius', 'Un brin de Paris', None],
#  ['Superbus', 'Travel the world', '2006-10-15'],
#  ['Philippe Clay', 'La Java De La Varenne', None],
#  ['Amanda Lear', 'Fashion Pack', None],
#  ['Katerine', 'Parivelib’', None],
#  ['Katerine', 'Titanic', '2005-10-10'],
#  ['Tayc', 'African Sugar', '2020-12-04'],
#  ['Tayc', 'On se connaît', '2019-02-26'],
#  ['Tayc', 'Ne me touchez pas', None],
#  ['Woodkid', 'Brooklyn', '2011-03-28'],
#  ['Andrex', 'Il Avait Le Charme Slave', None],
#  ['Françoise Hardy', 'Puisque vous partez en voyage', None],
#  ['Françoise Hardy', 'L’heure bleue', None],
#  ['Françoise Hardy', 'Ça m’suffit', None],
#  ['Françoise Hardy', 'Gin Tonic', None],
#  ['Klub des Loosers', 'Sous le signe du V', '2004-09-01'],
#  ['Klub des Loosers', 'Qui perd gagne', '2020-09-02'],
#  ['Klub des Loosers', 'Courir', '2020-09-18'],
#  ['Malicorne', 'L’Écolier Assassin', None],
#  ['Malicorne', 'Le mariage anglais', '1975-01-01'],
#  ['Jean-Jacques Debout', 'Les Rues de Paris', '1990-01-01'],
#  ['Boris Vian', 'Le Petit Commerce', None],
#  ['Boris Vian', 'Mozart avec nous', None],
#  ['Alain Barrière', 'Ca Fait Aimer La Vie', None],
#  ['Alain Barrière', 'Mon Pays', None],
#  ['Marie Laforêt', 'Richard Toll', None],
#  ['KeBlack', 'Ferrari', '2017-01-27'],
#  ['KeBlack', 'Madame', '2020-01-15'],
#  ['KeBlack', 'Bah ouais', '2018-05-11'],
#  ['Bourvil', 'Caroline, Caroline', None],
#  ['Bourvil', 'Les Rois Fainéants', None],
#  ['Bourvil', 'C’est l’piston', None],
#  ['Bourvil', 'Nous n’irons pas à Calcutta', None],
#  ['Eddy Mitchell', 'J’Aime… J’Aime Pas', None],
#  ['Eddy Mitchell', 'Je vous dérange ?', None],
#  ['Eddy Mitchell', 'Aux anges', None],
#  ['Eddy Mitchell', 'J’aime Avril à Paris', '2009-11-23'],
#  ['Eddy Mitchell', 'Le Chanteur du dancing', None],
#  ['Eddy Mitchell', 'Au camp du bonheur', None],
#  ['Eddy Mitchell', 'Mes colonies de vacances', '2010-10-18'],
#  ['Eddy Mitchell', 'Français Made In U.s.a.', None],
#  ['Eddy Mitchell', 'L’idole chante au dessert', None],
#  ['Eddy Mitchell', 'J’Vous Dérange ?', None],
#  ['Benjamin Clementine', 'Paris Cor Blimey', '2017-09-29'],
#  ['La Bamboche', 'Quitte Paris', None],
#  ['Julien Doré', 'Paris-Seychelles', '2013-08-29'],
#  ['Julien Doré', 'Chou Wasabi', '2014-08-22'],
#  ['Julien Doré', 'Les Limites', None],
#  ['Julien Doré', 'Chou Wasabi - Radio Edit', None],
#  ['Julien Doré', 'Platini', None],
#  ['Julien Doré', 'Glenn close', '2011-03-21'],
#  ['Julien Doré', 'Week-End à Rome - Piano-Voix', None],
#  ['Julien Doré', 'Bergman', '2011-03-21'],
#  ['Julien Doré', 'Soirées parisiennes', '2008-01-01'],
#  ['Julien Doré', 'Sublime & silence (Acoustic)', '2018-03-02'],
#  ['Julien Doré', 'Paris-seychelles - live from spotify paris', None],
#  ['L’Algérino', 'Bayna', None],
#  ['L’Algérino', 'Quint Flush', '2010-01-27'],
#  ['Olivia Ruiz', 'Larmes de crocodile', None],
#  ['-M- (FRA)', 'Un monstre à Paris', '2011-10-12'],
#  ['-M- (FRA)', 'L’amour dans l’âme', '2011-10-12'],
#  ['-M- (FRA)', 'Phébus', None],
#  ['Willy Denzey', '#1 Number One (Si tu le veux)', '2003-11-17'],
#  ['Il Était Une Fois', 'Viens Faire Un Tour Sous La Pluie', None],
#  ['Fonky Family', 'La Furie et la Foi', '1998-01-13'],
#  ['Michel Jonasz', 'Groove Baby Groove', None],
#  ['Marwa Loud', 'Remontada', '2018-03-09'],
#  ['Marwa Loud', 'Pas là', '2019-06-14'],
#  ['Marwa Loud', 'Mytho', '2020-09-03'],
#  ['Pierre Perret', 'Le tord-boyaux', None],
#  ['Pierre Perret', 'Blanche', None],
#  ['Pierre Perret', 'Le Gros Paysan', None],
#  ['Pierre Perret', 'Nos amies les bêtes', None],
#  ['Luis Mariano', 'Mexico', None],
#  ['Luis Mariano', 'C’Est Magnifique', None],
#  ['Luis Mariano', 'Miracle De Paris', None],
#  ['Luis Mariano', 'La Valse Mexicaine', None],
#  ['L’Skadrille', 'Soldat universel', '2008-05-19'],
#  ['L’Skadrille', 'H.L.M.', '2006-01-26'],
#  ['Jacqueline François', 'Mademoiselle de Paris', None],
#  ['Pierre Vassiliu', 'Film', None],
#  ['75ème Session x Panama Bende x 13 Sarkastick', 'La diff', '2014-05-03'],
#  ['113', 'Tonton du bled', None],
#  ['113', 'On sait l’faire', '2005-02-20'],
#  ['113', 'Célébration', '2009-06-29'],
#  ['113', 'Dubaï', '2010-12-06'],
#  ['113', 'Assoce de ...', '2002-03-08'],
#  ['113', 'Squatt', '1998-01-01'],
#  ['113', 'Un truc en moi', None],
#  ['113', 'Grandir avec ça', '2005-10-19'],
#  ['Alain Souchon', 'Ames fifties', None],
#  ['Alain Souchon', 'Écoutez d’où ma peine vient', None],
#  ['Alain Souchon', 'Câlin-câline', None],
#  ['Alain Souchon', 'Une guitare un citoyen', None],
#  ['Alain Souchon', 'T’aurais dû venir', None],
#  ['Alain Souchon', 'Le bateau mouche', None],
#  ['Christophe Mali', 'Jeune homme', None],
#  ['1995', 'La Suite', '2012-02-12'],
#  ['1995', 'The Motto (Remix)', '2012-01-26'],
#  ['1995', 'Bienvenüe', '2012-03-05'],
#  ['1995', 'Freestyle Générations (Part 1)', '2011-06-22'],
#  ['1995', 'Renégats', '2012-03-05'],
#  ['1995', 'Freestyle PSM', '2012-12-12'],
#  ['1995', 'TIP', '2011-06-27'],
#  ['1995', 'Je brille', '2011-06-27'],
#  ['1995', 'C’qui nous pousse', '2011-08-22'],
#  ['Manau', 'Fest noz de paname', None],
#  ['Manau', 'J’dédicace', None],
#  ['Manau', 'Dafunkamanau', None],
#  ['Philippe Lavil', 'Elle Tricote Des Pulls Pour Personne', None],
#  ['Alex Beaupain', 'Brooklyn Bridge', None],
#  ['Josephine Baker', 'J’ai deux amours', None],
#  ['Josephine Baker', 'Dis-moi joséphine?', None],
#  ['Josephine Baker', 'Paris mes amours', None],
#  ['Josephine Baker', 'Sans Amour', None],
#  ['Josephine Baker', 'Paris cheri', None],
#  ['Dionysos', 'Thank You Satan', None],
#  ['MMZ', 'Tout pour le gang', '2016-05-22'],
#  ['MMZ', 'Millions', '2016-11-04'],
#  ['MMZ', 'Miroir miroir', '2017-04-28'],
#  ['MMZ', 'Oh My (Miami)', None],
#  ['Team BS', 'Intro', '2014-02-24'],
#  ['Étienne Daho', 'Ouverture', None],
#  ['Étienne Daho', 'Paris Le Flore', '1986-04-01'],
#  ['Étienne Daho', 'Week-End à Rome - 1829661', None],
#  ['Étienne Daho', 'Les bords de Seine', '1996-11-19'],
#  ['Étienne Daho', 'Paris Ailleurs', None],
#  ['Étienne Daho', 'Rue Des Petits Hôtels', None],
#  ['France Gall', 'Jazz à Gogo', None],
#  ['France Gall', 'Ça Balance pas Mal à Paris', None],
#  ['France Gall', 'Links vom Rhein und rechts vom Rhein', None],
#  ['France Gall', 'Vahiné', None],
#  ['Hervé Vilard', 'Ma Chanson De Liberté', None],
#  ['La Caravane Passe', 'Gypsy For one day', '2013-04-25'],
#  ['Franglish', 'Bibi', '2020-06-12'],
#  ['Les Chaussettes Noires', 'Dactylo Rock', None],
#  ['Bertrand Cantat', 'Chuis Con', '2017-12-01'],
#  ['Jacques Dutronc', 'Le Roi De La Fête', None],
#  ['Mano Negra', 'Ronde De Nuit', '1988-01-01'],
#  ['Mano Negra', 'Drives Me Crazy', None],
#  ['Mano Negra', 'Bragg Jack', '1988-11-30'],
#  ['La Femme', 'S.S.D', '2016-09-02'],
#  ['La Femme', 'Me suive', '2016-09-02'],
#  ['La Femme', 'Me Suive (English version)', None],
#  ['Sapho', 'Train de Paris', None],
#  ['Sté Strausz', 'Le rap est ma vie', None],
#  ['Line Renaud', 'Bouclette', None],
#  ['Soviet Suprem', 'French Romance', None],
#  ['MZ', 'Noir c’est noir', '2016-04-22'],
#  ['MZ', 'Pas Nouveaux', '2014-12-05'],
#  ['MZ', 'Ma rue', '2016-04-22'],
#  ['MZ', 'Dans mon club', '2016-08-03'],
#  ['MZ', 'Fesses', '2013-07-01'],
#  ['MZ', 'Mr.Presents', '2013-03-01'],
#  ['MZ', 'Dehmo’Lude', '2015-12-03'],
#  ['Noir Désir', 'L’Homme Pressé', '1996-11-11'],
#  ['Noir Désir', 'Le grand incendie', '2001-09-11'],
#  ['Noir Désir', 'À l’arrière des taxis', '1989-01-10'],
#  ['Daddy Mory', 'Ina di club 2', '2007-05-27'],
#  ['Tessa B.', 'Jamais', '2018-07-06'],
#  ['William Sheller', 'Photos souvenirs', None],
#  ['Chantal Goya', 'Pandi Panda', None],
#  ['Mafia K’1 Fry', 'Rabzouz', '2003-01-01'],
#  ['Mafia K’1 Fry', 'En bas des tours', '2003-04-28'],
#  ['Mafia K’1 Fry', 'Val 2 Meurtre', '2007-01-29'],
#  ['Blankass', 'C’est quoi ton nom ?', '2019-01-01'],
#  ['Blankass', 'Maria', None],
#  ['Tri Yann', 'Kerfank', None],
#  ['Tri Yann', 'Chanson des commères', '1974-01-01'],
#  ['Michel Legrand', 'I love paris', None],
#  ['Suzane', 'Suzane', '2019-01-24'],
#  ['Suzane', 'La vie dolce', '2021-01-07'],
#  ['Naâman', 'We all', '2016-09-19'],
#  ['Madame Monsieur', 'Qui sait', '2018-04-20'],
#  ['Madame Monsieur', 'Mon pays', '2020-06-26'],
#  ['Gérard Manset', 'Pour Un Joueur De Guitare', None],
#  ['Kaaris', 'Crystal', '2015-03-04'],
#  ['Kaaris', '4Matic', '2016-11-11'],
#  ['Kaaris', '2.7 Zéro 10.17', '2016-11-11'],
#  ['Kaaris', 'Benz', '2016-11-11'],
#  ['Kaaris', 'NRV', '2020-07-31'],
#  ['Kaaris', '2 Bigos', '2016-11-11'],
#  ['Kaaris', 'Mood', '2017-11-03'],
#  ['Kaaris', 'Courez', '2017-11-03'],
#  ['Kaaris', 'Guedro', '2020-09-04'],
#  ['Kaaris', 'Mes pulsions', '2007-11-20'],
#  ['Kaaris', 'Mes pulsions (Remix)', '2007-11-20'],
#  ['Jean Gabin', 'Quand on s’promène au bord de l’eau', None],
#  ['FAUVE', 'Sainte Anne', None],
#  ['Ninho', 'Lettre à une femme', '2020-03-07'],
#  ['Ninho', 'Goutte d’eau', '2019-02-21'],
#  ['Ninho', 'Outro', '2019-03-22'],
#  ['Ninho', 'À Kinshasa', '2019-03-22'],
#  ['Ninho', 'Millésimes', '2020-03-07'],
#  ['Ninho', 'Cash money & Kilogramme', '2015-12-07'],
#  ['Nuttea', 'Elles dansent', None],
#  ['Nuttea', 'La Weed Brûle', None],
#  ['Jacqueline Taieb', 'Ce soir je m’en vais', None],
#  ['Shy’m', 'On s’en va', '2014-11-24'],
#  ['Sniper', 'Panam All Starz', '2003-09-15'],
#  ['Sniper', 'Retour aux sources', '2006-05-22'],
#  ['Sniper', 'Qu’est-ce qu’on doit faire', '2004-05-14'],
#  ['Seemone', 'Rue Vivienne', '2020-10-02'],
#  ['Lescop', 'Paris S’Endort', None],
#  ['Marvin Jouno', 'Love Later', '2016-03-11'],
#  ['Marvin Jouno', 'Panorama', '2016-03-11'],
#  ['Marvin Jouno', 'Est-ce l’Est ?', '2016-03-11'],
#  ['Marvin Jouno', 'Clap de fin', None],
#  ['Francis Lemarque', 'À Paris', None],
#  ['Émilie Simon', 'To the Dancers in the Rain', '2003-05-27'],
#  ['Émilie Simon', 'Paris j’ai pris perp\x8fte - 2125495', None],
#  ['Jean Sablon', 'Rendez-Vous Sous La Pluie', None],
#  ['Jean Sablon', 'Merci À Vous', None],
#  ['Jean Sablon', 'Sur Les Quais Du Vieux Paris', None],
#  ['Liane Foly', 'Hôtel D’Angleterre', None],
#  ['Leeroy', 'Cougars', '2016-02-19'],
#  ['Leeroy', 'Emmène-moi', '2016-02-19'],
#  ['Leeroy', 'Danse-moi', '2016-02-19'],
#  ['Yves Duteil', 'Tombée Des Nues', None],
#  ['Yves Duteil', 'Nathalie', None],
#  ['Christophe Maé', 'La Parisienne', '2016-05-13'],
#  ['Vincent Delerm', 'Et François de Roubaix dans le dos', None],
#  ['Vincent Delerm', 'Panorama', None],
#  ['Vincent Delerm', 'Les Enfants Pâles', None],
#  ['Colette Renard', 'Avec les anges', None],
#  ['Michel Fugain', 'Jamais je ne t’oublierai', None],
#  ['Michel Fugain', 'Balade en Bugatti', None],
#  ['Michel Fugain', 'Les alizés', None],
#  ['Michel Fugain', 'Le beau zoo', None],
#  ['Michel Fugain', 'Bluesy', None],
#  ['Maurice Fanon', 'Il Y A Si Peu De Temps', None],
#  ['Maurice Fanon', 'Paris-Cayenne', None],
#  ['Aristide Bruant', 'Au Bois de Boulogne', None],
#  ['Aristide Bruant', 'A Saint-Ouen', None],
#  ['13 Block', 'A1 A3', '2018-04-06'],
#  ['Indila', 'Parle à ta tête', '2019-11-14'],
#  ['Christophe Willem', 'Coffee', None],
#  ['Christophe Willem', 'Le Lycée', None],
#  ['Yannick Noah', 'Ma Pomme', '2014-02-21'],
#  ['Zazie', 'Après la pluie', '2020-04-10'],
#  ['Zazie', 'Les pieds nus', '2010-09-13'],
#  ['Jenifer', 'L’amour & moi', '2012-09-17'],
#  ['Jenifer', 'Post mélancolie', None],
#  ['Jenifer', 'Si maman si', '2013-06-03'],
#  ['Florent Pagny', 'Châtelet Les Halles', None],
#  ['Florent Pagny', 'Immense', '2017-09-22'],
#  ['Florent Pagny', 'Vesoul', None],
#  ['Florent Pagny', 'Et Maintenant', None],
#  ['Loïc Lantoine', 'Côté punk', '2004-01-01'],
#  ['Grégory Lemarchal', 'Je t’écris', None],
#  ['Henri Salvador', 'C’Est Pas La Joie', None],
#  ['Henri Salvador', 'Moi j’prends mon temps', None],
#  ['Henri Salvador', 'Moi J’Préfère La Marche À Pied', None],
#  ['Henri Salvador', 'Caroline', None],
#  ['Henri Salvador', 'Syracuse (live au Casino de Paris)', None],
#  ['Henri Salvador', 'La Fin des vacances', None],
#  ['Henri Salvador', 'Petit Lapin', None],
#  ['Charles Aznavour', 'Non, je n’ai rien oublié', None],
#  ['Charles Aznavour', 'Je m’voyais déjà', None],
#  ['Charles Aznavour', 'Paris au mois d’août', None],
#  ['Charles Aznavour', 'J’aime Paris au mois de mai', None],
#  ['Charles Aznavour', 'J’me voyais déjà', None],
#  ['Charles Aznavour', 'La route', None],
#  ['Charles Aznavour', 'Paris Is At Her Best In May', None],
#  ['Charles Aznavour', 'Le repos de la guerrière', None],
#  ['Charles Aznavour', 'L’album de toi', None],
#  ['Charles Aznavour', 'De la Môme à Edith', '2015-05-04'],
#  ['Charles Aznavour', 'Moi', '2005-10-11'],
#  ['Charles Aznavour', 'Sans limite', '2005-10-11'],
#  ['Juliette Gréco', 'Il n’y a plus d’après', None],
#  ['Juliette Gréco', 'Sous le ciel de Paris', None],
#  ['Juliette Gréco', 'Romance', None],
#  ['Juliette Gréco', 'Paris-canaille', None],
#  ['Juliette Gréco', 'Paname', None],
#  ['Juliette Gréco', 'Le gros Lulu', None],
#  ['Juliette Gréco', 'La famille Dupanard', None],
#  ['Juliette Gréco', 'Syracuse', None],
#  ['Arnaud Fleurent-Didier', 'Si on se dit pas tout', None],
#  ['Louisy Joseph', 'Mes insomnies', None],
#  ['Ilona Mitrecey', 'C’est les vacances', None],
#  ['Pierre Bachelet', 'Vingt ans', None],
#  ['Pierre Bachelet', 'Marionnettiste', None],
#  ['Calogero', 'De l’Ombre à la Lumière', '2009-04-20'],
#  ['Calogero', 'L’Eclipse', '2014-08-18'],
#  ['Calogero', 'Liberté chérie', '2017-08-25'],
#  ['Calogero', 'Fidèle', '2014-08-18'],
#  ['Laurent Lamarca', 'Le Vol Des Cygnes', '2018-04-06'],
#  ['Jean Guidoni', 'Tout Va Bien', None],
#  ['Jean Guidoni', 'Comme Dans Un Ballet De Pina Bausch', None],
#  ['Jean Guidoni', 'La Grande Expo De LAn 2000', None],
#  ['Jean Guidoni', 'La Carte Postale', None],
#  ['Hélène Rollès', 'Je suis venue à Paris', None],
#  ['Squeezie', 'Freestyle de potes', '2018-05-04'],
#  ['Squeezie', 'Guépard', '2020-07-03'],
#  ['Dalida', 'Là où je t’aime', None],
#  ['Dalida', 'Mama Caraïbo', None],
#  ['Dalida', 'Le restaurant italien', None],
#  ['Dalida', 'Le Vénitien de Levallois', None],
#  ['Dalida', 'Mon Italie', None],
#  ['Serge Gainsbourg', '69 année érotique', None],
#  ['Lunatic', 'Sang d’encre', None],
#  ['Lunatic', 'L.U.N.A.T.I.C.', '2006-02-20'],
#  ['Lunatic', 'B.O. (Generaldo Tape)', '2006-02-20'],
#  ['Sefyu', 'La vie qui va avec', None],
#  ['Sefyu', 'La légende', '2006-04-13'],
#  ['Sefyu', '3ème Guerre', '2008-05-12'],
#  ['Sefyu', 'Invaincu', '2019-04-12'],
#  ['Sefyu', 'Faits Divers 2', None],
#  ['Sefyu', 'Biff', '2006-04-24'],
#  ['Tsew The Kid', 'Ton âme', '2019-03-15'],
#  ['Tsew The Kid', 'Maussade', '2020-03-04'],
#  ['Tsew The Kid', 'Wanderlust', '2018-12-14'],
#  ['Kalash Criminel', 'Hood', '2017-05-03'],
#  ['Kalash Criminel', 'Insta Twitter', '2020-11-20'],
#  ['Kalash Criminel', 'Finish Him', '2020-11-20'],
#  ['Michel Sardou', 'Le figurant', None],
#  ['Michel Sardou', 'Méfions-nous des fourmis', None],
#  ['Michel Sardou', 'Je Me Souviens D’Un Adieu', None],
#  ['Michel Sardou', 'Les Hommes Qui Ne Dorment Jamais', None],
#  ['Michel Sardou', '18 Ans 18 Jours', None],
#  ['Michel Sardou', 'Valentine Day', None],
#  ['Michel Sardou', 'Victoria', None],
#  ['Michel Sardou', 'La Maison Des Vacances', None],
#  ['Oldelaf', 'Le café', None],
#  ['Oldelaf', 'Et si', '2018-03-02'],
#  ['Oldelaf', 'Novembre', '2020-03-01'],
#  ['BB Brunes', 'En ce qui me consterne', '2013-11-18'],
#  ['Odezenne', 'Saxophone', '2012-03-22'],
#  ['Odezenne', 'Existe Petit Bout De Rien', None],
#  ['Odezenne', 'Boom Boom', None],
#  ['Odezenne', 'Delta', '2019-09-13'],
#  ['Laurent Voulzy', 'Karin Redinger', None],
#  ['Laurent Voulzy', 'En tini', None],
#  ['Laurent Voulzy', 'Black Poule', None],
#  ['Louis Capart', 'Marie-Jeanne-Gabrielle', None],
#  ['Manu Chao', 'Le Rendez-vous', None],
#  ['Manu Chao', 'LE RENDEZ VOUS THE RETURN', None],
#  ['Boby Lapointe', 'La Fille du Pêcheur', None],
#  ['Boby Lapointe', 'Saucisson de cheval n°1', None],
#  ['Boby Lapointe', 'Diba diba', None],
#  ['Boby Lapointe', 'Fille Du Pêcheur', None],
#  ['Plana Georgette', 'Riquita', None],
#  ['Keny Arkana', 'Madame la Marquise', '2017-06-02'],
#  ['Keny Arkana', 'La vérité fait mal', '2017-06-02'],
#  ['Jacques Higelin', 'Le fil à la patte du caméléon', None],
#  ['Jacques Higelin', 'Le naïf haïtien', None],
#  ['Sofiane', 'Toka', '2017-04-07'],
#  ['Sofiane', 'Fais le mouv', '2016-08-26'],
#  ['Sofiane',
#   '#Jesuispasséchezso : Episode 1 / Marseille-Castellane',
#   '2016-04-11'],
#  ['Sofiane',
#   '#Jesuispasséchezso : Episode 9 / Tireurs dans la ville',
#   '2016-09-19'],
#  ['Sofiane', '#Jesuispasséchezso : Episode 2 / Neymar', '2016-04-19'],
#  ['Sofiane', 'Épisode sombre', '2020-04-10'],
#  ['Sofiane', '#Jesuispasséchezso : Episode 8 / Fais le Mouv', '2016-08-26'],
#  ['Sofiane', 'Freestyle Boosk’Affranchis', '2018-01-25'],
#  ['Sofiane', 'Ghettoyouth Remix', None],
#  ['Sofiane', 'Karismatik Ultimatum', None],
#  ['Jehan Jonas', 'Sur les quais', '1966-01-01'],
#  ['Naps', 'T’as cliqué', '2016-05-25'],
#  ['Naps', 'Cœur sur la main', '2020-02-28'],
#  ['Bramsito', 'Ma go', '2020-07-17'],
#  ['Maxime Le Forestier', 'Né quelque part', None],
#  ['Maxime Le Forestier', 'Voyage au moyen-âge', None],
#  ['Maxime Le Forestier', 'Les Rats', None],
#  ['Maxime Le Forestier', 'Le Bistrot', None],
#  ['Vianney', 'Pour de vrai', '2020-10-30'],
#  ['Vianney', 'Caroline', '2018-10-04'],
#  ['Vianney', 'La fille du sud', '2020-10-30'],
#  ['Fababy', 'Freestyle Planète Rap', '2012-03-02'],
#  ['Fababy', 'N’Appelle Pas La Police', '2013-10-30'],
#  ['Fababy', 'Avec le coeur', None],
#  ['Dick Rivers', 'Paris - Vintimille', None],
#  ['Mano Solo', 'Je suis venu vous voir', None],
#  ['Mano Solo', 'Allo Paris', None],
#  ['Mano Solo', 'Allez viens', None],
#  ['Mano Solo', 'Barbès-Clichy', None],
#  ['Mano Solo', 'C’est pas du gâteau', None],
#  ['Mano Solo', 'Sacré Coeur', None],
#  ['Mano Solo', 'Une Image', None],
#  ['Mano Solo', 'Botzaris', None],
#  ['Mano Solo', 'El Mungo', None],
#  ['Mano Solo', 'Les petits carrés blancs', None],
#  ['Mano Solo', 'Paris Boulevard', None],
#  ['Boulevard des Airs', 'Paris-Corbeil', None],
#  ['Boulevard des Airs', 'Paris-corbeil (remix)', None],
#  ['Sanseverino', '10 Jours Avant Paris', None],
#  ['Heuss L’enfoiré', 'BX Land #1', '2017-07-23'],
#  ['Heuss L’enfoiré', 'En esprit', '2019-01-25'],
#  ['Heuss L’enfoiré', 'Midi Midi', '2018-02-02'],
#  ['Heuss L’enfoiré', 'BX Land #3', '2018-12-28'],
#  ['Gérard Lenorman', 'Michèle', '1976-01-01'],
#  ['Melissmell', 'La Crapule', None],
#  ['M. Pokora', 'Danse pour moi', None],
#  ['M. Pokora', 'Internationalude', None],
#  ['M. Pokora', 'Player', None],
#  ['Zed Yun Pavarotti',
#   '#Frenchmen - Saison 2 - Zed Yun Pavarotti',
#   '2018-11-28'],
#  ['Les Négresses Vertes', 'Voilà l’Été', None],
#  ['Les Négresses Vertes', 'I Love Paris', None],
#  ['Fatal Bazooka', 'Mauvaise foi nocturne - version album', None],
#  ['Beat de Boul', 'Freestyle LPK7FDRF', '1995-01-01'],
#  ['Beat de Boul', 'Pas assez pour le futur', '1997-07-13'],
#  ['Booba', 'Paname', '2011-08-19'],
#  ['Booba', '4G', '2015-12-04'],
#  ['Booba', 'Jour de paye', '2010-11-22'],
#  ['Renaud', 'Hexagone', '1975-04-03'],
#  ['Renaud', 'Les bobos', '2006-09-04'],
#  ['Renaud', 'Si les Ricains', '1976-01-01'],
#  ['Renaud', 'Mon beauf’', None],
#  ['Renaud', 'À la belle de Mai', '1994-11-18'],
#  ['Renaud', 'La jeune fille du métro', None],
#  ['Renaud', 'La zone', None],
#  ['Renaud', 'Petit pédé', None],
#  ['Renaud', 'Le retour de Gérard Lambert', None],
#  ['Renaud', 'Écoutez-moi les gavroches', '1975-04-03'],
#  ['Renaud', 'Rouge-gorge', None],
#  ['Renaud', 'Je vis caché', None],
#  ['Renaud', 'Peau aime', None],
#  ['Renaud', 'Petite fille slave', '2016-04-08'],
#  ['Renaud', 'Le sirop de la rue', None],
#  ['Renaud', 'Les tomates', None],
#  ['Renaud', 'Adieu l’enfance', None],
#  ['Renaud', 'I bot un d’mi', None],
#  ['Renaud', 'La femme d’Hector', None],
#  ['Renaud', 'Le camionneur rêveur', None],
#  ['Nouvelle Vague', 'Week-end a Rome (feat. Vanessa Paradis)', None],
#  ['Wallen', 'Avoir La Vie Devant Soi', '2004-10-19'],
#  ['Damien Saez', 'Mon Européenne', '2017-01-28'],
#  ['Damien Saez', 'Pilule', '2010-03-29'],
#  ['Damien Saez', 'Tous les gamins du monde', '2016-11-04'],
#  ['Damien Saez', 'Marie', None],
#  ['Damien Saez', 'Les amours mortes', '2017-03-10'],
#  ['Damien Saez', 'Ma putain du show-biz', '2017-03-10'],
#  ['Damien Saez', 'Matins de neige', '2017-03-10'],
#  ['Damien Saez', 'En bords de Seine', '2017-03-10'],
#  ['Damien Saez', 'Messine', None],
#  ['Damien Saez', 'Mon pays je t’écris', '2016-12-09'],
#  ['Damien Saez', 'Ami De Liège', None],
#  ['Damien Saez', 'Qui je suis, d’où je viens', '2008-07-18'],
#  ['Damien Saez', 'Petrushka', '2019-11-22'],
#  ['Damien Saez', 'La dame en feu', '2019-11-22'],
#  ['Butter Bullets', 'Sport', '2017-12-04'],
#  ['Butter Bullets', 'Les Larmes du Soleil', '2010-08-04'],
#  ['Butter Bullets', '14 avril [Air Mès et Hermax]', '2017-12-04'],
#  ['Butter Bullets',
#   'Une balle dans la tête (Grosmachindeguerre Remix)',
#   '2012-11-05'],
#  ['Butter Bullets', 'L’odeur de la mort', '2012-11-05'],
#  ['Allain Leprest', 'Le Temps De Finir La Bouteille', '2005-10-08'],
#  ['Taxi Girl', 'Paris', None],
#  ['Arthur H', 'Le baron noir', None],
#  ['Arthur H', 'Le tonnerre du coeur', None],
#  ['Gauvain Sers', 'Comme si c’était hier', None],
#  ['Gauvain Sers', 'Comme chez Leprest', None],
#  ['Bérurier Noir', 'Nuit Apache', None],
#  ['Bérurier Noir', 'On a Faim', None],
#  ['Bérurier Noir', 'Et Hop + Macadam Circus II', None],
#  ['Bérurier Noir', 'Carnet de Route', None],
#  ['Bérurier Noir', 'Mourir à Paris', None],
#  ['OrelSan', 'Suicide social', '2011-09-15'],
#  ['OrelSan', 'La Petite Marchande De Portes-Clefs', '2011-09-26'],
#  ['High Five Crew', 'Lotus', '2014-02-09'],
#  ['Black M', 'Foncés grosses lèvres', '2013-07-08'],
#  ['Black M', 'Les yeux plus gros que... Beriz', '2013-09-25'],
#  ['Black M', 'À la vôtre', '2014-03-31'],
#  ['Black M', 'Death Note', '2017-09-29'],
#  ['Black M', 'Maman j’arrive', '2019-09-13'],
#  ['Sheryfa Luna', 'Je reviendrai', None],
#  ['Vald', 'Ne me déteste pas', '2018-02-02'],
#  ['Vald', 'Elyxir', '2012-01-29'],
#  ['Vald', 'Jean Teh', '2018-01-19'],
#  ['Vald', 'Freestyle Booska NQNT 2', '2015-09-25'],
#  ['Vald', 'La réussite', '2016-11-27'],
#  ['Vald', 'MacDo', '2018-09-14'],
#  ['Michel Berger', 'Si maman si', None],
#  ['Michel Berger', 'Chanson pour Man Ray', '1990-01-01'],
#  ['Guerilla Poubelle', 'Demain Il Pleut', None],
#  ['Guerilla Poubelle', 'Prévert, Kosma, Paris', None],
#  ['Guerilla Poubelle', 'Exception Culturelle & Trafic d’Armes', None],
#  ['Guerilla Poubelle', 'La ronde de nuit', '2018-12-21'],
#  ['Singuila', 'I Love Paris', '2017-04-21'],
#  ['Morsay', 'Michetonneuse', None],
#  ['Kamelancien', 'Crise Cardiaque (clash La Fouine)', None],
#  ['Kamelancien', 'Du bled à la France', None],
#  ['Johnny Hallyday', 'Je Suis Né dans La Rue', None],
#  ['Johnny Hallyday', 'Une lettre à l’enfant que j’étais', None],
#  ['Johnny Hallyday', 'Elle M’Oublie', None],
#  ['Kendji Girac', 'Viens Chez Nous', None],
#  ['Jean-Louis Murat', 'Comme un incendie', None],
#  ['Koxie', 'Garçon', '2007-06-25'],
#  ['Koxie', 'Ma meilleure amie', None],
#  ['Jean-François Michael', 'Adieu Jolie Candy', None],
#  ['Helmut Fritz', 'Ça m’énerve 2020', '2020-04-10'],
#  ['Lucenzo', 'Vem Dançar Kuduro', None],
#  ['Tino Rossi', 'Paris voici paris', None],
#  ['Diam’s', 'Petite Banlieusarde', None],
#  ['Natoo', 'Cathy Paris', '2017-06-18'],
#  ['Lys Gauty', 'Complainte désabusée', None],
#  ['Niska', 'PSG (Matuidi Charo)', '2015-03-29'],
#  ['Niska', 'Cala Boca', '2016-06-03'],
#  ['Niska', 'Alien', '2015-10-02'],
#  ['Pauline Croze', 'Mise à nu', '2005-02-14'],
#  ['Jean-Jacques Goldman', 'Doux', None],
#  ['Max Boublil', 'J’aime les moches', None],
#  ['Max Boublil', 'Moyen moyenne', None],
#  ['Soprano', 'Ti Amo', '2014-10-13'],
#  ['Soprano', 'Abusew', '2013-08-13'],
#  ['Soprano', 'Les Croqueurs De Diamant', '2015-10-30'],
#  ['Gradur', 'Sheguey 6 (Soldat Mili)', '2014-03-15'],
#  ['Gradur', '#LHOMMEAUBOB', '2015-02-23'],
#  ['Gradur', 'Beef', '2015-02-23'],
#  ['Gradur', 'Grady', '2015-11-27'],
#  ['Gradur', 'T’es partie', '2016-02-19'],
#  ['Gradur', 'Rolling Stones', '2019-11-29'],
#  ['Mick micheyl', 'Un gamin de paris', None],
#  ['Dany Brillant', 'Tu as brisé ma vie', '1993-11-03'],
#  ['Dany Brillant', 'J’habitais Saint-Germain-des-Prés', '2004-06-15'],
#  ['Dany Brillant', 'Rien que toi', '1994-04-24'],
#  ['Dany Brillant', 'La nuit est à nous', '1991-11-25'],
#  ['Charles Trenet', 'Revoir Paris', None],
#  ['Charles Trenet', 'Le Grand Café', None],
#  ['Charles Trenet', 'Moi j’aime le music hall', None],
#  ['Charles Trenet', 'Vous Oubliez Votre Cheval', None],
#  ['Charles Trenet', 'Retour À Paris', None],
#  ['Charles Trenet', 'Biguine À Bango', None],
#  ['Charles Trenet', 'En Quittant La Ville', None],
#  ['Charles Trenet', 'Les Oiseaux De Paris', None],
#  ['Charles Trenet', 'Les oiseaux de Paris (Charles Trenet)', None],
#  ['Charles Trenet', 'Annie-Anna', None],
#  ['Marc Lavoine', 'Paris', None],
#  ['Marc Lavoine', 'La Mélancolie', '2005-05-23'],
#  ['Marc Lavoine', 'Fabriqué', None],
#  ['Marc Lavoine', 'J’Entends La Musique', '1999-08-31'],
#  ['Jean Ferrat', 'C’est beau la vie', None],
#  ['Jean Ferrat', 'Les cerisiers', None],
#  ['Jean Ferrat', 'Complainte de Pablo Neruda', None],
#  ['Jean Ferrat', 'Les feux de Paris', None],
#  ['Jean Ferrat', 'Vipères lubriques', None],
#  ['Jean Ferrat', 'Les jeunes imbéciles', None],
#  ['Jean Ferrat', 'Hourrah!', None],
#  ['Jean Ferrat', 'Paris an 2000', None],
#  ['Jean Ferrat', 'Régarde-toi paname', None],
#  ['Jean Ferrat', 'Un jour futur', None],
#  ['Jean Ferrat', 'Quatre cents enfants noirs', None],
#  ['Jean Ferrat', 'Les noctambules', None],
#  ['Jean Ferrat', 'Un enfant quitte Paris', None],
#  ['François Béranger', 'Joue Pas Avec Mes Nerfs', None],
#  ['François Béranger', 'Chanson Bleue', None],
#  ['Maurice Chevalier', 'Ca Sent Si Bon La France', None],
#  ['Maurice Chevalier', 'Le Chapeau De Zozo', None],
#  ['Léo Ferré', 'Il n’y a plus rien', None],
#  ['Léo Ferré', 'Rotterdam', None],
#  ['Léo Ferré', 'Préface', None],
#  ['Léo Ferré', 'Les étrangers', None],
#  ['Léo Ferré', 'La violence et l’ennui', None],
#  ['Léo Ferré', 'La poésie', None],
#  ['Léo Ferré', 'C’est le printemps', None],
#  ['Léo Ferré', 'Nous deux', None],
#  ['Léo Ferré', 'La vie moderne', None],
#  ['Léo Ferré', 'Y’a une étoile', None],
#  ['Léo Ferré', 'Titi De Paris', None],
#  ['Léo Ferré', 'Les parisiens', None],
#  ['Léo Ferré', 'Les Chéris', None],
#  ['Léo Ferré', 'Le guinche', None],
#  ['Dosseh', 'MQTB', '2018-07-05'],
#  ['Dosseh', 'Été au tieks', '2015-06-19'],
#  ['Dosseh', '45 atmo', '2018-07-05'],
#  ['Dosseh', 'Je suis Yuri (#YuriNegrowski9)', '2015-12-29'],
#  ['Dosseh', 'Session freestyle avec Dinos & TGR', '2019-03-13'],
#  ['Dosseh', 'J.C.', '2011-07-29'],
#  ['Caterina Valente', 'Ganz Paris träumt von der Liebe', None],
#  ['Jeanne Moreau', 'Ah! Les p’tites femmes de Paris', None],
#  ['Édith Piaf', 'Paris', None],
#  ['Édith Piaf', 'Le chevalier de Paris', None],
#  ['Édith Piaf', 'Emporte-moi', None],
#  ['Édith Piaf', 'Une Valse', None],
#  ['Édith Piaf', 'Les orgues de barbarie', None],
#  ['Éric Toulis', 'L’intermittière', '2010-01-01'],
#  ['Éric Toulis', 'Dans les cocktails', '2000-01-01'],
#  ['Phil Barney', 'New York Sous La Pluie', None],
#  ['Georges Brassens', 'Supplique pour être enterré à la plage de Sète', None],
#  ['Georges Brassens', 'La Ballade des gens qui sont nés quelque part', None],
#  ['Georges Brassens', 'Le bistrot', None],
#  ['Georges Brassens', 'La femme d’Hector', None],
#  ['Georges Brassens', 'Les Ricochets', '1976-12-01'],
#  ['Georges Brassens', 'Le Modeste', None],
#  ['Georges Brassens', 'L’Assassinat', None],
#  ['Georges Brassens', 'Le Nombril des femmes d’agents', None],
#  ['Georges Brassens', '1ère Lettre à Toussenot', '1946-06-02'],
#  ['Georges Brassens', '2ème Lettre à Toussenot', '1946-10-24'],
#  ['Carla Bruni', 'Little French Song', None],
#  ['Kenza Farah', 'Le Bon Choix', '2014-12-25'],
#  ['Kenza Farah', 'KarismaFuckYou', '2012-02-04'],
#  ['Jean-Michel Caradec', 'Marie', None],
#  ['Yves Montand', 'Les Grands Boulevards', None],
#  ['Yves Montand', 'A Paris', None],
#  ['Yves Montand', 'Battling Joe', None],
#  ['Yves Montand', 'Metro', None],
#  ['Michel Delpech', 'Le Loir Et Cher', None],
#  ['Michel Delpech', 'L’Amour En Wagon-Lit', None],
#  ['Michel Delpech', 'Un Paris-Soir Sur Le Visage', None],
#  ['Michel Delpech', 'Moi J’Aime Le Music-Hall', None],
#  ['Michel Delpech', 'Inventaire 66', None],
#  ['Michel Delpech', 'Ce Fou De Nicolas', None],
#  ['Michel Delpech', 'Paris à marée basse', None],
#  ['Jil Caplan', 'Tard dans la nuit', None],
#  ['Camélia Jordana', 'Empire', None],
#  ['Chimène Badi', 'Septembre 94', None],
#  ['Guy Béart', 'Il n’y a plus d’après', None],
#  ['Guy Béart', 'Lune ma banlieue', None],
#  ['Gilbert Bécaud', 'Nathalie', None],
#  ['Gilbert Bécaud', 'Le Bain de Minuit', None],
#  ['The Pirouettes', '2016 (En ce temps-là)', '2016-09-16']]

# %%
fonction_bonus("porte de la chapelle")
# Out:
# [['Johnny Hallyday', 'Le temps passe', '2005-11-07'],
#  ['Johnny Hallyday', 'Le temps passe', '2005-11-07']]

# %%
fonction_bonus("rue des ecoles")
# Out:
# []

# %%
fonction_bonus("panthéon")
# Out:
# [['Alkpote', 'Rien ne change', '2014-04-07'],
#  ['Alkpote', 'Rien ne change', '2014-04-07'],
#  ['Jacques Bertin', 'Le bonheur des autres', None],
#  ['Jacques Bertin', 'Le bonheur des autres', None],
#  ['Michel Sardou', 'Si j’avais un frère', None],
#  ['Michel Sardou', 'Si j’avais un frère', None],
#  ['Maxime Le Forestier', 'Le Vieux Léon', None],
#  ['Maxime Le Forestier', 'Le Vieux Léon', None],
#  ['Booba', '4G', '2015-12-04'],
#  ['Booba', '4G', '2015-12-04'],
#  ['Renaud', 'Le vieux Léon', None],
#  ['Renaud', 'Le vieux Léon', None],
#  ['Jean Ferrat', 'Robert le Diable', None],
#  ['Jean Ferrat', 'Robert le Diable', None],
#  ['Jean Ferrat', 'Les feux de Paris', None],
#  ['Jean Ferrat', 'Les feux de Paris', None],
#  ['Jean Ferrat', 'Pauvre Boris', None],
#  ['Jean Ferrat', 'Pauvre Boris', None],
#  ['Georges Brassens', 'Supplique pour être enterré à la plage de Sète', None],
#  ['Georges Brassens', 'Supplique pour être enterré à la plage de Sète', None],
#  ['Georges Brassens', 'À Mireille dite “Petit Verglas”', None],
#  ['Georges Brassens', 'À Mireille dite “Petit Verglas”', None]]

# %%
m1 = ouvrir_json("/Users/mustapha/Documents/GitHub/Memoire/infos&stats/infos_all_data.json")
l1 = []
for i in m1:
    for k in i:
         for e in k["lieux"]:
            l1.append(e)

# %%
print("le nombre de lieux détectés par les trois modèles de spaCy: ",len(l1))
# Out:
# le nombre de lieux détectés par les trois modèles de spaCy:  489251
